# %%
import datetime
import os
import pickle
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
from sklearn.ensemble import AdaBoostClassifier
from sklearn.inspection import PartialDependenceDisplay, partial_dependence
from sklearn.metrics import (ConfusionMatrixDisplay, accuracy_score, precision_recall_curve, roc_auc_score, roc_curve)
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.tree import DecisionTreeClassifier

import shap

# %config InlineBackend.figure_format = 'retina'

# %%
from notebook import notebookapp
import urllib
import json
import ipykernel
from shutil import copy2

def notebook_path():
    """Returns the absolute path of the Notebook or None if it cannot be determined
    NOTE: works only when the security is token-based or there is also no password
    """
    connection_file = os.path.basename(ipykernel.get_connection_file())
    kernel_id = connection_file.split('-', 1)[1].split('.')[0]

    for srv in notebookapp.list_running_servers():
        try:
            if srv['token']=='' and not srv['password']:  # No token and no password, ahem...
                req = urllib.request.urlopen(srv['url']+'api/sessions')
            else:
                req = urllib.request.urlopen(srv['url']+'api/sessions?token='+srv['token'])
            sessions = json.load(req)
            for sess in sessions:
                if sess['kernel']['id'] == kernel_id:
                    return os.path.join(srv['notebook_dir'],sess['notebook']['path'])
        except:
            pass  # There may be stale entries in the runtime directory 
    return None


def copy_current_nb(new_name):
    nb = notebook_path()
    if nb:
        new_path = os.path.join(os.path.dirname(nb), new_name+'.ipynb')
        copy2(nb, new_path)
    else:
        print("Current notebook path cannot be determined.")

# %%
df = pd.read_csv('Data/cover_type_engineered.csv')

# %%
df = df.loc[:, [col for col in df if not col.startswith('Cover_Type_')]]
df = df.loc[(df['Cover_Type'] == 1) | (df['Cover_Type'] == 2)]

X = df.drop(columns=['Cover_Type', 'Aspect_Sector'])
y = df['Cover_Type'] - 1

# %%
X = X.loc[:, [col for col in X if not col.startswith('Soil_Type')]]

# %%
timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M")

warnings.filterwarnings("ignore", category=FutureWarning, module="pandas.api.types")

# Assuming X and y are defined
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# Define the base estimator for AdaBoost with a more complex decision tree
base_estimator = DecisionTreeClassifier()  

# Define the AdaBoost classifier using the base estimator
estimator = AdaBoostClassifier(estimator=base_estimator, algorithm='SAMME')

# Define hyperparameters for tuning both AdaBoost and its base estimator
hyperparameters = {
    "estimator__criterion": ["gini", "entropy"],
    "estimator__splitter": ["best", "random"],
    "estimator__max_features": [None, "sqrt", "log2"],
    "estimator__max_depth": [2, 3, 4, 5, 6],  
    "n_estimators": stats.randint(50, 150),
    "learning_rate": stats.uniform(0.01, 0.5),
}


random_search = RandomizedSearchCV(estimator,
                                   param_distributions=hyperparameters,
                                   scoring='accuracy',
                                   return_train_score=True,
                                   n_iter=500,
                                   cv=5,
                                   verbose=10,
                                   n_jobs=-1)

# Fit the RandomizedSearchCV
try:
    random_search.fit(X_train, y_train)  # Assuming X_train and y_train are defined
    print("Best parameters found:", random_search.best_params_)
    print("Best score found:", random_search.best_score_)

    
    # Save results
    results_path = f"./tuning_results/tuning_ada/{timestamp}"
    if not os.path.exists(results_path):
        os.makedirs(results_path)
        
    # Saving cross-validation results
    cv_results = pd.DataFrame(random_search.cv_results_)
    cv_results_file = f"{timestamp}_results.csv"
    cv_results.to_csv(os.path.join(results_path, cv_results_file), index=False)
    
    # Save .ipynb
    copy_current_nb(os.path.join(results_path, 'Evaluation_Notebook'))
    
    # Save Model
    file_name = f"ada_{timestamp}.pkl"
    pickle.dump(random_search, open(os.path.join(results_path, file_name), "wb"))
    
    # random_search = pickle.load(open(file_name, "rb"))
    

except Exception as e:
    print(f"An error occurred during model optimization: {e}")
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV 5/5; 1/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.4029919245860382, n_estimators=74
# [CV 5/5; 1/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.4029919245860382, n_estimators=74;, score=(train=0.894, test=0.779) total time=   0.5s
# [CV 3/5; 3/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.028788334552030108, n_estimators=101
# [CV 3/5; 3/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.028788334552030108, n_estimators=101;, score=(train=0.755, test=0.758) total time=   0.4s
# [CV 3/5; 4/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.3187673216039727, n_estimators=62
# [CV 3/5; 4/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.3187673216039727, n_estimators=62;, score=(train=0.797, test=0.795) total time=   0.4s
# [CV 2/5; 6/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.40499657329919675, n_estimators=110
# [CV 2/5; 6/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.40499657329919675, n_estimators=110;, score=(train=0.822, test=0.774) total time=   0.6s
# [CV 3/5; 7/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.1647679047200043, n_estimators=105
# [CV 3/5; 7/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.1647679047200043, n_estimators=105;, score=(train=0.765, test=0.771) total time=   0.3s
# [CV 4/5; 8/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4925087503165243, n_estimators=148
# [CV 4/5; 8/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4925087503165243, n_estimators=148;, score=(train=0.788, test=0.771) total time=   0.4s
# [CV 3/5; 10/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3453393242458708, n_estimators=149
# [CV 3/5; 10/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3453393242458708, n_estimators=149;, score=(train=0.816, test=0.803) total time=   0.4s
# [CV 5/5; 11/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.14723079671166184, n_estimators=70
# [CV 5/5; 11/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.14723079671166184, n_estimators=70;, score=(train=0.791, test=0.783) total time=   0.2s
# [CV 3/5; 13/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=best, learning_rate=0.20033067390355613, n_estimators=51
# [CV 3/5; 13/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=best, learning_rate=0.20033067390355613, n_estimators=51;, score=(train=0.866, test=0.821) total time=   2.0s
# [CV 1/5; 14/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.36071690163752673, n_estimators=66
# [CV 1/5; 14/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.36071690163752673, n_estimators=66;, score=(train=0.781, test=0.746) total time=   0.3s
# [CV 2/5; 14/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.36071690163752673, n_estimators=66
# [CV 2/5; 14/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.36071690163752673, n_estimators=66;, score=(train=0.773, test=0.766) total time=   0.3s
# [CV 3/5; 14/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.36071690163752673, n_estimators=66
# [CV 3/5; 14/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.36071690163752673, n_estimators=66;, score=(train=0.777, test=0.773) total time=   0.3s
# [CV 4/5; 14/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.36071690163752673, n_estimators=66
# [CV 4/5; 14/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.36071690163752673, n_estimators=66;, score=(train=0.778, test=0.758) total time=   0.3s
# [CV 5/5; 15/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.136731335130289, n_estimators=75
# [CV 5/5; 15/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.136731335130289, n_estimators=75;, score=(train=0.772, test=0.767) total time=   0.3s
# [CV 5/5; 16/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2046330580403934, n_estimators=78
# [CV 5/5; 16/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2046330580403934, n_estimators=78;, score=(train=0.809, test=0.783) total time=   0.4s
# [CV 4/5; 18/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.2867896511092972, n_estimators=55
# [CV 4/5; 18/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.2867896511092972, n_estimators=55;, score=(train=0.781, test=0.771) total time=   0.2s
# [CV 5/5; 19/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.34480412371043556, n_estimators=108
# [CV 5/5; 19/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.34480412371043556, n_estimators=108;, score=(train=0.765, test=0.764) total time=   1.7s
# [CV 1/5; 23/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2873651457452895, n_estimators=80
# [CV 1/5; 23/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2873651457452895, n_estimators=80;, score=(train=0.801, test=0.756) total time=   0.4s
# [CV 4/5; 23/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2873651457452895, n_estimators=80
# [CV 4/5; 23/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2873651457452895, n_estimators=80;, score=(train=0.792, test=0.774) total time=   0.4s
# [CV 5/5; 24/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.1319013779755211, n_estimators=53
# [CV 5/5; 24/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.1319013779755211, n_estimators=53;, score=(train=0.794, test=0.771) total time=   0.1s
# [CV 3/5; 25/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2145320167274281, n_estimators=112
# [CV 3/5; 25/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2145320167274281, n_estimators=112;, score=(train=0.812, test=0.787) total time=   0.7s
# [CV 1/5; 26/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.30806397634024263, n_estimators=107
# [CV 1/5; 26/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.30806397634024263, n_estimators=107;, score=(train=0.811, test=0.769) total time=   0.3s
# [CV 2/5; 26/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.30806397634024263, n_estimators=107
# [CV 2/5; 26/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.30806397634024263, n_estimators=107;, score=(train=0.816, test=0.770) total time=   0.3s
# [CV 5/5; 26/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.30806397634024263, n_estimators=107
# [CV 5/5; 26/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.30806397634024263, n_estimators=107;, score=(train=0.817, test=0.787) total time=   0.3s
# [CV 3/5; 27/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2966302158174049, n_estimators=119
# [CV 3/5; 27/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2966302158174049, n_estimators=119;, score=(train=0.813, test=0.799) total time=   0.3s
# [CV 5/5; 27/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2966302158174049, n_estimators=119
# [CV 5/5; 27/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2966302158174049, n_estimators=119;, score=(train=0.819, test=0.773) total time=   0.3s
# [CV 4/5; 28/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4461743100041531, n_estimators=128
# [CV 4/5; 28/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4461743100041531, n_estimators=128;, score=(train=0.765, test=0.751) total time=   0.3s
# [CV 2/5; 29/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.3895637430732994, n_estimators=145
# [CV 2/5; 29/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.3895637430732994, n_estimators=145;, score=(train=0.874, test=0.810) total time=   0.9s
# [CV 4/5; 30/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.3431301911353717, n_estimators=141
# [CV 4/5; 30/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.3431301911353717, n_estimators=141;, score=(train=0.810, test=0.777) total time=   0.7s
# [CV 4/5; 32/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.21257584733939028, n_estimators=132
# [CV 4/5; 32/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.21257584733939028, n_estimators=132;, score=(train=0.769, test=0.771) total time=   0.4s
# [CV 5/5; 34/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5029234576834851, n_estimators=78
# [CV 5/5; 34/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5029234576834851, n_estimators=78;, score=(train=0.812, test=0.780) total time=   0.2s
# [CV 3/5; 36/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.09402058549499952, n_estimators=117
# [CV 3/5; 36/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.09402058549499952, n_estimators=117;, score=(train=0.789, test=0.810) total time=   0.6s
# [CV 1/5; 38/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.11041794407572673, n_estimators=63
# [CV 1/5; 38/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.11041794407572673, n_estimators=63;, score=(train=0.797, test=0.754) total time=   0.3s
# [CV 1/5; 39/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.17059539915025412, n_estimators=128
# [CV 1/5; 39/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.17059539915025412, n_estimators=128;, score=(train=0.816, test=0.756) total time=   0.7s
# [CV 4/5; 40/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.27462330118109374, n_estimators=84
# [CV 4/5; 40/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.27462330118109374, n_estimators=84;, score=(train=0.817, test=0.787) total time=   0.5s
# [CV 2/5; 42/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.2142703668739529, n_estimators=86
# [CV 2/5; 42/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.2142703668739529, n_estimators=86;, score=(train=0.836, test=0.787) total time=   0.6s
# [CV 5/5; 42/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.2142703668739529, n_estimators=86
# [CV 5/5; 42/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.2142703668739529, n_estimators=86;, score=(train=0.834, test=0.771) total time=   0.7s
# [CV 5/5; 43/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.12210295864239905, n_estimators=109
# [CV 5/5; 43/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.12210295864239905, n_estimators=109;, score=(train=0.752, test=0.758) total time=   0.3s
# [CV 4/5; 44/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.4529401496858808, n_estimators=53
# [CV 4/5; 44/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.4529401496858808, n_estimators=53;, score=(train=0.782, test=0.760) total time=   0.3s
# [CV 2/5; 45/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.023725046058864156, n_estimators=116
# [CV 2/5; 45/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.023725046058864156, n_estimators=116;, score=(train=0.729, test=0.719) total time=   0.3s
# [CV 4/5; 45/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.023725046058864156, n_estimators=116
# [CV 4/5; 45/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.023725046058864156, n_estimators=116;, score=(train=0.750, test=0.742) total time=   0.3s
# [CV 2/5; 47/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=best, learning_rate=0.4265323658517138, n_estimators=105
# [CV 2/5; 47/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=best, learning_rate=0.4265323658517138, n_estimators=105;, score=(train=0.858, test=0.792) total time=   4.4s
# [CV 5/5; 51/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4287045181395124, n_estimators=84
# [CV 5/5; 51/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4287045181395124, n_estimators=84;, score=(train=0.800, test=0.779) total time=   0.3s
# [CV 3/5; 53/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.37663900876330586, n_estimators=77
# [CV 3/5; 53/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.37663900876330586, n_estimators=77;, score=(train=0.799, test=0.781) total time=   0.4s
# [CV 4/5; 54/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.15121001253735394, n_estimators=125
# [CV 4/5; 54/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.15121001253735394, n_estimators=125;, score=(train=0.767, test=0.768) total time=   0.4s
# [CV 5/5; 55/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.13449121982841644, n_estimators=131
# [CV 5/5; 55/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.13449121982841644, n_estimators=131;, score=(train=0.864, test=0.780) total time=   0.9s
# [CV 1/5; 57/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.335105796991263, n_estimators=81
# [CV 1/5; 57/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.335105796991263, n_estimators=81;, score=(train=0.824, test=0.773) total time=   0.2s
# [CV 4/5; 57/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.335105796991263, n_estimators=81
# [CV 4/5; 57/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.335105796991263, n_estimators=81;, score=(train=0.815, test=0.780) total time=   0.2s
# [CV 4/5; 58/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.09272777158563793, n_estimators=61
# [CV 4/5; 58/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.09272777158563793, n_estimators=61;, score=(train=0.749, test=0.734) total time=   0.1s
# [CV 2/5; 59/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.20025702844840865, n_estimators=101
# [CV 2/5; 59/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.20025702844840865, n_estimators=101;, score=(train=0.808, test=0.776) total time=   0.5s
# [CV 5/5; 59/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.20025702844840865, n_estimators=101
# [CV 5/5; 59/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.20025702844840865, n_estimators=101;, score=(train=0.812, test=0.768) total time=   0.5s
# [CV 4/5; 60/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.24497796478614575, n_estimators=93
# [CV 4/5; 60/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.24497796478614575, n_estimators=93;, score=(train=0.782, test=0.781) total time=   0.3s
# [CV 5/5; 61/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.34816042769926686, n_estimators=65
# [CV 5/5; 61/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.34816042769926686, n_estimators=65;, score=(train=0.772, test=0.776) total time=   0.2s
# [CV 3/5; 63/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.3823466309150362, n_estimators=76
# [CV 3/5; 63/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.3823466309150362, n_estimators=76;, score=(train=0.790, test=0.793) total time=   0.3s
# [CV 4/5; 64/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.26208711419285247, n_estimators=139
# [CV 4/5; 64/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.26208711419285247, n_estimators=139;, score=(train=0.825, test=0.786) total time=   0.8s
# [CV 2/5; 66/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.34073589076125016, n_estimators=143
# [CV 2/5; 66/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.34073589076125016, n_estimators=143;, score=(train=0.834, test=0.783) total time=   0.8s
# [CV 2/5; 68/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.01793011586345599, n_estimators=144
# [CV 2/5; 68/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.01793011586345599, n_estimators=144;, score=(train=0.760, test=0.758) total time=   0.5s
# [CV 1/5; 70/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.20334257941788958, n_estimators=70
# [CV 1/5; 70/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.20334257941788958, n_estimators=70;, score=(train=0.764, test=0.746) total time=   0.2s
# [CV 1/5; 71/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.015821664077456436, n_estimators=77
# [CV 1/5; 71/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.015821664077456436, n_estimators=77;, score=(train=0.800, test=0.762) total time=   2.2s
# [CV 3/5; 75/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.13336495074320348, n_estimators=131
# [CV 3/5; 75/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.13336495074320348, n_estimators=131;, score=(train=0.788, test=0.796) total time=   0.7s
# [CV 5/5; 77/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.12827054900494722, n_estimators=60
# [CV 5/5; 77/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.12827054900494722, n_estimators=60;, score=(train=0.842, test=0.776) total time=   4.3s
# [CV 1/5; 81/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.15597385851539286, n_estimators=149
# [CV 1/5; 81/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.15597385851539286, n_estimators=149;, score=(train=0.774, test=0.746) total time=   1.7s
# [CV 3/5; 83/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4776407279990405, n_estimators=89
# [CV 3/5; 83/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4776407279990405, n_estimators=89;, score=(train=0.833, test=0.774) total time=   2.0s
# [CV 1/5; 85/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.3582917388653638, n_estimators=146
# [CV 1/5; 85/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.3582917388653638, n_estimators=146;, score=(train=0.886, test=0.785) total time=   9.2s
# [CV 1/5; 91/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.3880793386115008, n_estimators=119
# [CV 1/5; 91/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.3880793386115008, n_estimators=119;, score=(train=0.781, test=0.747) total time=   1.1s
# [CV 4/5; 92/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.20338447664683107, n_estimators=58
# [CV 4/5; 92/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.20338447664683107, n_estimators=58;, score=(train=0.768, test=0.761) total time=   0.2s
# [CV 4/5; 93/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.2183000138217217, n_estimators=73
# [CV 4/5; 93/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.2183000138217217, n_estimators=73;, score=(train=0.811, test=0.787) total time=   0.7s
# [CV 4/5; 95/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.07374488471108274, n_estimators=129
# [CV 4/5; 95/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.07374488471108274, n_estimators=129;, score=(train=0.801, test=0.784) total time=   1.6s
# [CV 2/5; 97/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.44868593351494473, n_estimators=105
# [CV 2/5; 97/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.44868593351494473, n_estimators=105;, score=(train=0.801, test=0.760) total time=   0.4s
# [CV 4/5; 98/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.12421690163159853, n_estimators=125
# [CV 4/5; 98/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.12421690163159853, n_estimators=125;, score=(train=0.759, test=0.763) total time=   0.9s
# [CV 4/5; 100/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.48173341789178326, n_estimators=82
# [CV 4/5; 100/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.48173341789178326, n_estimators=82;, score=(train=0.791, test=0.767) total time=   0.2s
# [CV 2/5; 102/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.45222025494941176, n_estimators=102
# [CV 2/5; 102/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.45222025494941176, n_estimators=102;, score=(train=0.802, test=0.764) total time=   0.5s
# [CV 4/5; 103/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.25509227432752685, n_estimators=99
# [CV 4/5; 103/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.25509227432752685, n_estimators=99;, score=(train=0.766, test=0.760) total time=   0.2s
# [CV 5/5; 104/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.05472089010365649, n_estimators=72
# [CV 5/5; 104/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.05472089010365649, n_estimators=72;, score=(train=0.754, test=0.751) total time=   0.3s
# [CV 3/5; 106/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.25261791442422, n_estimators=125
# [CV 3/5; 106/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.25261791442422, n_estimators=125;, score=(train=0.787, test=0.783) total time=   0.3s
# [CV 1/5; 108/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=best, learning_rate=0.06834510104592777, n_estimators=74
# [CV 1/5; 108/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=best, learning_rate=0.06834510104592777, n_estimators=74;, score=(train=0.877, test=0.786) total time=   3.0s
# [CV 2/5; 111/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.04608239984633277, n_estimators=131
# [CV 2/5; 111/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.04608239984633277, n_estimators=131;, score=(train=0.741, test=0.726) total time=   0.3s
# [CV 5/5; 112/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.21697438041675243, n_estimators=117
# [CV 5/5; 112/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.21697438041675243, n_estimators=117;, score=(train=0.777, test=0.771) total time=   0.4s
# [CV 3/5; 114/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.02696698393669577, n_estimators=144
# [CV 3/5; 114/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.02696698393669577, n_estimators=144;, score=(train=0.831, test=0.809) total time=   1.5s
# [CV 1/5; 115/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.1873215775700131, n_estimators=84
# [CV 1/5; 115/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.1873215775700131, n_estimators=84;, score=(train=0.805, test=0.753) total time=   0.6s
# [CV 2/5; 115/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.1873215775700131, n_estimators=84
# [CV 2/5; 115/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.1873215775700131, n_estimators=84;, score=(train=0.817, test=0.777) total time=   0.5s
# [CV 5/5; 115/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.1873215775700131, n_estimators=84
# [CV 5/5; 115/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.1873215775700131, n_estimators=84;, score=(train=0.804, test=0.781) total time=   0.6s
# [CV 3/5; 116/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4427653514772909, n_estimators=127
# [CV 3/5; 116/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4427653514772909, n_estimators=127;, score=(train=0.773, test=0.777) total time=   0.4s
# [CV 1/5; 117/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2449271221497592, n_estimators=104
# [CV 1/5; 117/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2449271221497592, n_estimators=104;, score=(train=0.846, test=0.782) total time=   1.9s
# [CV 4/5; 117/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2449271221497592, n_estimators=104
# [CV 4/5; 117/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2449271221497592, n_estimators=104;, score=(train=0.832, test=0.792) total time=   1.9s
# [CV 2/5; 120/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.3867007212494613, n_estimators=51
# [CV 2/5; 120/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.3867007212494613, n_estimators=51;, score=(train=0.805, test=0.757) total time=   0.4s
# [CV 4/5; 120/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.3867007212494613, n_estimators=51
# [CV 4/5; 120/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.3867007212494613, n_estimators=51;, score=(train=0.790, test=0.786) total time=   0.2s
# [CV 4/5; 121/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1451284098828426, n_estimators=55
# [CV 4/5; 121/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1451284098828426, n_estimators=55;, score=(train=0.765, test=0.751) total time=   1.9s
# [CV 1/5; 124/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.23777349658797664, n_estimators=57
# [CV 1/5; 124/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.23777349658797664, n_estimators=57;, score=(train=0.847, test=0.773) total time=   3.2s
# [CV 2/5; 128/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2917970050940579, n_estimators=111
# [CV 2/5; 128/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2917970050940579, n_estimators=111;, score=(train=0.837, test=0.779) total time=   0.5s
# [CV 1/5; 129/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.1577121624137804, n_estimators=103
# [CV 1/5; 129/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.1577121624137804, n_estimators=103;, score=(train=0.865, test=0.773) total time=   0.9s
# [CV 4/5; 129/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.1577121624137804, n_estimators=103
# [CV 4/5; 129/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.1577121624137804, n_estimators=103;, score=(train=0.853, test=0.800) total time=   0.9s
# [CV 1/5; 131/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4553257794458017, n_estimators=102
# [CV 1/5; 131/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4553257794458017, n_estimators=102;, score=(train=0.808, test=0.738) total time=   0.6s
# [CV 5/5; 131/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4553257794458017, n_estimators=102
# [CV 5/5; 131/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4553257794458017, n_estimators=102;, score=(train=0.803, test=0.776) total time=   0.5s
# [CV 3/5; 134/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.32936269949329744, n_estimators=61
# [CV 3/5; 134/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.32936269949329744, n_estimators=61;, score=(train=0.828, test=0.802) total time=   0.5s
# [CV 1/5; 136/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.12798117547107618, n_estimators=61
# [CV 1/5; 136/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.12798117547107618, n_estimators=61;, score=(train=0.784, test=0.756) total time=   0.4s
# [CV 2/5; 137/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.112439118527194, n_estimators=98
# [CV 2/5; 137/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.112439118527194, n_estimators=98;, score=(train=0.780, test=0.760) total time=   0.5s
# [CV 1/5; 139/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1919639410785811, n_estimators=67
# [CV 1/5; 139/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1919639410785811, n_estimators=67;, score=(train=0.820, test=0.775) total time=   6.4s
# [CV 5/5; 142/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.04067250827844559, n_estimators=95
# [CV 5/5; 142/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.04067250827844559, n_estimators=95;, score=(train=0.759, test=0.758) total time=   0.5s
# [CV 3/5; 144/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.22125752004012977, n_estimators=126
# [CV 3/5; 144/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.22125752004012977, n_estimators=126;, score=(train=0.791, test=0.781) total time=   0.7s
# [CV 1/5; 146/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.10976434985291199, n_estimators=67
# [CV 1/5; 146/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.10976434985291199, n_estimators=67;, score=(train=0.779, test=0.740) total time=   0.2s
# [CV 2/5; 147/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.35275684487231646, n_estimators=111
# [CV 2/5; 147/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.35275684487231646, n_estimators=111;, score=(train=0.795, test=0.757) total time=   0.3s
# [CV 1/5; 149/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.11416703955821082, n_estimators=60
# [CV 1/5; 149/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.11416703955821082, n_estimators=60;, score=(train=0.803, test=0.749) total time=   0.4s
# [CV 4/5; 149/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.11416703955821082, n_estimators=60
# [CV 4/5; 149/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.11416703955821082, n_estimators=60;, score=(train=0.794, test=0.786) total time=   0.5s
# [CV 3/5; 150/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.40499868513149995, n_estimators=71
# [CV 3/5; 150/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.40499868513149995, n_estimators=71;, score=(train=0.884, test=0.803) total time=   1.1s
# [CV 5/5; 150/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.40499868513149995, n_estimators=71
# [CV 5/5; 150/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.40499868513149995, n_estimators=71;, score=(train=0.903, test=0.790) total time=   0.6s
# [CV 5/5; 151/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.1768701217379799, n_estimators=140
# [CV 5/5; 151/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.1768701217379799, n_estimators=140;, score=(train=0.804, test=0.802) total time=   1.2s
# [CV 2/5; 152/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.25156754484389154, n_estimators=57
# [CV 2/5; 152/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.25156754484389154, n_estimators=57;, score=(train=0.786, test=0.776) total time=   0.4s
# [CV 4/5; 152/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.25156754484389154, n_estimators=57
# [CV 4/5; 152/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=random, learning_rate=0.25156754484389154, n_estimators=57;, score=(train=0.779, test=0.761) total time=   0.4s
# [CV 3/5; 153/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.38584241049141194, n_estimators=91
# [CV 3/5; 153/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.38584241049141194, n_estimators=91;, score=(train=0.844, test=0.800) total time=   0.4s
# [CV 5/5; 153/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.38584241049141194, n_estimators=91
# [CV 5/5; 153/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.38584241049141194, n_estimators=91;, score=(train=0.853, test=0.784) total time=   1.0s
# [CV 3/5; 154/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.3990067306565449, n_estimators=125
# [CV 3/5; 154/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.3990067306565449, n_estimators=125;, score=(train=0.857, test=0.828) total time=   7.0s
# [CV 4/5; 160/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.4584286730057907, n_estimators=99
# [CV 4/5; 160/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.4584286730057907, n_estimators=99;, score=(train=0.810, test=0.796) total time=   0.4s
# [CV 5/5; 161/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.07678486188937649, n_estimators=80
# [CV 5/5; 161/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.07678486188937649, n_estimators=80;, score=(train=0.786, test=0.777) total time=   0.4s
# [CV 5/5; 162/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5035426908441155, n_estimators=82
# ...
# [CV 4/5; 197/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.014752717470781598, n_estimators=59;, score=(train=0.787, test=0.766) total time=   0.5s
# [CV 3/5; 199/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.13474110229475644, n_estimators=69
# [CV 3/5; 199/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.13474110229475644, n_estimators=69;, score=(train=0.762, test=0.758) total time=   1.6s
# [CV 1/5; 201/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.45988438527472925, n_estimators=145
# [CV 1/5; 201/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.45988438527472925, n_estimators=145;, score=(train=0.799, test=0.749) total time=   4.2s
# [CV 2/5; 206/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.509970412945556, n_estimators=81
# [CV 2/5; 206/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.509970412945556, n_estimators=81;, score=(train=0.790, test=0.768) total time=   0.4s
# [CV 3/5; 207/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.20626538693948276, n_estimators=124
# [CV 3/5; 207/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.20626538693948276, n_estimators=124;, score=(train=0.823, test=0.815) total time=   1.0s
# [CV 3/5; 209/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.35126649067069243, n_estimators=52
# [CV 3/5; 209/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.35126649067069243, n_estimators=52;, score=(train=0.883, test=0.806) total time=   0.5s
# [CV 4/5; 210/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.1890035937186788, n_estimators=83
# [CV 4/5; 210/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.1890035937186788, n_estimators=83;, score=(train=0.794, test=0.779) total time=   0.3s
# [CV 1/5; 212/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3189489520175696, n_estimators=75
# [CV 1/5; 212/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3189489520175696, n_estimators=75;, score=(train=0.803, test=0.764) total time=   0.3s
# [CV 3/5; 213/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.3676265319651135, n_estimators=115
# [CV 3/5; 213/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.3676265319651135, n_estimators=115;, score=(train=0.866, test=0.818) total time=   1.0s
# [CV 5/5; 215/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.019740646788637344, n_estimators=86
# [CV 5/5; 215/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.019740646788637344, n_estimators=86;, score=(train=0.782, test=0.773) total time=   0.6s
# [CV 2/5; 217/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.43330399422158705, n_estimators=142
# [CV 2/5; 217/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.43330399422158705, n_estimators=142;, score=(train=0.822, test=0.771) total time=   0.8s
# [CV 5/5; 218/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.1931397012604042, n_estimators=111
# [CV 5/5; 218/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.1931397012604042, n_estimators=111;, score=(train=0.820, test=0.777) total time=   0.4s
# [CV 3/5; 220/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.2939276823242689, n_estimators=77
# [CV 3/5; 220/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.2939276823242689, n_estimators=77;, score=(train=0.822, test=0.802) total time=   3.7s
# [CV 3/5; 225/500] START estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.35461136953167594, n_estimators=73
# [CV 3/5; 225/500] END estimator__criterion=gini, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.35461136953167594, n_estimators=73;, score=(train=0.808, test=0.780) total time=   0.3s
# [CV 1/5; 227/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.4498556943265372, n_estimators=137
# [CV 1/5; 227/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.4498556943265372, n_estimators=137;, score=(train=0.781, test=0.743) total time=   0.6s
# [CV 4/5; 228/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.3518775739471057, n_estimators=131
# [CV 4/5; 228/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=random, learning_rate=0.3518775739471057, n_estimators=131;, score=(train=0.840, test=0.802) total time=   1.0s
# [CV 2/5; 231/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.24020595657732347, n_estimators=129
# [CV 2/5; 231/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.24020595657732347, n_estimators=129;, score=(train=0.855, test=0.781) total time=   0.9s
# [CV 5/5; 231/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.24020595657732347, n_estimators=129
# [CV 5/5; 231/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.24020595657732347, n_estimators=129;, score=(train=0.850, test=0.774) total time=   0.9s
# [CV 3/5; 234/500] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.20354914316485606, n_estimators=100
# [CV 3/5; 234/500] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.20354914316485606, n_estimators=100;, score=(train=0.810, test=0.797) total time=   1.1s
# [CV 2/5; 235/500] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.473698332084819, n_estimators=102
# [CV 2/5; 235/500] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.473698332084819, n_estimators=102;, score=(train=0.827, test=0.763) total time=   0.6s
# [CV 3/5; 236/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.509223710529734, n_estimators=134
# [CV 3/5; 236/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.509223710529734, n_estimators=134;, score=(train=0.792, test=0.797) total time=   0.8s
# [CV 2/5; 238/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.04844548133810855, n_estimators=140
# [CV 2/5; 238/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.04844548133810855, n_estimators=140;, score=(train=0.817, test=0.767) total time=   1.0s
# [CV 4/5; 239/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.18124693622863208, n_estimators=96
# [CV 4/5; 239/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.18124693622863208, n_estimators=96;, score=(train=0.783, test=0.766) total time=   2.2s
# [CV 4/5; 242/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2744922172517388, n_estimators=98
# [CV 4/5; 242/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2744922172517388, n_estimators=98;, score=(train=0.787, test=0.776) total time=   0.6s
# [CV 3/5; 244/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.42438370131354397, n_estimators=61
# [CV 3/5; 244/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.42438370131354397, n_estimators=61;, score=(train=0.774, test=0.758) total time=   0.3s
# [CV 3/5; 245/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.43674506746027913, n_estimators=136
# [CV 3/5; 245/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.43674506746027913, n_estimators=136;, score=(train=0.907, test=0.810) total time=   1.1s
# [CV 1/5; 248/500] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.4833137243952962, n_estimators=102
# [CV 1/5; 248/500] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.4833137243952962, n_estimators=102;, score=(train=0.796, test=0.750) total time=   3.3s
# [CV 4/5; 251/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.10965454424447006, n_estimators=123
# [CV 4/5; 251/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.10965454424447006, n_estimators=123;, score=(train=0.814, test=0.773) total time=   5.3s
# [CV 1/5; 256/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.13766658644719176, n_estimators=137
# [CV 1/5; 256/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.13766658644719176, n_estimators=137;, score=(train=0.770, test=0.750) total time=   0.4s
# [CV 4/5; 256/500] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.13766658644719176, n_estimators=137
# [CV 4/5; 256/500] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.13766658644719176, n_estimators=137;, score=(train=0.770, test=0.764) total time=   0.4s
# [CV 2/5; 257/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.03699342736850791, n_estimators=92
# [CV 2/5; 257/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.03699342736850791, n_estimators=92;, score=(train=0.757, test=0.760) total time=   0.5s
# [CV 5/5; 257/500] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.03699342736850791, n_estimators=92
# [CV 5/5; 257/500] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.03699342736850791, n_estimators=92;, score=(train=0.757, test=0.755) total time=   0.5s
# [CV 3/5; 258/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.21294278520866072, n_estimators=149
# [CV 3/5; 258/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.21294278520866072, n_estimators=149;, score=(train=0.825, test=0.805) total time=   6.2s
# [CV 1/5; 265/500] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1419534677827699, n_estimators=136
# [CV 1/5; 265/500] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1419534677827699, n_estimators=136;, score=(train=0.846, test=0.782) total time=   4.8s
# [CV 3/5; 268/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4883386821630101, n_estimators=142
# [CV 3/5; 268/500] END estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4883386821630101, n_estimators=142;, score=(train=0.935, test=0.797) total time=   1.4s
# [CV 2/5; 271/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.37913721511798265, n_estimators=140
# [CV 2/5; 271/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.37913721511798265, n_estimators=140;, score=(train=0.769, test=0.745) total time=   0.4s
# [CV 5/5; 271/500] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.37913721511798265, n_estimators=140
# [CV 5/5; 271/500] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.37913721511798265, n_estimators=140;, score=(train=0.767, test=0.760) total time=   0.4s
# [CV 3/5; 272/500] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.056310234119699425, n_estimators=116
# [CV 3/5; 272/500] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.056310234119699425, n_estimators=116;, score=(train=0.799, test=0.803) total time=   5.3s
# [CV 1/5; 277/500] START estimator__criterion=entropy, estimator__max_depth=6, estimator__max_features=None, estimator__splitter=best, learning_rate=0.09624104928013992, n_estimators=119

# %%
cv_results.head()

# %%
results_path = f"./tuning_results/tuning_ada/{timestamp}/Assets"
if not os.path.exists(results_path):
    os.makedirs(results_path)

# %% [markdown]
# # CV Evaluation

# %%
cv_results.columns

# %%
cv_results.sort_values(by='rank_test_score', ascending=True).head(5)

# %%
sorted_cv = cv_results.sort_values(by='rank_test_score', ascending=True)

# %% [markdown]
# # Train vs Test Comparison

# %%
plt.figure(figsize=(16, 6))    

plt.plot(sorted_cv['rank_test_score'], sorted_cv['mean_train_score'], label="Train Score")
plt.plot(sorted_cv['rank_test_score'], sorted_cv['mean_test_score'], label="Validation Score")

plt.grid()
plt.xlabel('Sorted Validation Rank')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy by Final Rank')
plt.legend(loc='best')

filename = "test_train_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(10, 3))
fig.suptitle('Test Accuracy by Rank')

ax = fig.add_subplot(111)

plt.boxplot(sorted_cv.iloc[:10, :][['split0_test_score', 'split1_test_score', 'split2_test_score',
   'split3_test_score', 'split4_test_score']].T)
ax.set_xticklabels(range(1, 11))
ax.set_xlabel("Rank")
ax.set_ylabel("Accuracy")

filename = "test_accuracy_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(10, 3))
fig.suptitle('Train Accuracy by Rank')

ax = fig.add_subplot(111)

plt.boxplot(sorted_cv.iloc[:10, :][['split0_train_score', 'split1_train_score', 'split2_train_score',
   'split3_train_score', 'split4_train_score']].T)
ax.set_xticklabels(range(1, 11))
ax.set_xlabel("Rank")
ax.set_ylabel("Accuracy")

filename = "train_accuracy_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
max_params = cv_results.loc[cv_results['rank_test_score'] == 1]
best_params = max_params.params.values[0]

# %%
print(f"Mean Train set, Accuracy = {max_params['mean_train_score'].values[0]:.2f}")
print(f"Mean Test  set, Accuracy = {max_params['mean_test_score'].values[0]:.2f}")

# %%
random_search = pickle.load(open(os.path.join(f'./tuning_results/tuning_ada/{timestamp}/', file_name), "rb"))
model = random_search.best_estimator_

#model = ADAClassifier(**best_params)
#model.fit(X_train, y_train)

y_train_prediction = model.predict(X_train)
y_test_prediction = model.predict(X_test)

# %%
print(f"Train set, Accuracy = {accuracy_score(y_train, y_train_prediction):.2f}")
print(f"Test set, Accuracy = {accuracy_score(y_test, y_test_prediction):.2f}")

# %%
ind = np.argpartition(model.feature_importances_, -20)[-20:]

features = X.columns[ind]
importance = model.feature_importances_[ind]

fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(ind)), importance, align='center')
plt.yticks(range(len(ind)), features)
plt.title('Feature Importance ADA')
plt.grid()

filename = "feature_importance.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %%
# TEST
for col in ['param_estimator__max_depth', 'param_n_estimators', 'param_learning_rate']:
    
    plt.figure(figsize=(16, 6))    

    m, b = np.polyfit(list(sorted_cv['mean_test_score'].values), list(sorted_cv[col].values), 1)
    plt.plot(sorted_cv['mean_test_score'], m * sorted_cv['mean_test_score'] + b, c='r', label="Regression Line")
    plt.scatter(sorted_cv['mean_test_score'], sorted_cv[col], label=f"{col} Values")
    
    plt.grid()
    plt.xlabel('Mean Validation Score')
    plt.ylabel('Parameter Value')
    plt.title(col)
    plt.legend(loc='best')

    
    filename = f"{col}_by_rank.png"
    plt.savefig(os.path.join(results_path, filename))
                  
    plt.show()

# %% [markdown]
# # Hyperparameter Evaluation

# %%
def plot_parameters(x_values, title):
    
    fig, ax1 = plt.subplots(figsize=(16, 6))
    ax2 = ax1.twinx()

    ax1.scatter(x_values, cv_results['mean_test_score'], label='mean_test_score', c='b')
    #ax2.scatter(x_values, cv_results['std_test_score'], label='std_test_score', c='r')

    m, b = np.polyfit(list(x_values.values), list(cv_results['mean_test_score'].values), 1)
    ax1.plot(x_values, m * x_values + b, c='b')

    m, b = np.polyfit(list(x_values.values), list(cv_results['std_test_score'].values), 1)
    ax2.plot(x_values, m * x_values + b, c='r', label='std_test_score')
    
    ax1.set_title(title)
    ax1.set_xlabel('Parameter Value')
    ax1.set_ylabel('Mean Test Score')
    ax2.set_ylabel('Standard Deviation of Test Score')
    ax1.grid(True)
    
    
    # Combine the legends from both axes
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax2.legend(lines + lines2, labels + labels2, loc='upper right')

    filename = f"{title}_test_score.png"
    plt.savefig(os.path.join(results_path, filename))
            
    plt.show()

# %%
for param in ['param_estimator__max_depth', 'param_n_estimators', 'param_learning_rate']:

    x_values = cv_results[param]
    plot_parameters(x_values, param)

# %% [markdown]
# # Plotting Evaluation Metrics (Precision, Recall, F1-Score, AUC-ROC):

# %%
# For multiclass classification, you need to binarize the labels
y_true_bin = label_binarize(y_test, classes=np.unique(y_test))
y_score_bin = label_binarize(y_test_prediction, classes=np.unique(y_test_prediction))

auc_roc = roc_auc_score(y_true_bin, y_score_bin, average='macro')

# Plot Precision-Recall curve for each class
precision = dict()
recall = dict()

plt.figure(figsize=(16, 6))    
for i in range(7):
    precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], y_score_bin[:, i])
    plt.plot(recall[i], precision[i], label='Covertype {}'.format(i + 1))

plt.grid()
plt.xlabel('Recall')
plt.ylabel('True Positive Rate / Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')

filename = "precision_recall.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()


# Plot AUC-ROC curve for each class
fpr = dict()
tpr = dict()

plt.figure(figsize=(16, 6))    
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score_bin[:, i])
    plt.plot(fpr[i], tpr[i], label='Covertype {}'.format(i + 1))

plt.grid()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate / Precision')
plt.title('ROC Curve')
plt.legend(loc='best')
            
filename = "roc_curve.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# # Partial Dependence

# %%
# potentially iterate over features (and relation ie 0 to 1)

# %%
features, feature_names = [(0,)], [f"Features #{i}" for i in range(X.shape[1])]
deciles = {0: np.linspace(0, 1, num=5)}

pd_results = partial_dependence(
    model, X, features=1, kind="average", grid_resolution=5)

display = PartialDependenceDisplay(
    [pd_results], features=features, feature_names=feature_names,
    target_idx=0, deciles=deciles
)
display.plot(pdp_lim={1: (-1.38, 0.66)})

plt.grid()
plt.xlabel('Feature Value')
plt.ylabel('Partial Dependence') 
plt.title('Partial Dependence')

filename = "partial_dependence.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
class_names = np.unique(y)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        model,
        X_test,
        y_test,
        display_labels=class_names + 1,
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    png_name = title.lower().replace(" ", "_")
    filename = f"{png_name}.png"
    plt.savefig(os.path.join(results_path, filename))

plt.show()

# %% [markdown]
# # Shap Values

# %%
explainer = shap.TreeExplainer(model)
explanation = explainer.shap_values(X_test, check_additivity=False)

# %%
shap.summary_plot(explanation, X_test, plot_type="bar", show=False)

filename = f"shap_summary.png"
plt.savefig(os.path.join(results_path, filename))
plt.close()

# %% [markdown]
# SHAP values show how each feature affects each final prediction, the significance of each feature compared to others, and the model's reliance on the interaction between features.

# %% [markdown]
# # KAGGLE Prediction

# %%
test_processed = pd.read_csv('Data/test_engineered.csv')

# %%
test_processed.head()

# %%
test_processed = test_processed.loc[:, [col for col in test_processed if not col.startswith('Cover_Type_')]]
X_kaggle = test_processed.drop(columns=['Aspect_Sector'])
y_kaggle = model.predict(X_kaggle) + 1

# %%
pd.read_csv("Data/Kaggle/full_submission.csv").head()

# %%
test_processed['Cover_Type'] = y_kaggle

# %%
kaggle_submission = test_processed.loc[:, ['Id', 'Cover_Type']]

# %%
kaggle_submission.Cover_Type.value_counts()

# %%
kaggle_submission.to_csv(f'Data/kaggle_submission_{timestamp}.csv', index=False)

# %%
pd.read_csv(f'Data/kaggle_submission_{timestamp}.csv')
