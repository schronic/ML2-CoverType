# %%
import datetime
import os
import pickle
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
from sklearn.ensemble import AdaBoostClassifier
from sklearn.inspection import PartialDependenceDisplay, partial_dependence
from sklearn.metrics import (ConfusionMatrixDisplay, accuracy_score, precision_recall_curve, roc_auc_score, roc_curve)
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.tree import DecisionTreeClassifier

import shap

# %config InlineBackend.figure_format = 'retina'

# %%
from notebook import notebookapp
import urllib
import json
import ipykernel
from shutil import copy2

def notebook_path():
    """Returns the absolute path of the Notebook or None if it cannot be determined
    NOTE: works only when the security is token-based or there is also no password
    """
    connection_file = os.path.basename(ipykernel.get_connection_file())
    kernel_id = connection_file.split('-', 1)[1].split('.')[0]

    for srv in notebookapp.list_running_servers():
        try:
            if srv['token']=='' and not srv['password']:  # No token and no password, ahem...
                req = urllib.request.urlopen(srv['url']+'api/sessions')
            else:
                req = urllib.request.urlopen(srv['url']+'api/sessions?token='+srv['token'])
            sessions = json.load(req)
            for sess in sessions:
                if sess['kernel']['id'] == kernel_id:
                    return os.path.join(srv['notebook_dir'],sess['notebook']['path'])
        except:
            pass  # There may be stale entries in the runtime directory 
    return None


def copy_current_nb(new_name):
    nb = notebook_path()
    if nb:
        new_path = os.path.join(os.path.dirname(nb), new_name+'.ipynb')
        copy2(nb, new_path)
    else:
        print("Current notebook path cannot be determined.")

# %%
df = pd.read_csv('Data/cover_type_engineered.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv('Data/cover_type_engineered.csv')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data/cover_type_engineered.csv'

# %%
df = df.loc[:, [col for col in df if not col.startswith('Cover_Type_')]]
X = df.drop(columns=['Cover_Type', 'Aspect_Sector'])
y = df['Cover_Type'] - 1

# %%
timestamp = '202402281047' # datetime.datetime.now().strftime("%Y%m%d%H%M")

# %%
warnings.filterwarnings("ignore", category=FutureWarning, module="pandas.api.types")

# Assuming X and y are defined
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

# Define the base estimator for AdaBoost with a more complex decision tree
base_estimator = DecisionTreeClassifier()  

# Define the AdaBoost classifier using the base estimator
estimator = AdaBoostClassifier(estimator=base_estimator, algorithm='SAMME')

# Define hyperparameters for tuning both AdaBoost and its base estimator
hyperparameters = {
    "estimator__criterion": ["gini", "entropy"],
    "estimator__splitter": ["best", "random"],
    "estimator__max_features": [None, "sqrt", "log2"],
    "estimator__max_depth": [None, 2, 3, 4, 5, 7, 10, 12, 15],  
    "n_estimators": stats.randint(50, 500),
    "learning_rate": stats.uniform(0.01, 1.0),
}


random_search = RandomizedSearchCV(estimator,
                                   param_distributions=hyperparameters,
                                   scoring='accuracy',
                                   return_train_score=True,
                                   n_iter=100,
                                   cv=5,
                                   verbose=10,
                                   n_jobs=-1)

# Fit the RandomizedSearchCV
try:
    random_search.fit(X_train, y_train)  # Assuming X_train and y_train are defined
    print("Best parameters found:", random_search.best_params_)
    print("Best score found:", random_search.best_score_)

    
    # Save results
    results_path = f"./tuning_results/tuning_ada/{timestamp}"
    if not os.path.exists(results_path):
        os.makedirs(results_path)
        
    # Saving cross-validation results
    cv_results = pd.DataFrame(random_search.cv_results_)
    cv_results_file = f"{timestamp}_results.csv"
    cv_results.to_csv(os.path.join(results_path, cv_results_file), index=False)
    
    # Save .ipynb
    copy_current_nb(os.path.join(results_path, 'Evaluation_Notebook'))
    
    # Save Model
    file_name = f"ada_{timestamp}.pkl"
    pickle.dump(random_search, open(os.path.join(results_path, file_name), "wb"))
    
    # random_search = pickle.load(open(file_name, "rb"))
    

except Exception as e:
    print(f"An error occurred during model optimization: {e}")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 2/5; 1/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.06848176931756665, n_estimators=492
# [CV 2/5; 1/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.06848176931756665, n_estimators=492;, score=(train=0.734, test=0.730) total time=   6.2s
# [CV 3/5; 5/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7585701620446833, n_estimators=413
# [CV 3/5; 5/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7585701620446833, n_estimators=413;, score=(train=0.826, test=0.746) total time=  11.6s
# [CV 1/5; 8/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.9170850505277642, n_estimators=248
# [CV 1/5; 8/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.9170850505277642, n_estimators=248;, score=(train=0.663, test=0.624) total time=   1.8s
# [CV 4/5; 8/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.9170850505277642, n_estimators=248
# [CV 4/5; 8/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.9170850505277642, n_estimators=248;, score=(train=0.640, test=0.637) total time=   1.8s
# [CV 4/5; 9/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.13131020761872325, n_estimators=496
# [CV 4/5; 9/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.13131020761872325, n_estimators=496;, score=(train=0.745, test=0.711) total time=  40.8s
# [CV 2/5; 13/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1416131724991172, n_estimators=201
# [CV 2/5; 13/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1416131724991172, n_estimators=201;, score=(train=1.000, test=0.885) total time= 1.2min
# [CV 4/5; 13/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1416131724991172, n_estimators=201
# [CV 4/5; 13/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1416131724991172, n_estimators=201;, score=(train=1.000, test=0.879) total time= 1.3min
# [CV 3/5; 14/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.09895156681786953, n_estimators=370
# [CV 3/5; 14/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.09895156681786953, n_estimators=370;, score=(train=0.718, test=0.706) total time=  46.8s
# [CV 2/5; 18/100] START estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.16746064518198533, n_estimators=398
# [CV 2/5; 18/100] END estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.16746064518198533, n_estimators=398;, score=(train=0.906, test=0.800) total time=   4.3s
# [CV 1/5; 19/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.7999724436733792, n_estimators=343
# [CV 1/5; 19/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.7999724436733792, n_estimators=343;, score=(train=0.840, test=0.739) total time=  10.4s
# [CV 1/5; 21/100] START estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18356991983307336, n_estimators=267
# [CV 1/5; 21/100] END estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18356991983307336, n_estimators=267;, score=(train=1.000, test=0.847) total time=  11.1s
# [CV 2/5; 23/100] START estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7464019343289866, n_estimators=261
# [CV 2/5; 23/100] END estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7464019343289866, n_estimators=261;, score=(train=1.000, test=0.864) total time=  15.6s
# [CV 1/5; 26/100] START estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.980492076586965, n_estimators=242
# [CV 1/5; 26/100] END estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.980492076586965, n_estimators=242;, score=(train=0.848, test=0.727) total time=   3.0s
# [CV 5/5; 26/100] START estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.980492076586965, n_estimators=242
# [CV 5/5; 26/100] END estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.980492076586965, n_estimators=242;, score=(train=0.852, test=0.742) total time=   2.7s
# [CV 1/5; 28/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.5810475199556067, n_estimators=452
# [CV 1/5; 28/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.5810475199556067, n_estimators=452;, score=(train=0.835, test=0.757) total time=  13.3s
# [CV 4/5; 28/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.5810475199556067, n_estimators=452
# [CV 4/5; 28/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.5810475199556067, n_estimators=452;, score=(train=0.822, test=0.754) total time=  12.6s
# [CV 2/5; 30/100] START estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=None, estimator__splitter=best, learning_rate=0.5518787376413166, n_estimators=191
# [CV 2/5; 30/100] END estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=None, estimator__splitter=best, learning_rate=0.5518787376413166, n_estimators=191;, score=(train=0.993, test=0.864) total time= 1.0min
# [CV 4/5; 32/100] START estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.27164736815703083, n_estimators=364
# [CV 4/5; 32/100] END estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.27164736815703083, n_estimators=364;, score=(train=1.000, test=0.891) total time= 2.1min
# [CV 2/5; 37/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9204883140696485, n_estimators=367
# [CV 2/5; 37/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9204883140696485, n_estimators=367;, score=(train=1.000, test=0.851) total time=  29.5s
# [CV 5/5; 37/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9204883140696485, n_estimators=367
# [CV 5/5; 37/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9204883140696485, n_estimators=367;, score=(train=1.000, test=0.845) total time=  28.5s
# [CV 3/5; 38/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9812647055982573, n_estimators=106
# [CV 3/5; 38/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9812647055982573, n_estimators=106;, score=(train=1.000, test=0.870) total time= 1.5min
# [CV 1/5; 39/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184
# [CV 1/5; 39/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184;, score=(train=0.797, test=0.733) total time=   4.6s
# [CV 2/5; 39/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184
# [CV 2/5; 39/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184;, score=(train=0.803, test=0.740) total time=   5.2s
# [CV 3/5; 39/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184
# [CV 3/5; 39/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184;, score=(train=0.791, test=0.737) total time=   4.6s
# [CV 4/5; 39/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184
# [CV 4/5; 39/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184;, score=(train=0.800, test=0.743) total time=   4.9s
# [CV 2/5; 40/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8713865184021674, n_estimators=285
# [CV 2/5; 40/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8713865184021674, n_estimators=285;, score=(train=1.000, test=0.854) total time=  22.7s
# [CV 1/5; 41/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235
# [CV 1/5; 41/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235;, score=(train=0.644, test=0.634) total time=   3.7s
# [CV 3/5; 41/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235
# [CV 3/5; 41/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235;, score=(train=0.618, test=0.620) total time=   3.5s
# [CV 1/5; 42/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5923126634207857, n_estimators=481
# [CV 1/5; 42/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5923126634207857, n_estimators=481;, score=(train=1.000, test=0.789) total time=  10.0s
# [CV 5/5; 42/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5923126634207857, n_estimators=481
# [CV 5/5; 42/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5923126634207857, n_estimators=481;, score=(train=1.000, test=0.789) total time=  10.5s
# [CV 3/5; 44/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9896649876759759, n_estimators=178
# [CV 3/5; 44/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9896649876759759, n_estimators=178;, score=(train=0.619, test=0.581) total time=   3.8s
# [CV 4/5; 45/100] START estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.22556651929654403, n_estimators=85
# [CV 4/5; 45/100] END estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.22556651929654403, n_estimators=85;, score=(train=1.000, test=0.835) total time=   3.0s
# [CV 5/5; 46/100] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.5020576609911874, n_estimators=263
# [CV 5/5; 46/100] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.5020576609911874, n_estimators=263;, score=(train=0.672, test=0.650) total time=   3.3s
# [CV 1/5; 48/100] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.12824213834301224, n_estimators=420
# [CV 1/5; 48/100] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.12824213834301224, n_estimators=420;, score=(train=0.810, test=0.755) total time=  51.4s
# [CV 4/5; 48/100] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.12824213834301224, n_estimators=420
# [CV 4/5; 48/100] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.12824213834301224, n_estimators=420;, score=(train=0.821, test=0.778) total time=  49.2s
# [CV 3/5; 49/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464
# [CV 3/5; 49/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464;, score=(train=1.000, test=0.778) total time=  10.1s
# [CV 5/5; 49/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464
# [CV 5/5; 49/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464;, score=(train=1.000, test=0.783) total time=  11.7s
# [CV 3/5; 50/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9562082081101384, n_estimators=67
# [CV 3/5; 50/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9562082081101384, n_estimators=67;, score=(train=0.822, test=0.746) total time=  18.4s
# [CV 1/5; 51/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.27028138728512596, n_estimators=298
# [CV 1/5; 51/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.27028138728512596, n_estimators=298;, score=(train=0.703, test=0.677) total time=   3.4s
# [CV 5/5; 1/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.06848176931756665, n_estimators=492
# [CV 5/5; 1/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.06848176931756665, n_estimators=492;, score=(train=0.739, test=0.728) total time=   6.0s
# [CV 4/5; 4/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.28153314983835287, n_estimators=423
# [CV 4/5; 4/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.28153314983835287, n_estimators=423;, score=(train=0.813, test=0.762) total time=   3.8s
# [CV 2/5; 6/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.05026746284225058, n_estimators=324
# [CV 2/5; 6/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.05026746284225058, n_estimators=324;, score=(train=0.664, test=0.661) total time=   2.6s
# [CV 5/5; 6/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.05026746284225058, n_estimators=324
# [CV 5/5; 6/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.05026746284225058, n_estimators=324;, score=(train=0.663, test=0.650) total time=   2.3s
# [CV 3/5; 7/100] START estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6382888322042363, n_estimators=121
# [CV 3/5; 7/100] END estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6382888322042363, n_estimators=121;, score=(train=1.000, test=0.862) total time=   8.1s
# [CV 1/5; 10/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3873788897069701, n_estimators=204
# [CV 1/5; 10/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3873788897069701, n_estimators=204;, score=(train=0.683, test=0.671) total time=   1.4s
# [CV 4/5; 10/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3873788897069701, n_estimators=204
# [CV 4/5; 10/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3873788897069701, n_estimators=204;, score=(train=0.686, test=0.687) total time=   1.4s
# [CV 2/5; 11/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.590426362031689, n_estimators=481
# [CV 2/5; 11/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.590426362031689, n_estimators=481;, score=(train=0.849, test=0.737) total time=   9.6s
# [CV 4/5; 11/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.590426362031689, n_estimators=481
# [CV 4/5; 11/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.590426362031689, n_estimators=481;, score=(train=0.852, test=0.757) total time=  10.1s
# [CV 2/5; 12/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=best, learning_rate=0.03495626165570564, n_estimators=495
# [CV 2/5; 12/100] END estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=best, learning_rate=0.03495626165570564, n_estimators=495;, score=(train=1.000, test=0.876) total time= 3.4min
# [CV 1/5; 15/100] START estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187
# [CV 1/5; 15/100] END estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187;, score=(train=1.000, test=0.781) total time=   0.1s
# [CV 2/5; 15/100] START estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187
# [CV 2/5; 15/100] END estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187;, score=(train=1.000, test=0.791) total time=   0.1s
# [CV 3/5; 15/100] START estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187
# [CV 3/5; 15/100] END estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187;, score=(train=1.000, test=0.795) total time=   0.1s
# [CV 4/5; 15/100] START estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187
# [CV 4/5; 15/100] END estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187;, score=(train=1.000, test=0.770) total time=   0.1s
# [CV 5/5; 15/100] START estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187
# [CV 5/5; 15/100] END estimator__criterion=entropy, estimator__max_depth=None, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6556481241473785, n_estimators=187;, score=(train=1.000, test=0.775) total time=   0.1s
# [CV 1/5; 16/100] START estimator__criterion=gini, estimator__max_depth=None, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2431313418267933, n_estimators=246
# [CV 1/5; 16/100] END estimator__criterion=gini, estimator__max_depth=None, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2431313418267933, n_estimators=246;, score=(train=1.000, test=0.711) total time=   0.1s
# [CV 3/5; 16/100] START estimator__criterion=gini, estimator__max_depth=None, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2431313418267933, n_estimators=246
# [CV 3/5; 16/100] END estimator__criterion=gini, estimator__max_depth=None, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2431313418267933, n_estimators=246;, score=(train=1.000, test=0.705) total time=   0.1s
# [CV 5/5; 16/100] START estimator__criterion=gini, estimator__max_depth=None, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2431313418267933, n_estimators=246
# [CV 5/5; 16/100] END estimator__criterion=gini, estimator__max_depth=None, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2431313418267933, n_estimators=246;, score=(train=1.000, test=0.699) total time=   0.1s
# [CV 2/5; 17/100] START estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.12908697292305504, n_estimators=174
# [CV 2/5; 17/100] END estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.12908697292305504, n_estimators=174;, score=(train=0.861, test=0.791) total time=   1.9s
# [CV 4/5; 17/100] START estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.12908697292305504, n_estimators=174
# [CV 4/5; 17/100] END estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.12908697292305504, n_estimators=174;, score=(train=0.870, test=0.799) total time=   1.8s
# [CV 5/5; 17/100] START estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.12908697292305504, n_estimators=174
# [CV 5/5; 17/100] END estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.12908697292305504, n_estimators=174;, score=(train=0.862, test=0.776) total time=   2.1s
# [CV 3/5; 18/100] START estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.16746064518198533, n_estimators=398
# [CV 3/5; 18/100] END estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.16746064518198533, n_estimators=398;, score=(train=0.902, test=0.780) total time=   4.3s
# [CV 3/5; 19/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.7999724436733792, n_estimators=343
# [CV 3/5; 19/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.7999724436733792, n_estimators=343;, score=(train=0.837, test=0.745) total time=  10.3s
# [CV 3/5; 21/100] START estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18356991983307336, n_estimators=267
# [CV 3/5; 21/100] END estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18356991983307336, n_estimators=267;, score=(train=1.000, test=0.852) total time=  10.9s
# [CV 4/5; 23/100] START estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7464019343289866, n_estimators=261
# [CV 4/5; 23/100] END estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7464019343289866, n_estimators=261;, score=(train=1.000, test=0.861) total time=  15.5s
# [CV 2/5; 26/100] START estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.980492076586965, n_estimators=242
# [CV 2/5; 26/100] END estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.980492076586965, n_estimators=242;, score=(train=0.844, test=0.713) total time=   2.8s
# [CV 1/5; 27/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1258571641049061, n_estimators=277
# [CV 1/5; 27/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1258571641049061, n_estimators=277;, score=(train=0.658, test=0.652) total time=  22.4s
# [CV 2/5; 29/100] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.7400675790244325, n_estimators=266
# [CV 2/5; 29/100] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.7400675790244325, n_estimators=266;, score=(train=0.788, test=0.720) total time=  41.6s
# [CV 5/5; 30/100] START estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=None, estimator__splitter=best, learning_rate=0.5518787376413166, n_estimators=191
# [CV 5/5; 30/100] END estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=None, estimator__splitter=best, learning_rate=0.5518787376413166, n_estimators=191;, score=(train=0.991, test=0.854) total time=  58.7s
# [CV 4/5; 34/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.9847912854575468, n_estimators=427
# [CV 4/5; 34/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.9847912854575468, n_estimators=427;, score=(train=0.647, test=0.625) total time=   3.5s
# [CV 2/5; 35/100] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3064881922201459, n_estimators=257
# [CV 2/5; 35/100] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3064881922201459, n_estimators=257;, score=(train=0.656, test=0.662) total time=   1.9s
# [CV 4/5; 35/100] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3064881922201459, n_estimators=257
# [CV 4/5; 35/100] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3064881922201459, n_estimators=257;, score=(train=0.663, test=0.645) total time=   1.8s
# [CV 2/5; 36/100] START estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.8844145165236406, n_estimators=452
# [CV 2/5; 36/100] END estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.8844145165236406, n_estimators=452;, score=(train=1.000, test=0.888) total time= 4.2min
# [CV 5/5; 39/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184
# [CV 5/5; 39/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7422073080725561, n_estimators=184;, score=(train=0.786, test=0.740) total time=   4.9s
# [CV 3/5; 40/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8713865184021674, n_estimators=285
# [CV 3/5; 40/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8713865184021674, n_estimators=285;, score=(train=1.000, test=0.844) total time=  22.6s
# [CV 2/5; 41/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235
# [CV 2/5; 41/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235;, score=(train=0.631, test=0.642) total time=   3.6s
# [CV 4/5; 41/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235
# [CV 4/5; 41/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235;, score=(train=0.646, test=0.648) total time=   3.5s
# [CV 2/5; 42/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5923126634207857, n_estimators=481
# [CV 2/5; 42/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5923126634207857, n_estimators=481;, score=(train=1.000, test=0.789) total time=  10.1s
# [CV 2/5; 43/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.5562607464547268, n_estimators=316
# [CV 3/5; 2/100] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.6308028080064928, n_estimators=135
# [CV 3/5; 2/100] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.6308028080064928, n_estimators=135;, score=(train=0.661, test=0.653) total time=   1.8s
# [CV 4/5; 2/100] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.6308028080064928, n_estimators=135
# [CV 4/5; 2/100] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.6308028080064928, n_estimators=135;, score=(train=0.679, test=0.670) total time=   1.5s
# [CV 3/5; 4/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.28153314983835287, n_estimators=423
# [CV 3/5; 4/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.28153314983835287, n_estimators=423;, score=(train=0.806, test=0.754) total time=   4.4s
# [CV 1/5; 6/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.05026746284225058, n_estimators=324
# [CV 1/5; 6/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.05026746284225058, n_estimators=324;, score=(train=0.674, test=0.666) total time=   2.4s
# [CV 4/5; 6/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.05026746284225058, n_estimators=324
# [CV 4/5; 6/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.05026746284225058, n_estimators=324;, score=(train=0.672, test=0.665) total time=   2.4s
# [CV 2/5; 7/100] START estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6382888322042363, n_estimators=121
# [CV 2/5; 7/100] END estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6382888322042363, n_estimators=121;, score=(train=1.000, test=0.862) total time=   8.1s
# [CV 2/5; 9/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.13131020761872325, n_estimators=496
# [CV 2/5; 9/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=None, estimator__splitter=best, learning_rate=0.13131020761872325, n_estimators=496;, score=(train=0.750, test=0.731) total time=  40.6s
# [CV 4/5; 12/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=best, learning_rate=0.03495626165570564, n_estimators=495
# [CV 4/5; 12/100] END estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=best, learning_rate=0.03495626165570564, n_estimators=495;, score=(train=1.000, test=0.865) total time= 3.5min
# [CV 2/5; 20/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.7577044707188288, n_estimators=427
# [CV 2/5; 20/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.7577044707188288, n_estimators=427;, score=(train=0.667, test=0.668) total time=   3.3s
# [CV 4/5; 20/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.7577044707188288, n_estimators=427
# [CV 4/5; 20/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.7577044707188288, n_estimators=427;, score=(train=0.659, test=0.639) total time=   3.5s
# [CV 5/5; 21/100] START estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18356991983307336, n_estimators=267
# [CV 5/5; 21/100] END estimator__criterion=gini, estimator__max_depth=10, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18356991983307336, n_estimators=267;, score=(train=1.000, test=0.852) total time=  11.0s
# [CV 1/5; 24/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2853221689420893, n_estimators=354
# [CV 1/5; 24/100] END estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2853221689420893, n_estimators=354;, score=(train=0.997, test=0.812) total time=   5.0s
# [CV 4/5; 24/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2853221689420893, n_estimators=354
# [CV 4/5; 24/100] END estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2853221689420893, n_estimators=354;, score=(train=0.998, test=0.816) total time=   5.2s
# [CV 3/5; 25/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.467073419038334, n_estimators=345
# [CV 3/5; 25/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.467073419038334, n_estimators=345;, score=(train=0.841, test=0.747) total time=   7.8s
# [CV 5/5; 27/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1258571641049061, n_estimators=277
# [CV 5/5; 27/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1258571641049061, n_estimators=277;, score=(train=0.658, test=0.647) total time=  22.2s
# [CV 3/5; 29/100] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.7400675790244325, n_estimators=266
# [CV 3/5; 29/100] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.7400675790244325, n_estimators=266;, score=(train=0.767, test=0.708) total time=  41.4s
# [CV 1/5; 31/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.18121957601802008, n_estimators=418
# [CV 1/5; 31/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.18121957601802008, n_estimators=418;, score=(train=1.000, test=0.816) total time=   9.4s
# [CV 4/5; 31/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.18121957601802008, n_estimators=418
# [CV 4/5; 31/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.18121957601802008, n_estimators=418;, score=(train=1.000, test=0.831) total time=   9.8s
# [CV 3/5; 32/100] START estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.27164736815703083, n_estimators=364
# [CV 3/5; 32/100] END estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.27164736815703083, n_estimators=364;, score=(train=1.000, test=0.885) total time= 2.1min
# [CV 1/5; 37/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9204883140696485, n_estimators=367
# [CV 1/5; 37/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9204883140696485, n_estimators=367;, score=(train=1.000, test=0.843) total time=  29.1s
# [CV 4/5; 37/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9204883140696485, n_estimators=367
# [CV 4/5; 37/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=random, learning_rate=0.9204883140696485, n_estimators=367;, score=(train=1.000, test=0.853) total time=  28.8s
# [CV 2/5; 38/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9812647055982573, n_estimators=106
# [CV 2/5; 38/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9812647055982573, n_estimators=106;, score=(train=1.000, test=0.870) total time= 1.0min
# [CV 5/5; 38/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9812647055982573, n_estimators=106
# [CV 5/5; 38/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9812647055982573, n_estimators=106;, score=(train=1.000, test=0.866) total time= 1.4min
# [CV 5/5; 41/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235
# [CV 5/5; 41/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.8876226457691753, n_estimators=235;, score=(train=0.646, test=0.632) total time=   3.8s
# [CV 4/5; 42/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5923126634207857, n_estimators=481
# [CV 4/5; 42/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.5923126634207857, n_estimators=481;, score=(train=1.000, test=0.801) total time=  10.3s
# [CV 5/5; 43/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.5562607464547268, n_estimators=316
# [CV 5/5; 43/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.5562607464547268, n_estimators=316;, score=(train=1.000, test=0.804) total time=   8.6s
# [CV 1/5; 45/100] START estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.22556651929654403, n_estimators=85
# [CV 1/5; 45/100] END estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.22556651929654403, n_estimators=85;, score=(train=1.000, test=0.828) total time=   3.0s
# [CV 1/5; 46/100] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.5020576609911874, n_estimators=263
# [CV 1/5; 46/100] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.5020576609911874, n_estimators=263;, score=(train=0.671, test=0.650) total time=   3.3s
# [CV 2/5; 47/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=best, learning_rate=0.06212195964093525, n_estimators=342
# [CV 2/5; 47/100] END estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=best, learning_rate=0.06212195964093525, n_estimators=342;, score=(train=1.000, test=0.874) total time= 2.7min
# [CV 1/5; 54/100] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.9793061286875535, n_estimators=345
# [CV 1/5; 54/100] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.9793061286875535, n_estimators=345;, score=(train=0.777, test=0.697) total time=   7.8s
# [CV 3/5; 55/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4724614189746875, n_estimators=212
# [CV 3/5; 55/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.4724614189746875, n_estimators=212;, score=(train=0.718, test=0.673) total time=   4.2s
# [CV 4/5; 56/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.16287259958925482, n_estimators=253
# [CV 4/5; 56/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.16287259958925482, n_estimators=253;, score=(train=0.886, test=0.819) total time=  42.4s
# [CV 3/5; 58/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4142623868322045, n_estimators=487
# [CV 3/5; 58/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4142623868322045, n_estimators=487;, score=(train=0.707, test=0.674) total time=   3.8s
# [CV 2/5; 59/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.2812980119359413, n_estimators=367
# [CV 2/5; 59/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.2812980119359413, n_estimators=367;, score=(train=0.845, test=0.755) total time=   7.8s
# [CV 1/5; 60/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6819838529856675, n_estimators=164
# [CV 1/5; 60/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6819838529856675, n_estimators=164;, score=(train=0.665, test=0.651) total time=   2.8s
# [CV 5/5; 60/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6819838529856675, n_estimators=164
# [CV 5/5; 60/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6819838529856675, n_estimators=164;, score=(train=0.651, test=0.647) total time=   2.8s
# [CV 5/5; 61/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.703853447910059, n_estimators=90
# ...
# [CV 1/5; 5/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7585701620446833, n_estimators=413
# [CV 1/5; 5/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=random, learning_rate=0.7585701620446833, n_estimators=413;, score=(train=0.814, test=0.740) total time=  11.3s
# [CV 4/5; 7/100] START estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6382888322042363, n_estimators=121
# [CV 4/5; 7/100] END estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6382888322042363, n_estimators=121;, score=(train=1.000, test=0.866) total time=   8.2s
# [CV 2/5; 10/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3873788897069701, n_estimators=204
# [CV 2/5; 10/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.3873788897069701, n_estimators=204;, score=(train=0.694, test=0.686) total time=   1.4s
# [CV 1/5; 11/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.590426362031689, n_estimators=481
# [CV 1/5; 11/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.590426362031689, n_estimators=481;, score=(train=0.854, test=0.741) total time=  10.2s
# [CV 5/5; 11/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.590426362031689, n_estimators=481
# [CV 5/5; 11/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.590426362031689, n_estimators=481;, score=(train=0.855, test=0.753) total time=  10.8s
# [CV 3/5; 12/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=best, learning_rate=0.03495626165570564, n_estimators=495
# [CV 3/5; 12/100] END estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=None, estimator__splitter=best, learning_rate=0.03495626165570564, n_estimators=495;, score=(train=1.000, test=0.874) total time= 3.8min
# [CV 5/5; 20/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.7577044707188288, n_estimators=427
# [CV 5/5; 20/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.7577044707188288, n_estimators=427;, score=(train=0.655, test=0.642) total time=   3.8s
# [CV 2/5; 22/100] START estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2157457723624049, n_estimators=176
# [CV 2/5; 22/100] END estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2157457723624049, n_estimators=176;, score=(train=0.959, test=0.814) total time=   5.1s
# [CV 5/5; 22/100] START estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2157457723624049, n_estimators=176
# [CV 5/5; 22/100] END estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.2157457723624049, n_estimators=176;, score=(train=0.958, test=0.822) total time=   5.1s
# [CV 3/5; 24/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2853221689420893, n_estimators=354
# [CV 3/5; 24/100] END estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.2853221689420893, n_estimators=354;, score=(train=0.998, test=0.804) total time=   5.2s
# [CV 1/5; 25/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.467073419038334, n_estimators=345
# [CV 1/5; 25/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.467073419038334, n_estimators=345;, score=(train=0.844, test=0.751) total time=   8.2s
# [CV 4/5; 26/100] START estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.980492076586965, n_estimators=242
# [CV 4/5; 26/100] END estimator__criterion=entropy, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.980492076586965, n_estimators=242;, score=(train=0.854, test=0.731) total time=   2.7s
# [CV 3/5; 27/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1258571641049061, n_estimators=277
# [CV 3/5; 27/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=best, learning_rate=0.1258571641049061, n_estimators=277;, score=(train=0.661, test=0.653) total time=  24.3s
# [CV 5/5; 29/100] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.7400675790244325, n_estimators=266
# [CV 5/5; 29/100] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.7400675790244325, n_estimators=266;, score=(train=0.764, test=0.728) total time=  45.3s
# [CV 3/5; 31/100] START estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.18121957601802008, n_estimators=418
# [CV 3/5; 31/100] END estimator__criterion=gini, estimator__max_depth=15, estimator__max_features=sqrt, estimator__splitter=random, learning_rate=0.18121957601802008, n_estimators=418;, score=(train=1.000, test=0.817) total time=  11.4s
# [CV 1/5; 32/100] START estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.27164736815703083, n_estimators=364
# [CV 1/5; 32/100] END estimator__criterion=gini, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.27164736815703083, n_estimators=364;, score=(train=1.000, test=0.881) total time= 2.1min
# [CV 4/5; 36/100] START estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.8844145165236406, n_estimators=452
# [CV 4/5; 36/100] END estimator__criterion=entropy, estimator__max_depth=12, estimator__max_features=None, estimator__splitter=best, learning_rate=0.8844145165236406, n_estimators=452;, score=(train=1.000, test=0.884) total time= 4.7min
# [CV 3/5; 48/100] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.12824213834301224, n_estimators=420
# [CV 3/5; 48/100] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=None, estimator__splitter=best, learning_rate=0.12824213834301224, n_estimators=420;, score=(train=0.812, test=0.776) total time=  52.6s
# [CV 1/5; 49/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464
# [CV 1/5; 49/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464;, score=(train=1.000, test=0.776) total time=   9.8s
# [CV 2/5; 49/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464
# [CV 2/5; 49/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464;, score=(train=1.000, test=0.783) total time=  10.6s
# [CV 4/5; 49/100] START estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464
# [CV 4/5; 49/100] END estimator__criterion=entropy, estimator__max_depth=15, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.7804991018346336, n_estimators=464;, score=(train=1.000, test=0.795) total time=  11.6s
# [CV 2/5; 50/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9562082081101384, n_estimators=67
# [CV 2/5; 50/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9562082081101384, n_estimators=67;, score=(train=0.809, test=0.733) total time=  17.3s
# [CV 5/5; 50/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9562082081101384, n_estimators=67
# [CV 5/5; 50/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.9562082081101384, n_estimators=67;, score=(train=0.793, test=0.735) total time=  19.2s
# [CV 1/5; 53/100] START estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.2200878846570118, n_estimators=384
# [CV 1/5; 53/100] END estimator__criterion=gini, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.2200878846570118, n_estimators=384;, score=(train=0.688, test=0.672) total time=   4.3s
# [CV 2/5; 54/100] START estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.9793061286875535, n_estimators=345
# [CV 2/5; 54/100] END estimator__criterion=gini, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.9793061286875535, n_estimators=345;, score=(train=0.763, test=0.686) total time=   8.8s
# [CV 1/5; 56/100] START estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.16287259958925482, n_estimators=253
# [CV 1/5; 56/100] END estimator__criterion=gini, estimator__max_depth=5, estimator__max_features=None, estimator__splitter=best, learning_rate=0.16287259958925482, n_estimators=253;, score=(train=0.889, test=0.802) total time=  42.8s
# [CV 1/5; 58/100] START estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4142623868322045, n_estimators=487
# [CV 1/5; 58/100] END estimator__criterion=entropy, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.4142623868322045, n_estimators=487;, score=(train=0.703, test=0.686) total time=   3.9s
# [CV 1/5; 59/100] START estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.2812980119359413, n_estimators=367
# [CV 1/5; 59/100] END estimator__criterion=entropy, estimator__max_depth=5, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.2812980119359413, n_estimators=367;, score=(train=0.851, test=0.748) total time=   8.8s
# [CV 3/5; 60/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6819838529856675, n_estimators=164
# [CV 3/5; 60/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=None, estimator__splitter=random, learning_rate=0.6819838529856675, n_estimators=164;, score=(train=0.671, test=0.667) total time=   2.7s
# [CV 2/5; 61/100] START estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.703853447910059, n_estimators=90
# [CV 2/5; 61/100] END estimator__criterion=entropy, estimator__max_depth=10, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.703853447910059, n_estimators=90;, score=(train=0.999, test=0.810) total time=   4.2s
# [CV 4/5; 62/100] START estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.30228880750218245, n_estimators=337
# [CV 4/5; 62/100] END estimator__criterion=entropy, estimator__max_depth=2, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.30228880750218245, n_estimators=337;, score=(train=0.689, test=0.673) total time=   4.4s
# [CV 5/5; 64/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.9506199828256515, n_estimators=273
# [CV 5/5; 64/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.9506199828256515, n_estimators=273;, score=(train=0.684, test=0.658) total time=   4.5s
# [CV 1/5; 66/100] START estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.9504912753615781, n_estimators=164
# [CV 1/5; 66/100] END estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.9504912753615781, n_estimators=164;, score=(train=0.935, test=0.765) total time=   3.5s
# [CV 2/5; 66/100] START estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.9504912753615781, n_estimators=164
# [CV 2/5; 66/100] END estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.9504912753615781, n_estimators=164;, score=(train=0.928, test=0.764) total time=   3.4s
# [CV 5/5; 66/100] START estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.9504912753615781, n_estimators=164
# [CV 5/5; 66/100] END estimator__criterion=gini, estimator__max_depth=7, estimator__max_features=log2, estimator__splitter=best, learning_rate=0.9504912753615781, n_estimators=164;, score=(train=0.926, test=0.770) total time=   3.6s
# [CV 4/5; 67/100] START estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.047840149071081466, n_estimators=56
# [CV 4/5; 67/100] END estimator__criterion=gini, estimator__max_depth=3, estimator__max_features=log2, estimator__splitter=random, learning_rate=0.047840149071081466, n_estimators=56;, score=(train=0.603, test=0.604) total time=   0.4s
# [CV 2/5; 68/100] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18257299942255, n_estimators=453
# [CV 2/5; 68/100] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18257299942255, n_estimators=453;, score=(train=0.789, test=0.749) total time=  11.6s
# [CV 5/5; 68/100] START estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18257299942255, n_estimators=453
# [CV 5/5; 68/100] END estimator__criterion=entropy, estimator__max_depth=4, estimator__max_features=sqrt, estimator__splitter=best, learning_rate=0.18257299942255, n_estimators=453;, score=(train=0.802, test=0.754) total time=  12.3s

# %%
cv_results.head()

# %%
results_path = f"./tuning_results/tuning_ada/{timestamp}/Assets"
if not os.path.exists(results_path):
    os.makedirs(results_path)

# %% [markdown]
# # CV Evaluation

# %%
cv_results.columns

# %%
cv_results.sort_values(by='rank_test_score', ascending=True).head(5)

# %%
sorted_cv = cv_results.sort_values(by='rank_test_score', ascending=True)

# %% [markdown]
# # Train vs Test Comparison

# %%
plt.figure(figsize=(16, 6))    

plt.plot(sorted_cv['rank_test_score'], sorted_cv['mean_train_score'], label="Train Score")
plt.plot(sorted_cv['rank_test_score'], sorted_cv['mean_test_score'], label="Validation Score")

plt.grid()
plt.xlabel('Sorted Validation Rank')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy by Final Rank')
plt.legend(loc='best')

filename = "test_train_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(10, 3))
fig.suptitle('Test Accuracy by Rank')

ax = fig.add_subplot(111)

plt.boxplot(sorted_cv.iloc[:10, :][['split0_test_score', 'split1_test_score', 'split2_test_score',
   'split3_test_score', 'split4_test_score']].T)
ax.set_xticklabels(range(1, 11))
ax.set_xlabel("Rank")
ax.set_ylabel("Accuracy")

filename = "test_accuracy_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(10, 3))
fig.suptitle('Train Accuracy by Rank')

ax = fig.add_subplot(111)

plt.boxplot(sorted_cv.iloc[:10, :][['split0_train_score', 'split1_train_score', 'split2_train_score',
   'split3_train_score', 'split4_train_score']].T)
ax.set_xticklabels(range(1, 11))
ax.set_xlabel("Rank")
ax.set_ylabel("Accuracy")

filename = "train_accuracy_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
max_params = cv_results.loc[cv_results['rank_test_score'] == 1]
best_params = max_params.params.values[0]

# %%
print(f"Mean Train set, Accuracy = {max_params['mean_train_score'].values[0]:.2f}")
print(f"Mean Test  set, Accuracy = {max_params['mean_test_score'].values[0]:.2f}")

# %%
random_search = pickle.load(open(os.path.join(f'./tuning_results/tuning_ada/{timestamp}/', file_name), "rb"))
model = random_search.best_estimator_

#model = ADAClassifier(**best_params)
#model.fit(X_train, y_train)

y_train_prediction = model.predict(X_train)
y_test_prediction = model.predict(X_test)

# %%
print(f"Train set, Accuracy = {accuracy_score(y_train, y_train_prediction):.2f}")
print(f"Test set, Accuracy = {accuracy_score(y_test, y_test_prediction):.2f}")

# %%
ind = np.argpartition(model.feature_importances_, -20)[-20:]

features = X.columns[ind]
importance = model.feature_importances_[ind]

fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(ind)), importance, align='center')
plt.yticks(range(len(ind)), features)
plt.title('Feature Importance ADA')
plt.grid()

filename = "feature_importance.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %%
# TEST
for col in ['param_estimator__splitter', 'param_estimator__criterion',
       'param_estimator__splitter', 'param_estimator__max_features', 'param_estimator__max_depth',
       'param_n_estimators', 'param_learning_rate']:
    
    plt.figure(figsize=(16, 6))    

    m, b = np.polyfit(list(sorted_cv['mean_test_score'].values), list(sorted_cv[col].values), 1)
    plt.plot(sorted_cv['mean_test_score'], m * sorted_cv['mean_test_score'] + b, c='r', label="Regression Line")
    plt.scatter(sorted_cv['mean_test_score'], sorted_cv[col], label=f"{col} Values")
    
    plt.grid()
    plt.xlabel('Mean Validation Score')
    plt.ylabel('Parameter Value')
    plt.title(col)
    plt.legend(loc='best')

    
    filename = f"{col}_by_rank.png"
    plt.savefig(os.path.join(results_path, filename))
                  
    plt.show()

# %% [markdown]
# # Hyperparameter Evaluation

# %%
def plot_parameters(x_values, title):
    
    fig, ax1 = plt.subplots(figsize=(16, 6))
    ax2 = ax1.twinx()

    ax1.scatter(x_values, cv_results['mean_test_score'], label='mean_test_score', c='b')
    #ax2.scatter(x_values, cv_results['std_test_score'], label='std_test_score', c='r')

    m, b = np.polyfit(list(x_values.values), list(cv_results['mean_test_score'].values), 1)
    ax1.plot(x_values, m * x_values + b, c='b')

    m, b = np.polyfit(list(x_values.values), list(cv_results['std_test_score'].values), 1)
    ax2.plot(x_values, m * x_values + b, c='r', label='std_test_score')
    
    ax1.set_title(title)
    ax1.set_xlabel('Parameter Value')
    ax1.set_ylabel('Mean Test Score')
    ax2.set_ylabel('Standard Deviation of Test Score')
    ax1.grid(True)
    
    
    # Combine the legends from both axes
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax2.legend(lines + lines2, labels + labels2, loc='upper right')

    filename = f"{title}_test_score.png"
    plt.savefig(os.path.join(results_path, filename))
            
    plt.show()

# %%
for param in ['param_estimator__splitter', 'param_estimator__criterion',
       'param_estimator__splitter', 'param_estimator__max_features', 'param_estimator__max_depth',
       'param_n_estimators', 'param_learning_rate']:
    x_values = cv_results[param]
    plot_parameters(x_values, param)

# %% [markdown]
# # Plotting Evaluation Metrics (Precision, Recall, F1-Score, AUC-ROC):

# %%
# For multiclass classification, you need to binarize the labels
y_true_bin = label_binarize(y_test, classes=np.unique(y_test))
y_score_bin = label_binarize(y_test_prediction, classes=np.unique(y_test_prediction))

auc_roc = roc_auc_score(y_true_bin, y_score_bin, average='macro')

# Plot Precision-Recall curve for each class
precision = dict()
recall = dict()

plt.figure(figsize=(16, 6))    
for i in range(7):
    precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], y_score_bin[:, i])
    plt.plot(recall[i], precision[i], label='Covertype {}'.format(i + 1))

plt.grid()
plt.xlabel('Recall')
plt.ylabel('True Positive Rate / Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')

filename = "precision_recall.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()


# Plot AUC-ROC curve for each class
fpr = dict()
tpr = dict()

plt.figure(figsize=(16, 6))    
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score_bin[:, i])
    plt.plot(fpr[i], tpr[i], label='Covertype {}'.format(i + 1))

plt.grid()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate / Precision')
plt.title('ROC Curve')
plt.legend(loc='best')
            
filename = "roc_curve.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# # Partial Dependence

# %%
# potentially iterate over features (and relation ie 0 to 1)

# %%
features, feature_names = [(0,)], [f"Features #{i}" for i in range(X.shape[1])]
deciles = {0: np.linspace(0, 1, num=5)}

pd_results = partial_dependence(
    model, X, features=1, kind="average", grid_resolution=5)

display = PartialDependenceDisplay(
    [pd_results], features=features, feature_names=feature_names,
    target_idx=0, deciles=deciles
)
display.plot(pdp_lim={1: (-1.38, 0.66)})

plt.grid()
plt.xlabel('Feature Value')
plt.ylabel('Partial Dependence') 
plt.title('Partial Dependence')

filename = "partial_dependence.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
class_names = np.unique(y)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        model,
        X_test,
        y_test,
        display_labels=class_names + 1,
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    png_name = title.lower().replace(" ", "_")
    filename = f"{png_name}.png"
    plt.savefig(os.path.join(results_path, filename))

plt.show()

# %% [markdown]
# # Shap Values

# %%
explainer = shap.TreeExplainer(model)
explanation = explainer.shap_values(X_test, check_additivity=False)

# %%
shap.summary_plot(explanation, X_test, plot_type="bar", show=False)

filename = f"shap_summary.png"
plt.savefig(os.path.join(results_path, filename))
plt.close()

# %% [markdown]
# SHAP values show how each feature affects each final prediction, the significance of each feature compared to others, and the model's reliance on the interaction between features.
