# %%
# APPROACH TO ONLY TRAIN ON ONE AND TWO

# %%
import datetime
import os
import pickle
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
from sklearn.inspection import PartialDependenceDisplay, partial_dependence
from sklearn.metrics import (ConfusionMatrixDisplay, accuracy_score, precision_recall_curve, roc_auc_score, roc_curve)
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import label_binarize
from xgboost import XGBClassifier

import shap

# %config InlineBackend.figure_format = 'retina'

# %%
from notebook import notebookapp
import urllib
import json
import ipykernel
from shutil import copy2

def notebook_path():
    """Returns the absolute path of the Notebook or None if it cannot be determined
    NOTE: works only when the security is token-based or there is also no password
    """
    connection_file = os.path.basename(ipykernel.get_connection_file())
    kernel_id = connection_file.split('-', 1)[1].split('.')[0]

    for srv in notebookapp.list_running_servers():
        try:
            if srv['token']=='' and not srv['password']:  # No token and no password, ahem...
                req = urllib.request.urlopen(srv['url']+'api/sessions')
            else:
                req = urllib.request.urlopen(srv['url']+'api/sessions?token='+srv['token'])
            sessions = json.load(req)
            for sess in sessions:
                if sess['kernel']['id'] == kernel_id:
                    return os.path.join(srv['notebook_dir'],sess['notebook']['path'])
        except:
            pass  # There may be stale entries in the runtime directory 
    return None


def copy_current_nb(new_name):
    nb = notebook_path()
    if nb:
        new_path = os.path.join(os.path.dirname(nb), new_name+'.ipynb')
        copy2(nb, new_path)
    else:
        print("Current notebook path cannot be determined.")

# %%
df = pd.read_csv('Data/cover_type_engineered.csv')

# %%
df = df.loc[:, [col for col in df if not col.startswith('Cover_Type_')]]
df = df.loc[(df['Cover_Type'] == 1) | (df['Cover_Type'] == 2)]

X = df.drop(columns=['Cover_Type', 'Aspect_Sector'])
y = df['Cover_Type'] - 1

# %%
timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M")

warnings.filterwarnings("ignore", category=FutureWarning, module="pandas.api.types")

# Assuming X and y are defined
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=42)

# Define the estimator
estimator = XGBClassifier(tree_method="hist")

# Define hyperparameters for tuning
hyperparameters = {
    "n_estimators": stats.randint(50, 150),  # Increased range
    "learning_rate": stats.uniform(0.05, 0.1),  # Adjusted range
    "colsample_bytree": stats.uniform(0.6, 0.4),
    "colsample_bylevel": stats.uniform(0.6, 0.4),
    "colsample_bynode": stats.uniform(0.6, 0.4),
    "max_depth": stats.randint(15, 50),  # Increased range
    "subsample": stats.uniform(0.6, 0.4),
    "gamma": stats.uniform(0, 2),  # Adjusted range
    "reg_lambda": stats.uniform(0, 2),  # Adjusted range
    "reg_alpha": stats.uniform(0, 2),  # Adjusted range
}

# Define the RandomizedSearchCV parameters
random_search = RandomizedSearchCV(estimator, 
                                   param_distributions=hyperparameters, 
                                   scoring='accuracy',
                                   return_train_score=True,
                                   n_iter=500, 
                                   cv=5, 
                                   verbose=10, 
                                   n_jobs=-1)

# Fit the RandomizedSearchCV
try:
    random_search.fit(X_train, y_train)  # Assuming X_train and y_train are defined
    print("Best parameters found:", random_search.best_params_)
    print("Best score found:", random_search.best_score_)

    
    # Save results
    results_path = f"./tuning_results/tuning_xgb/{timestamp}"
    if not os.path.exists(results_path):
        os.makedirs(results_path)
        
    # Saving cross-validation results
    cv_results = pd.DataFrame(random_search.cv_results_)
    cv_results_file = f"{timestamp}_results.csv"
    cv_results.to_csv(os.path.join(results_path, cv_results_file), index=False)
    
    # Save .ipynb
    copy_current_nb(os.path.join(results_path, 'Evaluation_Notebook'))
    
    # Save Model
    file_name = f"xgb_{timestamp}.pkl"
    pickle.dump(random_search, open(os.path.join(results_path, file_name), "wb"))
        

except Exception as e:
    print(f"An error occurred during model optimization: {e}")
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV 2/5; 2/500] START colsample_bylevel=0.6398760460621272, colsample_bynode=0.6604297339327864, colsample_bytree=0.8909285194831833, gamma=0.4561738017712562, learning_rate=0.07795562585902209, max_depth=24, n_estimators=86, reg_alpha=0.010790441341474333, reg_lambda=1.8140258781293448, subsample=0.8589472484759024
# [CV 2/5; 2/500] END colsample_bylevel=0.6398760460621272, colsample_bynode=0.6604297339327864, colsample_bytree=0.8909285194831833, gamma=0.4561738017712562, learning_rate=0.07795562585902209, max_depth=24, n_estimators=86, reg_alpha=0.010790441341474333, reg_lambda=1.8140258781293448, subsample=0.8589472484759024;, score=(train=0.997, test=0.803) total time=   0.7s
# [CV 4/5; 3/500] START colsample_bylevel=0.7847967251785161, colsample_bynode=0.6626516517825252, colsample_bytree=0.922542827216404, gamma=0.2575271803657049, learning_rate=0.08655512044711312, max_depth=39, n_estimators=140, reg_alpha=1.9762167624875888, reg_lambda=0.06384409799692592, subsample=0.6868162676021907
# [CV 4/5; 3/500] END colsample_bylevel=0.7847967251785161, colsample_bynode=0.6626516517825252, colsample_bytree=0.922542827216404, gamma=0.2575271803657049, learning_rate=0.08655512044711312, max_depth=39, n_estimators=140, reg_alpha=1.9762167624875888, reg_lambda=0.06384409799692592, subsample=0.6868162676021907;, score=(train=0.983, test=0.796) total time=   0.8s
# [CV 2/5; 5/500] START colsample_bylevel=0.6399632970910134, colsample_bynode=0.830043790558207, colsample_bytree=0.9859828633104645, gamma=1.536161035582145, learning_rate=0.09248867576966847, max_depth=44, n_estimators=105, reg_alpha=0.2051703234972555, reg_lambda=1.2809335508763429, subsample=0.7870591853513491
# [CV 2/5; 5/500] END colsample_bylevel=0.6399632970910134, colsample_bynode=0.830043790558207, colsample_bytree=0.9859828633104645, gamma=1.536161035582145, learning_rate=0.09248867576966847, max_depth=44, n_estimators=105, reg_alpha=0.2051703234972555, reg_lambda=1.2809335508763429, subsample=0.7870591853513491;, score=(train=0.964, test=0.800) total time=   0.4s
# [CV 3/5; 6/500] START colsample_bylevel=0.7360414878802034, colsample_bynode=0.9928012044876124, colsample_bytree=0.7439550417413754, gamma=0.638573452250325, learning_rate=0.05992363303381737, max_depth=38, n_estimators=91, reg_alpha=1.3875069039896148, reg_lambda=0.8821941645650588, subsample=0.6535666654259281
# [CV 3/5; 6/500] END colsample_bylevel=0.7360414878802034, colsample_bynode=0.9928012044876124, colsample_bytree=0.7439550417413754, gamma=0.638573452250325, learning_rate=0.05992363303381737, max_depth=38, n_estimators=91, reg_alpha=1.3875069039896148, reg_lambda=0.8821941645650588, subsample=0.6535666654259281;, score=(train=0.949, test=0.853) total time=   0.6s
# [CV 1/5; 8/500] START colsample_bylevel=0.9366671923268144, colsample_bynode=0.9056226526589617, colsample_bytree=0.9764097304774897, gamma=0.9171229663605314, learning_rate=0.1286166123678995, max_depth=43, n_estimators=146, reg_alpha=0.8519981144395732, reg_lambda=1.0999758176395875, subsample=0.789072663615132
# [CV 1/5; 8/500] END colsample_bylevel=0.9366671923268144, colsample_bynode=0.9056226526589617, colsample_bytree=0.9764097304774897, gamma=0.9171229663605314, learning_rate=0.1286166123678995, max_depth=43, n_estimators=146, reg_alpha=0.8519981144395732, reg_lambda=1.0999758176395875, subsample=0.789072663615132;, score=(train=0.981, test=0.819) total time=   0.6s
# [CV 2/5; 9/500] START colsample_bylevel=0.633738307012597, colsample_bynode=0.8246331956069743, colsample_bytree=0.886620053547295, gamma=0.17388236225878773, learning_rate=0.11514772310531148, max_depth=25, n_estimators=124, reg_alpha=1.8103276109557216, reg_lambda=0.07139398091285587, subsample=0.7944875156688678
# [CV 2/5; 9/500] END colsample_bylevel=0.633738307012597, colsample_bynode=0.8246331956069743, colsample_bytree=0.886620053547295, gamma=0.17388236225878773, learning_rate=0.11514772310531148, max_depth=25, n_estimators=124, reg_alpha=1.8103276109557216, reg_lambda=0.07139398091285587, subsample=0.7944875156688678;, score=(train=0.997, test=0.798) total time=   0.6s
# [CV 4/5; 11/500] START colsample_bylevel=0.9004601250293633, colsample_bynode=0.9176381602279653, colsample_bytree=0.9170372073632107, gamma=1.4976182752130043, learning_rate=0.056314144414918624, max_depth=44, n_estimators=68, reg_alpha=0.40419172508620504, reg_lambda=1.73598678931199, subsample=0.6417241873118315
# [CV 4/5; 11/500] END colsample_bylevel=0.9004601250293633, colsample_bynode=0.9176381602279653, colsample_bytree=0.9170372073632107, gamma=1.4976182752130043, learning_rate=0.056314144414918624, max_depth=44, n_estimators=68, reg_alpha=0.40419172508620504, reg_lambda=1.73598678931199, subsample=0.6417241873118315;, score=(train=0.929, test=0.782) total time=   0.5s
# [CV 2/5; 13/500] START colsample_bylevel=0.8739019326091273, colsample_bynode=0.6882555794071881, colsample_bytree=0.8731233968079095, gamma=1.4486265657285309, learning_rate=0.06369599468513854, max_depth=40, n_estimators=106, reg_alpha=0.9871551075285538, reg_lambda=0.9772319603408579, subsample=0.7510348055080096
# [CV 2/5; 13/500] END colsample_bylevel=0.8739019326091273, colsample_bynode=0.6882555794071881, colsample_bytree=0.8731233968079095, gamma=1.4486265657285309, learning_rate=0.06369599468513854, max_depth=40, n_estimators=106, reg_alpha=0.9871551075285538, reg_lambda=0.9772319603408579, subsample=0.7510348055080096;, score=(train=0.938, test=0.798) total time=   0.5s
# [CV 4/5; 14/500] START colsample_bylevel=0.7709876191628094, colsample_bynode=0.6557518208323901, colsample_bytree=0.664764214588498, gamma=1.9649717931777462, learning_rate=0.09574982509292633, max_depth=48, n_estimators=61, reg_alpha=1.698636095229541, reg_lambda=1.8809024790980515, subsample=0.9623303952019507
# [CV 4/5; 14/500] END colsample_bylevel=0.7709876191628094, colsample_bynode=0.6557518208323901, colsample_bytree=0.664764214588498, gamma=1.9649717931777462, learning_rate=0.09574982509292633, max_depth=48, n_estimators=61, reg_alpha=1.698636095229541, reg_lambda=1.8809024790980515, subsample=0.9623303952019507;, score=(train=0.879, test=0.774) total time=   0.2s
# [CV 1/5; 16/500] START colsample_bylevel=0.770759101716597, colsample_bynode=0.8582338431066772, colsample_bytree=0.9149005519252036, gamma=0.44133633416958884, learning_rate=0.13264917739883875, max_depth=37, n_estimators=56, reg_alpha=1.612580293867052, reg_lambda=1.245436554359448, subsample=0.6374275467956716
# [CV 1/5; 16/500] END colsample_bylevel=0.770759101716597, colsample_bynode=0.8582338431066772, colsample_bytree=0.9149005519252036, gamma=0.44133633416958884, learning_rate=0.13264917739883875, max_depth=37, n_estimators=56, reg_alpha=1.612580293867052, reg_lambda=1.245436554359448, subsample=0.6374275467956716;, score=(train=0.961, test=0.812) total time=   0.4s
# [CV 1/5; 17/500] START colsample_bylevel=0.7545684753510645, colsample_bynode=0.7706527546576476, colsample_bytree=0.7714507904467052, gamma=1.65924616732735, learning_rate=0.07103684998818094, max_depth=38, n_estimators=135, reg_alpha=1.003653793515762, reg_lambda=0.2790239988317973, subsample=0.7560451118825682
# [CV 1/5; 17/500] END colsample_bylevel=0.7545684753510645, colsample_bynode=0.7706527546576476, colsample_bytree=0.7714507904467052, gamma=1.65924616732735, learning_rate=0.07103684998818094, max_depth=38, n_estimators=135, reg_alpha=1.003653793515762, reg_lambda=0.2790239988317973, subsample=0.7560451118825682;, score=(train=0.937, test=0.812) total time=   0.4s
# [CV 1/5; 19/500] START colsample_bylevel=0.7702337378051856, colsample_bynode=0.9191750091182809, colsample_bytree=0.7257403796056334, gamma=1.5806534698222174, learning_rate=0.08575689862206122, max_depth=18, n_estimators=110, reg_alpha=1.0523232788518013, reg_lambda=1.6934386396639838, subsample=0.9190970676594976
# [CV 1/5; 19/500] END colsample_bylevel=0.7702337378051856, colsample_bynode=0.9191750091182809, colsample_bytree=0.7257403796056334, gamma=1.5806534698222174, learning_rate=0.08575689862206122, max_depth=18, n_estimators=110, reg_alpha=1.0523232788518013, reg_lambda=1.6934386396639838, subsample=0.9190970676594976;, score=(train=0.930, test=0.803) total time=   0.4s
# [CV 5/5; 19/500] START colsample_bylevel=0.7702337378051856, colsample_bynode=0.9191750091182809, colsample_bytree=0.7257403796056334, gamma=1.5806534698222174, learning_rate=0.08575689862206122, max_depth=18, n_estimators=110, reg_alpha=1.0523232788518013, reg_lambda=1.6934386396639838, subsample=0.9190970676594976
# [CV 5/5; 19/500] END colsample_bylevel=0.7702337378051856, colsample_bynode=0.9191750091182809, colsample_bytree=0.7257403796056334, gamma=1.5806534698222174, learning_rate=0.08575689862206122, max_depth=18, n_estimators=110, reg_alpha=1.0523232788518013, reg_lambda=1.6934386396639838, subsample=0.9190970676594976;, score=(train=0.929, test=0.796) total time=   0.4s
# [CV 3/5; 21/500] START colsample_bylevel=0.8500741708521777, colsample_bynode=0.6573485113676256, colsample_bytree=0.9237012677848498, gamma=0.6256028217866627, learning_rate=0.12367496682511703, max_depth=24, n_estimators=100, reg_alpha=1.7614527024757474, reg_lambda=0.6713958497764496, subsample=0.7388393747761904
# [CV 3/5; 21/500] END colsample_bylevel=0.8500741708521777, colsample_bynode=0.6573485113676256, colsample_bytree=0.9237012677848498, gamma=0.6256028217866627, learning_rate=0.12367496682511703, max_depth=24, n_estimators=100, reg_alpha=1.7614527024757474, reg_lambda=0.6713958497764496, subsample=0.7388393747761904;, score=(train=0.971, test=0.845) total time=   0.5s
# [CV 1/5; 23/500] START colsample_bylevel=0.8870842676844022, colsample_bynode=0.9573636016796255, colsample_bytree=0.6934066761107801, gamma=1.77073418887134, learning_rate=0.11596931142436952, max_depth=15, n_estimators=81, reg_alpha=1.6141277589317704, reg_lambda=0.484112404644079, subsample=0.7183900956580538
# [CV 1/5; 23/500] END colsample_bylevel=0.8870842676844022, colsample_bynode=0.9573636016796255, colsample_bytree=0.6934066761107801, gamma=1.77073418887134, learning_rate=0.11596931142436952, max_depth=15, n_estimators=81, reg_alpha=1.6141277589317704, reg_lambda=0.484112404644079, subsample=0.7183900956580538;, score=(train=0.914, test=0.794) total time=   0.4s
# [CV 4/5; 24/500] START colsample_bylevel=0.9635969204750792, colsample_bynode=0.6702001337945912, colsample_bytree=0.8842088539478283, gamma=1.1767531865637313, learning_rate=0.13513446016939884, max_depth=32, n_estimators=75, reg_alpha=1.8535866086899315, reg_lambda=0.9348566517763248, subsample=0.9895741253399036
# [CV 4/5; 24/500] END colsample_bylevel=0.9635969204750792, colsample_bynode=0.6702001337945912, colsample_bytree=0.8842088539478283, gamma=1.1767531865637313, learning_rate=0.13513446016939884, max_depth=32, n_estimators=75, reg_alpha=1.8535866086899315, reg_lambda=0.9348566517763248, subsample=0.9895741253399036;, score=(train=0.929, test=0.788) total time=   0.3s
# [CV 2/5; 26/500] START colsample_bylevel=0.658810109627329, colsample_bynode=0.6852518566470772, colsample_bytree=0.7611493945133239, gamma=1.367273215069604, learning_rate=0.07270318756019317, max_depth=39, n_estimators=80, reg_alpha=0.5247197928001153, reg_lambda=1.7482566632917504, subsample=0.9771404363882572
# [CV 2/5; 26/500] END colsample_bylevel=0.658810109627329, colsample_bynode=0.6852518566470772, colsample_bytree=0.7611493945133239, gamma=1.367273215069604, learning_rate=0.07270318756019317, max_depth=39, n_estimators=80, reg_alpha=0.5247197928001153, reg_lambda=1.7482566632917504, subsample=0.9771404363882572;, score=(train=0.950, test=0.810) total time=   0.4s
# [CV 5/5; 26/500] START colsample_bylevel=0.658810109627329, colsample_bynode=0.6852518566470772, colsample_bytree=0.7611493945133239, gamma=1.367273215069604, learning_rate=0.07270318756019317, max_depth=39, n_estimators=80, reg_alpha=0.5247197928001153, reg_lambda=1.7482566632917504, subsample=0.9771404363882572
# [CV 5/5; 26/500] END colsample_bylevel=0.658810109627329, colsample_bynode=0.6852518566470772, colsample_bytree=0.7611493945133239, gamma=1.367273215069604, learning_rate=0.07270318756019317, max_depth=39, n_estimators=80, reg_alpha=0.5247197928001153, reg_lambda=1.7482566632917504, subsample=0.9771404363882572;, score=(train=0.944, test=0.804) total time=   0.4s
# [CV 1/5; 28/500] START colsample_bylevel=0.9835968428078504, colsample_bynode=0.934540676291174, colsample_bytree=0.7224558241481127, gamma=0.4768427551441512, learning_rate=0.11918256330190227, max_depth=34, n_estimators=135, reg_alpha=1.6107530416359785, reg_lambda=0.8420024232951926, subsample=0.9054326457824725
# [CV 1/5; 28/500] END colsample_bylevel=0.9835968428078504, colsample_bynode=0.934540676291174, colsample_bytree=0.7224558241481127, gamma=0.4768427551441512, learning_rate=0.11918256330190227, max_depth=34, n_estimators=135, reg_alpha=1.6107530416359785, reg_lambda=0.8420024232951926, subsample=0.9054326457824725;, score=(train=0.981, test=0.805) total time=   0.6s
# [CV 4/5; 29/500] START colsample_bylevel=0.9790720190308912, colsample_bynode=0.6343167746501043, colsample_bytree=0.682653438658888, gamma=0.7149882269972072, learning_rate=0.10504258950608747, max_depth=49, n_estimators=124, reg_alpha=0.6935084109348739, reg_lambda=0.5183569560913646, subsample=0.7811654115654973
# [CV 4/5; 29/500] END colsample_bylevel=0.9790720190308912, colsample_bynode=0.6343167746501043, colsample_bytree=0.682653438658888, gamma=0.7149882269972072, learning_rate=0.10504258950608747, max_depth=49, n_estimators=124, reg_alpha=0.6935084109348739, reg_lambda=0.5183569560913646, subsample=0.7811654115654973;, score=(train=0.984, test=0.800) total time=   0.5s
# [CV 2/5; 32/500] START colsample_bylevel=0.8174042565223767, colsample_bynode=0.7870697563603821, colsample_bytree=0.9993903010903709, gamma=1.933257205143138, learning_rate=0.1390960462457157, max_depth=38, n_estimators=103, reg_alpha=0.16100993193863, reg_lambda=0.28967814908432654, subsample=0.7731260639026175
# [CV 2/5; 32/500] END colsample_bylevel=0.8174042565223767, colsample_bynode=0.7870697563603821, colsample_bytree=0.9993903010903709, gamma=1.933257205143138, learning_rate=0.1390960462457157, max_depth=38, n_estimators=103, reg_alpha=0.16100993193863, reg_lambda=0.28967814908432654, subsample=0.7731260639026175;, score=(train=0.967, test=0.794) total time=   0.4s
# [CV 4/5; 32/500] START colsample_bylevel=0.8174042565223767, colsample_bynode=0.7870697563603821, colsample_bytree=0.9993903010903709, gamma=1.933257205143138, learning_rate=0.1390960462457157, max_depth=38, n_estimators=103, reg_alpha=0.16100993193863, reg_lambda=0.28967814908432654, subsample=0.7731260639026175
# [CV 4/5; 32/500] END colsample_bylevel=0.8174042565223767, colsample_bynode=0.7870697563603821, colsample_bytree=0.9993903010903709, gamma=1.933257205143138, learning_rate=0.1390960462457157, max_depth=38, n_estimators=103, reg_alpha=0.16100993193863, reg_lambda=0.28967814908432654, subsample=0.7731260639026175;, score=(train=0.962, test=0.803) total time=   0.3s
# [CV 5/5; 33/500] START colsample_bylevel=0.8290882553934326, colsample_bynode=0.8667352066037085, colsample_bytree=0.7387638380951648, gamma=0.7922536796761539, learning_rate=0.14427734916789026, max_depth=31, n_estimators=111, reg_alpha=0.032322257188798, reg_lambda=1.0848812765188705, subsample=0.7609543339516311
# [CV 5/5; 33/500] END colsample_bylevel=0.8290882553934326, colsample_bynode=0.8667352066037085, colsample_bytree=0.7387638380951648, gamma=0.7922536796761539, learning_rate=0.14427734916789026, max_depth=31, n_estimators=111, reg_alpha=0.032322257188798, reg_lambda=1.0848812765188705, subsample=0.7609543339516311;, score=(train=0.997, test=0.810) total time=   0.4s
# [CV 1/5; 1/500] START colsample_bylevel=0.9568623721184107, colsample_bynode=0.9675192403964803, colsample_bytree=0.7438389587386695, gamma=1.850842060817991, learning_rate=0.07355647037225387, max_depth=30, n_estimators=65, reg_alpha=1.5015903556461276, reg_lambda=1.7995961878471345, subsample=0.9897003095921357
# [CV 1/5; 1/500] END colsample_bylevel=0.9568623721184107, colsample_bynode=0.9675192403964803, colsample_bytree=0.7438389587386695, gamma=1.850842060817991, learning_rate=0.07355647037225387, max_depth=30, n_estimators=65, reg_alpha=1.5015903556461276, reg_lambda=1.7995961878471345, subsample=0.9897003095921357;, score=(train=0.905, test=0.798) total time=   0.4s
# [CV 2/5; 3/500] START colsample_bylevel=0.7847967251785161, colsample_bynode=0.6626516517825252, colsample_bytree=0.922542827216404, gamma=0.2575271803657049, learning_rate=0.08655512044711312, max_depth=39, n_estimators=140, reg_alpha=1.9762167624875888, reg_lambda=0.06384409799692592, subsample=0.6868162676021907
# [CV 2/5; 3/500] END colsample_bylevel=0.7847967251785161, colsample_bynode=0.6626516517825252, colsample_bytree=0.922542827216404, gamma=0.2575271803657049, learning_rate=0.08655512044711312, max_depth=39, n_estimators=140, reg_alpha=1.9762167624875888, reg_lambda=0.06384409799692592, subsample=0.6868162676021907;, score=(train=0.989, test=0.810) total time=   0.9s
# [CV 1/5; 5/500] START colsample_bylevel=0.6399632970910134, colsample_bynode=0.830043790558207, colsample_bytree=0.9859828633104645, gamma=1.536161035582145, learning_rate=0.09248867576966847, max_depth=44, n_estimators=105, reg_alpha=0.2051703234972555, reg_lambda=1.2809335508763429, subsample=0.7870591853513491
# [CV 1/5; 5/500] END colsample_bylevel=0.6399632970910134, colsample_bynode=0.830043790558207, colsample_bytree=0.9859828633104645, gamma=1.536161035582145, learning_rate=0.09248867576966847, max_depth=44, n_estimators=105, reg_alpha=0.2051703234972555, reg_lambda=1.2809335508763429, subsample=0.7870591853513491;, score=(train=0.960, test=0.794) total time=   0.6s
# [CV 5/5; 5/500] START colsample_bylevel=0.6399632970910134, colsample_bynode=0.830043790558207, colsample_bytree=0.9859828633104645, gamma=1.536161035582145, learning_rate=0.09248867576966847, max_depth=44, n_estimators=105, reg_alpha=0.2051703234972555, reg_lambda=1.2809335508763429, subsample=0.7870591853513491
# [CV 5/5; 5/500] END colsample_bylevel=0.6399632970910134, colsample_bynode=0.830043790558207, colsample_bytree=0.9859828633104645, gamma=1.536161035582145, learning_rate=0.09248867576966847, max_depth=44, n_estimators=105, reg_alpha=0.2051703234972555, reg_lambda=1.2809335508763429, subsample=0.7870591853513491;, score=(train=0.960, test=0.792) total time=   0.5s
# [CV 3/5; 7/500] START colsample_bylevel=0.9653997921985492, colsample_bynode=0.8080145237136216, colsample_bytree=0.6667045634676535, gamma=0.4509316501057161, learning_rate=0.11023392563745012, max_depth=47, n_estimators=83, reg_alpha=0.39280489372255656, reg_lambda=0.1283845345293797, subsample=0.8633978878950946
# [CV 3/5; 7/500] END colsample_bylevel=0.9653997921985492, colsample_bynode=0.8080145237136216, colsample_bytree=0.6667045634676535, gamma=0.4509316501057161, learning_rate=0.11023392563745012, max_depth=47, n_estimators=83, reg_alpha=0.39280489372255656, reg_lambda=0.1283845345293797, subsample=0.8633978878950946;, score=(train=1.000, test=0.874) total time=   0.7s
# [CV 1/5; 9/500] START colsample_bylevel=0.633738307012597, colsample_bynode=0.8246331956069743, colsample_bytree=0.886620053547295, gamma=0.17388236225878773, learning_rate=0.11514772310531148, max_depth=25, n_estimators=124, reg_alpha=1.8103276109557216, reg_lambda=0.07139398091285587, subsample=0.7944875156688678
# [CV 1/5; 9/500] END colsample_bylevel=0.633738307012597, colsample_bynode=0.8246331956069743, colsample_bytree=0.886620053547295, gamma=0.17388236225878773, learning_rate=0.11514772310531148, max_depth=25, n_estimators=124, reg_alpha=1.8103276109557216, reg_lambda=0.07139398091285587, subsample=0.7944875156688678;, score=(train=0.996, test=0.810) total time=   0.6s
# [CV 2/5; 11/500] START colsample_bylevel=0.9004601250293633, colsample_bynode=0.9176381602279653, colsample_bytree=0.9170372073632107, gamma=1.4976182752130043, learning_rate=0.056314144414918624, max_depth=44, n_estimators=68, reg_alpha=0.40419172508620504, reg_lambda=1.73598678931199, subsample=0.6417241873118315
# [CV 2/5; 11/500] END colsample_bylevel=0.9004601250293633, colsample_bynode=0.9176381602279653, colsample_bytree=0.9170372073632107, gamma=1.4976182752130043, learning_rate=0.056314144414918624, max_depth=44, n_estimators=68, reg_alpha=0.40419172508620504, reg_lambda=1.73598678931199, subsample=0.6417241873118315;, score=(train=0.935, test=0.808) total time=   0.5s
# [CV 5/5; 12/500] START colsample_bylevel=0.9996818803401167, colsample_bynode=0.9344395125565236, colsample_bytree=0.7582933490888369, gamma=0.7113681024636767, learning_rate=0.08662499859642216, max_depth=19, n_estimators=54, reg_alpha=0.22738512437271763, reg_lambda=1.1836646916010964, subsample=0.9324309091868348
# [CV 5/5; 12/500] END colsample_bylevel=0.9996818803401167, colsample_bynode=0.9344395125565236, colsample_bytree=0.7582933490888369, gamma=0.7113681024636767, learning_rate=0.08662499859642216, max_depth=19, n_estimators=54, reg_alpha=0.22738512437271763, reg_lambda=1.1836646916010964, subsample=0.9324309091868348;, score=(train=0.994, test=0.808) total time=   0.6s
# [CV 1/5; 15/500] START colsample_bylevel=0.6181772161807269, colsample_bynode=0.9670226485252632, colsample_bytree=0.6479168412134715, gamma=1.0069240128235066, learning_rate=0.06668488728557664, max_depth=28, n_estimators=114, reg_alpha=1.4686454690995945, reg_lambda=1.437727097680926, subsample=0.85577760077944
# [CV 1/5; 15/500] END colsample_bylevel=0.6181772161807269, colsample_bynode=0.9670226485252632, colsample_bytree=0.6479168412134715, gamma=1.0069240128235066, learning_rate=0.06668488728557664, max_depth=28, n_estimators=114, reg_alpha=1.4686454690995945, reg_lambda=1.437727097680926, subsample=0.85577760077944;, score=(train=0.942, test=0.794) total time=   0.5s
# [CV 5/5; 16/500] START colsample_bylevel=0.770759101716597, colsample_bynode=0.8582338431066772, colsample_bytree=0.9149005519252036, gamma=0.44133633416958884, learning_rate=0.13264917739883875, max_depth=37, n_estimators=56, reg_alpha=1.612580293867052, reg_lambda=1.245436554359448, subsample=0.6374275467956716
# [CV 5/5; 16/500] END colsample_bylevel=0.770759101716597, colsample_bynode=0.8582338431066772, colsample_bytree=0.9149005519252036, gamma=0.44133633416958884, learning_rate=0.13264917739883875, max_depth=37, n_estimators=56, reg_alpha=1.612580293867052, reg_lambda=1.245436554359448, subsample=0.6374275467956716;, score=(train=0.961, test=0.796) total time=   0.4s
# [CV 3/5; 18/500] START colsample_bylevel=0.6803438466115439, colsample_bynode=0.7036781638386517, colsample_bytree=0.8333131899163316, gamma=0.22568041392941107, learning_rate=0.11235110757720122, max_depth=18, n_estimators=103, reg_alpha=1.7495218841173537, reg_lambda=0.40241629631611797, subsample=0.8184568949589517
# [CV 3/5; 18/500] END colsample_bylevel=0.6803438466115439, colsample_bynode=0.7036781638386517, colsample_bytree=0.8333131899163316, gamma=0.22568041392941107, learning_rate=0.11235110757720122, max_depth=18, n_estimators=103, reg_alpha=1.7495218841173537, reg_lambda=0.40241629631611797, subsample=0.8184568949589517;, score=(train=0.990, test=0.855) total time=   0.5s
# [CV 4/5; 20/500] START colsample_bylevel=0.6328021340640755, colsample_bynode=0.9043425293919043, colsample_bytree=0.9382638299035716, gamma=0.05878629515286815, learning_rate=0.14441859149049835, max_depth=29, n_estimators=50, reg_alpha=1.9705964211209064, reg_lambda=1.5472330589518661, subsample=0.8087541712949463
# [CV 4/5; 20/500] END colsample_bylevel=0.6328021340640755, colsample_bynode=0.9043425293919043, colsample_bytree=0.9382638299035716, gamma=0.05878629515286815, learning_rate=0.14441859149049835, max_depth=29, n_estimators=50, reg_alpha=1.9705964211209064, reg_lambda=1.5472330589518661, subsample=0.8087541712949463;, score=(train=0.975, test=0.810) total time=   0.4s
# [CV 1/5; 22/500] START colsample_bylevel=0.7639273070432742, colsample_bynode=0.631130947851306, colsample_bytree=0.9540416447206244, gamma=1.4585755361899524, learning_rate=0.05225497334103986, max_depth=16, n_estimators=61, reg_alpha=1.3225812819633604, reg_lambda=0.04916747100127061, subsample=0.6804719053584054
# [CV 1/5; 22/500] END colsample_bylevel=0.7639273070432742, colsample_bynode=0.631130947851306, colsample_bytree=0.9540416447206244, gamma=1.4585755361899524, learning_rate=0.05225497334103986, max_depth=16, n_estimators=61, reg_alpha=1.3225812819633604, reg_lambda=0.04916747100127061, subsample=0.6804719053584054;, score=(train=0.912, test=0.793) total time=   0.4s
# [CV 5/5; 23/500] START colsample_bylevel=0.8870842676844022, colsample_bynode=0.9573636016796255, colsample_bytree=0.6934066761107801, gamma=1.77073418887134, learning_rate=0.11596931142436952, max_depth=15, n_estimators=81, reg_alpha=1.6141277589317704, reg_lambda=0.484112404644079, subsample=0.7183900956580538
# [CV 5/5; 23/500] END colsample_bylevel=0.8870842676844022, colsample_bynode=0.9573636016796255, colsample_bytree=0.6934066761107801, gamma=1.77073418887134, learning_rate=0.11596931142436952, max_depth=15, n_estimators=81, reg_alpha=1.6141277589317704, reg_lambda=0.484112404644079, subsample=0.7183900956580538;, score=(train=0.909, test=0.787) total time=   0.4s
# [CV 1/5; 26/500] START colsample_bylevel=0.658810109627329, colsample_bynode=0.6852518566470772, colsample_bytree=0.7611493945133239, gamma=1.367273215069604, learning_rate=0.07270318756019317, max_depth=39, n_estimators=80, reg_alpha=0.5247197928001153, reg_lambda=1.7482566632917504, subsample=0.9771404363882572
# [CV 1/5; 26/500] END colsample_bylevel=0.658810109627329, colsample_bynode=0.6852518566470772, colsample_bytree=0.7611493945133239, gamma=1.367273215069604, learning_rate=0.07270318756019317, max_depth=39, n_estimators=80, reg_alpha=0.5247197928001153, reg_lambda=1.7482566632917504, subsample=0.9771404363882572;, score=(train=0.947, test=0.794) total time=   0.4s
# [CV 4/5; 26/500] START colsample_bylevel=0.658810109627329, colsample_bynode=0.6852518566470772, colsample_bytree=0.7611493945133239, gamma=1.367273215069604, learning_rate=0.07270318756019317, max_depth=39, n_estimators=80, reg_alpha=0.5247197928001153, reg_lambda=1.7482566632917504, subsample=0.9771404363882572
# [CV 4/5; 26/500] END colsample_bylevel=0.658810109627329, colsample_bynode=0.6852518566470772, colsample_bytree=0.7611493945133239, gamma=1.367273215069604, learning_rate=0.07270318756019317, max_depth=39, n_estimators=80, reg_alpha=0.5247197928001153, reg_lambda=1.7482566632917504, subsample=0.9771404363882572;, score=(train=0.943, test=0.798) total time=   0.4s
# [CV 2/5; 27/500] START colsample_bylevel=0.6251017167726455, colsample_bynode=0.8104359319862702, colsample_bytree=0.7993557548535114, gamma=1.7874527446800705, learning_rate=0.11845793353968188, max_depth=15, n_estimators=95, reg_alpha=1.1338402124586218, reg_lambda=0.12524286961530828, subsample=0.6309370422526593
# [CV 2/5; 27/500] END colsample_bylevel=0.6251017167726455, colsample_bynode=0.8104359319862702, colsample_bytree=0.7993557548535114, gamma=1.7874527446800705, learning_rate=0.11845793353968188, max_depth=15, n_estimators=95, reg_alpha=1.1338402124586218, reg_lambda=0.12524286961530828, subsample=0.6309370422526593;, score=(train=0.914, test=0.788) total time=   0.3s
# [CV 2/5; 29/500] START colsample_bylevel=0.9790720190308912, colsample_bynode=0.6343167746501043, colsample_bytree=0.682653438658888, gamma=0.7149882269972072, learning_rate=0.10504258950608747, max_depth=49, n_estimators=124, reg_alpha=0.6935084109348739, reg_lambda=0.5183569560913646, subsample=0.7811654115654973
# [CV 2/5; 29/500] END colsample_bylevel=0.9790720190308912, colsample_bynode=0.6343167746501043, colsample_bytree=0.682653438658888, gamma=0.7149882269972072, learning_rate=0.10504258950608747, max_depth=49, n_estimators=124, reg_alpha=0.6935084109348739, reg_lambda=0.5183569560913646, subsample=0.7811654115654973;, score=(train=0.988, test=0.807) total time=   0.5s
# [CV 4/5; 30/500] START colsample_bylevel=0.9736922484686159, colsample_bynode=0.6265388673767697, colsample_bytree=0.7343702809059814, gamma=1.633615501483615, learning_rate=0.06638915810720412, max_depth=37, n_estimators=96, reg_alpha=1.859926818110794, reg_lambda=0.5686087235649511, subsample=0.7494695670668701
# [CV 4/5; 30/500] END colsample_bylevel=0.9736922484686159, colsample_bynode=0.6265388673767697, colsample_bytree=0.7343702809059814, gamma=1.633615501483615, learning_rate=0.06638915810720412, max_depth=37, n_estimators=96, reg_alpha=1.859926818110794, reg_lambda=0.5686087235649511, subsample=0.7494695670668701;, score=(train=0.899, test=0.774) total time=   0.3s
# [CV 5/5; 31/500] START colsample_bylevel=0.611985010954069, colsample_bynode=0.8937605972349278, colsample_bytree=0.8786137550049384, gamma=0.2749042129723831, learning_rate=0.10519082745304872, max_depth=26, n_estimators=129, reg_alpha=0.09760424306047644, reg_lambda=0.1174803982062611, subsample=0.6165514120030219
# [CV 5/5; 31/500] END colsample_bylevel=0.611985010954069, colsample_bynode=0.8937605972349278, colsample_bytree=0.8786137550049384, gamma=0.2749042129723831, learning_rate=0.10519082745304872, max_depth=26, n_estimators=129, reg_alpha=0.09760424306047644, reg_lambda=0.1174803982062611, subsample=0.6165514120030219;, score=(train=1.000, test=0.799) total time=   0.8s
# [CV 2/5; 34/500] START colsample_bylevel=0.6502765889359922, colsample_bynode=0.7347360039080868, colsample_bytree=0.9216576894624933, gamma=1.8451637594979322, learning_rate=0.14208098161245303, max_depth=48, n_estimators=83, reg_alpha=1.1865319252361108, reg_lambda=1.1907802560527232, subsample=0.7147642506095271
# [CV 2/5; 34/500] END colsample_bylevel=0.6502765889359922, colsample_bynode=0.7347360039080868, colsample_bytree=0.9216576894624933, gamma=1.8451637594979322, learning_rate=0.14208098161245303, max_depth=48, n_estimators=83, reg_alpha=1.1865319252361108, reg_lambda=1.1907802560527232, subsample=0.7147642506095271;, score=(train=0.912, test=0.793) total time=   0.3s
# [CV 2/5; 35/500] START colsample_bylevel=0.6212045465588849, colsample_bynode=0.7153912319891604, colsample_bytree=0.9939126701260267, gamma=1.2126665547977635, learning_rate=0.07247172444203286, max_depth=32, n_estimators=54, reg_alpha=0.24183098948288806, reg_lambda=1.4191792772817227, subsample=0.8815735775368511
# [CV 2/5; 35/500] END colsample_bylevel=0.6212045465588849, colsample_bynode=0.7153912319891604, colsample_bytree=0.9939126701260267, gamma=1.2126665547977635, learning_rate=0.07247172444203286, max_depth=32, n_estimators=54, reg_alpha=0.24183098948288806, reg_lambda=1.4191792772817227, subsample=0.8815735775368511;, score=(train=0.963, test=0.813) total time=   0.5s
# [CV 2/5; 37/500] START colsample_bylevel=0.7429053327961056, colsample_bynode=0.7015250604611424, colsample_bytree=0.8187127049444709, gamma=1.9442478980963538, learning_rate=0.051764122594187736, max_depth=30, n_estimators=92, reg_alpha=0.04113185720171986, reg_lambda=1.9538137911947664, subsample=0.9974565967215258
# [CV 2/5; 37/500] END colsample_bylevel=0.7429053327961056, colsample_bynode=0.7015250604611424, colsample_bytree=0.8187127049444709, gamma=1.9442478980963538, learning_rate=0.051764122594187736, max_depth=30, n_estimators=92, reg_alpha=0.04113185720171986, reg_lambda=1.9538137911947664, subsample=0.9974565967215258;, score=(train=0.939, test=0.810) total time=   0.4s
# [CV 2/5; 1/500] START colsample_bylevel=0.9568623721184107, colsample_bynode=0.9675192403964803, colsample_bytree=0.7438389587386695, gamma=1.850842060817991, learning_rate=0.07355647037225387, max_depth=30, n_estimators=65, reg_alpha=1.5015903556461276, reg_lambda=1.7995961878471345, subsample=0.9897003095921357
# [CV 2/5; 1/500] END colsample_bylevel=0.9568623721184107, colsample_bynode=0.9675192403964803, colsample_bytree=0.7438389587386695, gamma=1.850842060817991, learning_rate=0.07355647037225387, max_depth=30, n_estimators=65, reg_alpha=1.5015903556461276, reg_lambda=1.7995961878471345, subsample=0.9897003095921357;, score=(train=0.910, test=0.807) total time=   0.5s
# [CV 3/5; 3/500] START colsample_bylevel=0.7847967251785161, colsample_bynode=0.6626516517825252, colsample_bytree=0.922542827216404, gamma=0.2575271803657049, learning_rate=0.08655512044711312, max_depth=39, n_estimators=140, reg_alpha=1.9762167624875888, reg_lambda=0.06384409799692592, subsample=0.6868162676021907
# [CV 3/5; 3/500] END colsample_bylevel=0.7847967251785161, colsample_bynode=0.6626516517825252, colsample_bytree=0.922542827216404, gamma=0.2575271803657049, learning_rate=0.08655512044711312, max_depth=39, n_estimators=140, reg_alpha=1.9762167624875888, reg_lambda=0.06384409799692592, subsample=0.6868162676021907;, score=(train=0.987, test=0.867) total time=   0.8s
# [CV 5/5; 4/500] START colsample_bylevel=0.8820320888853248, colsample_bynode=0.6828062870048309, colsample_bytree=0.6995383728648709, gamma=0.63821165378832, learning_rate=0.05330349504099492, max_depth=18, n_estimators=140, reg_alpha=1.2476994972824913, reg_lambda=0.8055486941031111, subsample=0.8766823158134913
# [CV 5/5; 4/500] END colsample_bylevel=0.8820320888853248, colsample_bynode=0.6828062870048309, colsample_bytree=0.6995383728648709, gamma=0.63821165378832, learning_rate=0.05330349504099492, max_depth=18, n_estimators=140, reg_alpha=1.2476994972824913, reg_lambda=0.8055486941031111, subsample=0.8766823158134913;, score=(train=0.975, test=0.801) total time=   0.8s
# [CV 1/5; 7/500] START colsample_bylevel=0.9653997921985492, colsample_bynode=0.8080145237136216, colsample_bytree=0.6667045634676535, gamma=0.4509316501057161, learning_rate=0.11023392563745012, max_depth=47, n_estimators=83, reg_alpha=0.39280489372255656, reg_lambda=0.1283845345293797, subsample=0.8633978878950946
# [CV 1/5; 7/500] END colsample_bylevel=0.9653997921985492, colsample_bynode=0.8080145237136216, colsample_bytree=0.6667045634676535, gamma=0.4509316501057161, learning_rate=0.11023392563745012, max_depth=47, n_estimators=83, reg_alpha=0.39280489372255656, reg_lambda=0.1283845345293797, subsample=0.8633978878950946;, score=(train=1.000, test=0.813) total time=   0.6s
# [CV 4/5; 8/500] START colsample_bylevel=0.9366671923268144, colsample_bynode=0.9056226526589617, colsample_bytree=0.9764097304774897, gamma=0.9171229663605314, learning_rate=0.1286166123678995, max_depth=43, n_estimators=146, reg_alpha=0.8519981144395732, reg_lambda=1.0999758176395875, subsample=0.789072663615132
# [CV 4/5; 8/500] END colsample_bylevel=0.9366671923268144, colsample_bynode=0.9056226526589617, colsample_bytree=0.9764097304774897, gamma=0.9171229663605314, learning_rate=0.1286166123678995, max_depth=43, n_estimators=146, reg_alpha=0.8519981144395732, reg_lambda=1.0999758176395875, subsample=0.789072663615132;, score=(train=0.977, test=0.803) total time=   0.5s
# [CV 2/5; 10/500] START colsample_bylevel=0.6222690618256155, colsample_bynode=0.9991806128434747, colsample_bytree=0.7378282677338055, gamma=1.4861992428997064, learning_rate=0.10058331002812909, max_depth=40, n_estimators=74, reg_alpha=0.3280688522403925, reg_lambda=1.9536126546267405, subsample=0.7383400743303974
# [CV 2/5; 10/500] END colsample_bylevel=0.6222690618256155, colsample_bynode=0.9991806128434747, colsample_bytree=0.7378282677338055, gamma=1.4861992428997064, learning_rate=0.10058331002812909, max_depth=40, n_estimators=74, reg_alpha=0.3280688522403925, reg_lambda=1.9536126546267405, subsample=0.7383400743303974;, score=(train=0.940, test=0.791) total time=   0.3s
# [CV 5/5; 10/500] START colsample_bylevel=0.6222690618256155, colsample_bynode=0.9991806128434747, colsample_bytree=0.7378282677338055, gamma=1.4861992428997064, learning_rate=0.10058331002812909, max_depth=40, n_estimators=74, reg_alpha=0.3280688522403925, reg_lambda=1.9536126546267405, subsample=0.7383400743303974
# [CV 5/5; 10/500] END colsample_bylevel=0.6222690618256155, colsample_bynode=0.9991806128434747, colsample_bytree=0.7378282677338055, gamma=1.4861992428997064, learning_rate=0.10058331002812909, max_depth=40, n_estimators=74, reg_alpha=0.3280688522403925, reg_lambda=1.9536126546267405, subsample=0.7383400743303974;, score=(train=0.945, test=0.789) total time=   0.3s
# [CV 2/5; 12/500] START colsample_bylevel=0.9996818803401167, colsample_bynode=0.9344395125565236, colsample_bytree=0.7582933490888369, gamma=0.7113681024636767, learning_rate=0.08662499859642216, max_depth=19, n_estimators=54, reg_alpha=0.22738512437271763, reg_lambda=1.1836646916010964, subsample=0.9324309091868348
# [CV 2/5; 12/500] END colsample_bylevel=0.9996818803401167, colsample_bynode=0.9344395125565236, colsample_bytree=0.7582933490888369, gamma=0.7113681024636767, learning_rate=0.08662499859642216, max_depth=19, n_estimators=54, reg_alpha=0.22738512437271763, reg_lambda=1.1836646916010964, subsample=0.9324309091868348;, score=(train=0.994, test=0.813) total time=   0.6s
# [CV 5/5; 13/500] START colsample_bylevel=0.8739019326091273, colsample_bynode=0.6882555794071881, colsample_bytree=0.8731233968079095, gamma=1.4486265657285309, learning_rate=0.06369599468513854, max_depth=40, n_estimators=106, reg_alpha=0.9871551075285538, reg_lambda=0.9772319603408579, subsample=0.7510348055080096
# [CV 5/5; 13/500] END colsample_bylevel=0.8739019326091273, colsample_bynode=0.6882555794071881, colsample_bytree=0.8731233968079095, gamma=1.4486265657285309, learning_rate=0.06369599468513854, max_depth=40, n_estimators=106, reg_alpha=0.9871551075285538, reg_lambda=0.9772319603408579, subsample=0.7510348055080096;, score=(train=0.934, test=0.804) total time=   0.5s
# [CV 2/5; 16/500] START colsample_bylevel=0.770759101716597, colsample_bynode=0.8582338431066772, colsample_bytree=0.9149005519252036, gamma=0.44133633416958884, learning_rate=0.13264917739883875, max_depth=37, n_estimators=56, reg_alpha=1.612580293867052, reg_lambda=1.245436554359448, subsample=0.6374275467956716
# [CV 2/5; 16/500] END colsample_bylevel=0.770759101716597, colsample_bynode=0.8582338431066772, colsample_bytree=0.9149005519252036, gamma=0.44133633416958884, learning_rate=0.13264917739883875, max_depth=37, n_estimators=56, reg_alpha=1.612580293867052, reg_lambda=1.245436554359448, subsample=0.6374275467956716;, score=(train=0.959, test=0.793) total time=   0.4s
# [CV 4/5; 17/500] START colsample_bylevel=0.7545684753510645, colsample_bynode=0.7706527546576476, colsample_bytree=0.7714507904467052, gamma=1.65924616732735, learning_rate=0.07103684998818094, max_depth=38, n_estimators=135, reg_alpha=1.003653793515762, reg_lambda=0.2790239988317973, subsample=0.7560451118825682
# [CV 4/5; 17/500] END colsample_bylevel=0.7545684753510645, colsample_bynode=0.7706527546576476, colsample_bytree=0.7714507904467052, gamma=1.65924616732735, learning_rate=0.07103684998818094, max_depth=38, n_estimators=135, reg_alpha=1.003653793515762, reg_lambda=0.2790239988317973, subsample=0.7560451118825682;, score=(train=0.933, test=0.798) total time=   0.4s
# [CV 4/5; 18/500] START colsample_bylevel=0.6803438466115439, colsample_bynode=0.7036781638386517, colsample_bytree=0.8333131899163316, gamma=0.22568041392941107, learning_rate=0.11235110757720122, max_depth=18, n_estimators=103, reg_alpha=1.7495218841173537, reg_lambda=0.40241629631611797, subsample=0.8184568949589517
# [CV 4/5; 18/500] END colsample_bylevel=0.6803438466115439, colsample_bynode=0.7036781638386517, colsample_bytree=0.8333131899163316, gamma=0.22568041392941107, learning_rate=0.11235110757720122, max_depth=18, n_estimators=103, reg_alpha=1.7495218841173537, reg_lambda=0.40241629631611797, subsample=0.8184568949589517;, score=(train=0.989, test=0.796) total time=   0.6s
# [CV 2/5; 21/500] START colsample_bylevel=0.8500741708521777, colsample_bynode=0.6573485113676256, colsample_bytree=0.9237012677848498, gamma=0.6256028217866627, learning_rate=0.12367496682511703, max_depth=24, n_estimators=100, reg_alpha=1.7614527024757474, reg_lambda=0.6713958497764496, subsample=0.7388393747761904
# [CV 2/5; 21/500] END colsample_bylevel=0.8500741708521777, colsample_bynode=0.6573485113676256, colsample_bytree=0.9237012677848498, gamma=0.6256028217866627, learning_rate=0.12367496682511703, max_depth=24, n_estimators=100, reg_alpha=1.7614527024757474, reg_lambda=0.6713958497764496, subsample=0.7388393747761904;, score=(train=0.971, test=0.807) total time=   0.5s
# [CV 4/5; 22/500] START colsample_bylevel=0.7639273070432742, colsample_bynode=0.631130947851306, colsample_bytree=0.9540416447206244, gamma=1.4585755361899524, learning_rate=0.05225497334103986, max_depth=16, n_estimators=61, reg_alpha=1.3225812819633604, reg_lambda=0.04916747100127061, subsample=0.6804719053584054
# [CV 4/5; 22/500] END colsample_bylevel=0.7639273070432742, colsample_bynode=0.631130947851306, colsample_bytree=0.9540416447206244, gamma=1.4585755361899524, learning_rate=0.05225497334103986, max_depth=16, n_estimators=61, reg_alpha=1.3225812819633604, reg_lambda=0.04916747100127061, subsample=0.6804719053584054;, score=(train=0.912, test=0.796) total time=   0.3s
# [CV 4/5; 23/500] START colsample_bylevel=0.8870842676844022, colsample_bynode=0.9573636016796255, colsample_bytree=0.6934066761107801, gamma=1.77073418887134, learning_rate=0.11596931142436952, max_depth=15, n_estimators=81, reg_alpha=1.6141277589317704, reg_lambda=0.484112404644079, subsample=0.7183900956580538
# [CV 4/5; 23/500] END colsample_bylevel=0.8870842676844022, colsample_bynode=0.9573636016796255, colsample_bytree=0.6934066761107801, gamma=1.77073418887134, learning_rate=0.11596931142436952, max_depth=15, n_estimators=81, reg_alpha=1.6141277589317704, reg_lambda=0.484112404644079, subsample=0.7183900956580538;, score=(train=0.907, test=0.786) total time=   0.4s
# [CV 5/5; 25/500] START colsample_bylevel=0.9892724945690217, colsample_bynode=0.9126730815885712, colsample_bytree=0.8250061687989761, gamma=0.011792435927757028, learning_rate=0.08580618084222558, max_depth=46, n_estimators=81, reg_alpha=1.88193429958873, reg_lambda=0.9932706626057772, subsample=0.7887892916285836
# [CV 5/5; 25/500] END colsample_bylevel=0.9892724945690217, colsample_bynode=0.9126730815885712, colsample_bytree=0.8250061687989761, gamma=0.011792435927757028, learning_rate=0.08580618084222558, max_depth=46, n_estimators=81, reg_alpha=1.88193429958873, reg_lambda=0.9932706626057772, subsample=0.7887892916285836;, score=(train=0.988, test=0.794) total time=   0.9s
# [CV 3/5; 27/500] START colsample_bylevel=0.6251017167726455, colsample_bynode=0.8104359319862702, colsample_bytree=0.7993557548535114, gamma=1.7874527446800705, learning_rate=0.11845793353968188, max_depth=15, n_estimators=95, reg_alpha=1.1338402124586218, reg_lambda=0.12524286961530828, subsample=0.6309370422526593
# [CV 3/5; 27/500] END colsample_bylevel=0.6251017167726455, colsample_bynode=0.8104359319862702, colsample_bytree=0.7993557548535114, gamma=1.7874527446800705, learning_rate=0.11845793353968188, max_depth=15, n_estimators=95, reg_alpha=1.1338402124586218, reg_lambda=0.12524286961530828, subsample=0.6309370422526593;, score=(train=0.915, test=0.869) total time=   0.3s
# [CV 5/5; 28/500] START colsample_bylevel=0.9835968428078504, colsample_bynode=0.934540676291174, colsample_bytree=0.7224558241481127, gamma=0.4768427551441512, learning_rate=0.11918256330190227, max_depth=34, n_estimators=135, reg_alpha=1.6107530416359785, reg_lambda=0.8420024232951926, subsample=0.9054326457824725
# [CV 5/5; 28/500] END colsample_bylevel=0.9835968428078504, colsample_bynode=0.934540676291174, colsample_bytree=0.7224558241481127, gamma=0.4768427551441512, learning_rate=0.11918256330190227, max_depth=34, n_estimators=135, reg_alpha=1.6107530416359785, reg_lambda=0.8420024232951926, subsample=0.9054326457824725;, score=(train=0.986, test=0.799) total time=   0.7s
# [CV 1/5; 31/500] START colsample_bylevel=0.611985010954069, colsample_bynode=0.8937605972349278, colsample_bytree=0.8786137550049384, gamma=0.2749042129723831, learning_rate=0.10519082745304872, max_depth=26, n_estimators=129, reg_alpha=0.09760424306047644, reg_lambda=0.1174803982062611, subsample=0.6165514120030219
# [CV 1/5; 31/500] END colsample_bylevel=0.611985010954069, colsample_bynode=0.8937605972349278, colsample_bytree=0.8786137550049384, gamma=0.2749042129723831, learning_rate=0.10519082745304872, max_depth=26, n_estimators=129, reg_alpha=0.09760424306047644, reg_lambda=0.1174803982062611, subsample=0.6165514120030219;, score=(train=1.000, test=0.810) total time=   0.8s
# [CV 2/5; 33/500] START colsample_bylevel=0.8290882553934326, colsample_bynode=0.8667352066037085, colsample_bytree=0.7387638380951648, gamma=0.7922536796761539, learning_rate=0.14427734916789026, max_depth=31, n_estimators=111, reg_alpha=0.032322257188798, reg_lambda=1.0848812765188705, subsample=0.7609543339516311
# [CV 2/5; 33/500] END colsample_bylevel=0.8290882553934326, colsample_bynode=0.8667352066037085, colsample_bytree=0.7387638380951648, gamma=0.7922536796761539, learning_rate=0.14427734916789026, max_depth=31, n_estimators=111, reg_alpha=0.032322257188798, reg_lambda=1.0848812765188705, subsample=0.7609543339516311;, score=(train=0.997, test=0.793) total time=   0.4s
# [CV 1/5; 35/500] START colsample_bylevel=0.6212045465588849, colsample_bynode=0.7153912319891604, colsample_bytree=0.9939126701260267, gamma=1.2126665547977635, learning_rate=0.07247172444203286, max_depth=32, n_estimators=54, reg_alpha=0.24183098948288806, reg_lambda=1.4191792772817227, subsample=0.8815735775368511
# [CV 1/5; 35/500] END colsample_bylevel=0.6212045465588849, colsample_bynode=0.7153912319891604, colsample_bytree=0.9939126701260267, gamma=1.2126665547977635, learning_rate=0.07247172444203286, max_depth=32, n_estimators=54, reg_alpha=0.24183098948288806, reg_lambda=1.4191792772817227, subsample=0.8815735775368511;, score=(train=0.966, test=0.815) total time=   0.4s
# [CV 4/5; 36/500] START colsample_bylevel=0.7086150588478461, colsample_bynode=0.9341157407916101, colsample_bytree=0.7062256458235723, gamma=1.1258743160663542, learning_rate=0.08117478432038895, max_depth=44, n_estimators=124, reg_alpha=1.0353303115188224, reg_lambda=1.7544976288320286, subsample=0.9415046135965655
# [CV 4/5; 36/500] END colsample_bylevel=0.7086150588478461, colsample_bynode=0.9341157407916101, colsample_bytree=0.7062256458235723, gamma=1.1258743160663542, learning_rate=0.08117478432038895, max_depth=44, n_estimators=124, reg_alpha=1.0353303115188224, reg_lambda=1.7544976288320286, subsample=0.9415046135965655;, score=(train=0.948, test=0.791) total time=   0.5s
# [CV 2/5; 38/500] START colsample_bylevel=0.8533379974187558, colsample_bynode=0.7689041541199688, colsample_bytree=0.6139042603778949, gamma=0.329774285497058, learning_rate=0.08880491966245235, max_depth=30, n_estimators=105, reg_alpha=1.8740961107816287, reg_lambda=1.0504147487068114, subsample=0.7300579341940454
# [CV 2/5; 38/500] END colsample_bylevel=0.8533379974187558, colsample_bynode=0.7689041541199688, colsample_bytree=0.6139042603778949, gamma=0.329774285497058, learning_rate=0.08880491966245235, max_depth=30, n_estimators=105, reg_alpha=1.8740961107816287, reg_lambda=1.0504147487068114, subsample=0.7300579341940454;, score=(train=0.971, test=0.791) total time=   0.6s
# [CV 1/5; 2/500] START colsample_bylevel=0.6398760460621272, colsample_bynode=0.6604297339327864, colsample_bytree=0.8909285194831833, gamma=0.4561738017712562, learning_rate=0.07795562585902209, max_depth=24, n_estimators=86, reg_alpha=0.010790441341474333, reg_lambda=1.8140258781293448, subsample=0.8589472484759024
# [CV 1/5; 2/500] END colsample_bylevel=0.6398760460621272, colsample_bynode=0.6604297339327864, colsample_bytree=0.8909285194831833, gamma=0.4561738017712562, learning_rate=0.07795562585902209, max_depth=24, n_estimators=86, reg_alpha=0.010790441341474333, reg_lambda=1.8140258781293448, subsample=0.8589472484759024;, score=(train=0.999, test=0.808) total time=   0.8s
# ...
# [CV 1/5; 189/500] START colsample_bylevel=0.8345613993604226, colsample_bynode=0.8096305249022304, colsample_bytree=0.7510366471125143, gamma=1.8593882749077053, learning_rate=0.11164953481454304, max_depth=22, n_estimators=127, reg_alpha=1.1039273297862957, reg_lambda=0.8080214252295805, subsample=0.6476557906123913
# [CV 1/5; 189/500] END colsample_bylevel=0.8345613993604226, colsample_bynode=0.8096305249022304, colsample_bytree=0.7510366471125143, gamma=1.8593882749077053, learning_rate=0.11164953481454304, max_depth=22, n_estimators=127, reg_alpha=1.1039273297862957, reg_lambda=0.8080214252295805, subsample=0.6476557906123913;, score=(train=0.922, test=0.801) total time=   0.3s
# [CV 1/5; 190/500] START colsample_bylevel=0.8651412035031776, colsample_bynode=0.9302956095071913, colsample_bytree=0.8200195071390025, gamma=0.018222869660705854, learning_rate=0.06044526574719425, max_depth=48, n_estimators=93, reg_alpha=1.4020227662549396, reg_lambda=1.331596231155463, subsample=0.8457539611427933
# [CV 1/5; 190/500] END colsample_bylevel=0.8651412035031776, colsample_bynode=0.9302956095071913, colsample_bytree=0.8200195071390025, gamma=0.018222869660705854, learning_rate=0.06044526574719425, max_depth=48, n_estimators=93, reg_alpha=1.4020227662549396, reg_lambda=1.331596231155463, subsample=0.8457539611427933;, score=(train=0.987, test=0.815) total time=   1.1s
# [CV 2/5; 192/500] START colsample_bylevel=0.8691364392995673, colsample_bynode=0.8371275887562587, colsample_bytree=0.6914150233894707, gamma=1.895023697482973, learning_rate=0.1360449839898923, max_depth=45, n_estimators=134, reg_alpha=0.8988079194781133, reg_lambda=0.09164714272741747, subsample=0.8949329117764958
# [CV 2/5; 192/500] END colsample_bylevel=0.8691364392995673, colsample_bynode=0.8371275887562587, colsample_bytree=0.6914150233894707, gamma=1.895023697482973, learning_rate=0.1360449839898923, max_depth=45, n_estimators=134, reg_alpha=0.8988079194781133, reg_lambda=0.09164714272741747, subsample=0.8949329117764958;, score=(train=0.938, test=0.789) total time=   0.3s
# [CV 5/5; 193/500] START colsample_bylevel=0.6082352573057229, colsample_bynode=0.6986641422514426, colsample_bytree=0.7787885475515941, gamma=0.23475186373318713, learning_rate=0.13060603127015769, max_depth=41, n_estimators=99, reg_alpha=1.9086531356709884, reg_lambda=1.949371995116366, subsample=0.916178667834612
# [CV 5/5; 193/500] END colsample_bylevel=0.6082352573057229, colsample_bynode=0.6986641422514426, colsample_bytree=0.7787885475515941, gamma=0.23475186373318713, learning_rate=0.13060603127015769, max_depth=41, n_estimators=99, reg_alpha=1.9086531356709884, reg_lambda=1.949371995116366, subsample=0.916178667834612;, score=(train=0.984, test=0.791) total time=   0.5s
# [CV 3/5; 195/500] START colsample_bylevel=0.9127869320777723, colsample_bynode=0.8232642232727274, colsample_bytree=0.9229089822222702, gamma=1.4060871838701043, learning_rate=0.06920030374617588, max_depth=26, n_estimators=67, reg_alpha=1.9390153156112122, reg_lambda=0.8135672389154487, subsample=0.8458360275747049
# [CV 3/5; 195/500] END colsample_bylevel=0.9127869320777723, colsample_bynode=0.8232642232727274, colsample_bytree=0.9229089822222702, gamma=1.4060871838701043, learning_rate=0.06920030374617588, max_depth=26, n_estimators=67, reg_alpha=1.9390153156112122, reg_lambda=0.8135672389154487, subsample=0.8458360275747049;, score=(train=0.910, test=0.867) total time=   0.5s
# [CV 1/5; 197/500] START colsample_bylevel=0.721689308725641, colsample_bynode=0.8913009052684893, colsample_bytree=0.8242477288575718, gamma=0.024144013553912602, learning_rate=0.07256513445183671, max_depth=31, n_estimators=104, reg_alpha=1.4254875302300407, reg_lambda=1.1198347083564446, subsample=0.8439682822338826
# [CV 1/5; 197/500] END colsample_bylevel=0.721689308725641, colsample_bynode=0.8913009052684893, colsample_bytree=0.8242477288575718, gamma=0.024144013553912602, learning_rate=0.07256513445183671, max_depth=31, n_estimators=104, reg_alpha=1.4254875302300407, reg_lambda=1.1198347083564446, subsample=0.8439682822338826;, score=(train=0.996, test=0.808) total time=   0.9s
# [CV 4/5; 198/500] START colsample_bylevel=0.8605834021941485, colsample_bynode=0.8957093582406279, colsample_bytree=0.6379183668561506, gamma=0.4342237799221911, learning_rate=0.12401643739024117, max_depth=35, n_estimators=126, reg_alpha=0.871363091296854, reg_lambda=0.5356387162808967, subsample=0.6948648076592054
# [CV 4/5; 198/500] END colsample_bylevel=0.8605834021941485, colsample_bynode=0.8957093582406279, colsample_bytree=0.6379183668561506, gamma=0.4342237799221911, learning_rate=0.12401643739024117, max_depth=35, n_estimators=126, reg_alpha=0.871363091296854, reg_lambda=0.5356387162808967, subsample=0.6948648076592054;, score=(train=0.997, test=0.798) total time=   0.5s
# [CV 4/5; 200/500] START colsample_bylevel=0.6558195265061755, colsample_bynode=0.8672758218335805, colsample_bytree=0.7775894269374104, gamma=1.6449920949964596, learning_rate=0.06575108523309975, max_depth=21, n_estimators=69, reg_alpha=0.018212149055072624, reg_lambda=1.7392299747889597, subsample=0.7986041080184586
# [CV 4/5; 200/500] END colsample_bylevel=0.6558195265061755, colsample_bynode=0.8672758218335805, colsample_bytree=0.7775894269374104, gamma=1.6449920949964596, learning_rate=0.06575108523309975, max_depth=21, n_estimators=69, reg_alpha=0.018212149055072624, reg_lambda=1.7392299747889597, subsample=0.7986041080184586;, score=(train=0.951, test=0.793) total time=   0.4s
# [CV 1/5; 202/500] START colsample_bylevel=0.7087588160820428, colsample_bynode=0.6105307980655627, colsample_bytree=0.637856062788291, gamma=0.5028597110348865, learning_rate=0.07140447382016282, max_depth=43, n_estimators=66, reg_alpha=1.6703227325366397, reg_lambda=1.2254091265013094, subsample=0.6168405055210288
# [CV 1/5; 202/500] END colsample_bylevel=0.7087588160820428, colsample_bynode=0.6105307980655627, colsample_bytree=0.637856062788291, gamma=0.5028597110348865, learning_rate=0.07140447382016282, max_depth=43, n_estimators=66, reg_alpha=1.6703227325366397, reg_lambda=1.2254091265013094, subsample=0.6168405055210288;, score=(train=0.914, test=0.782) total time=   0.4s
# [CV 3/5; 203/500] START colsample_bylevel=0.9430588774385686, colsample_bynode=0.9361110750600461, colsample_bytree=0.6479126284052423, gamma=1.7415218064713318, learning_rate=0.14607780598049375, max_depth=19, n_estimators=137, reg_alpha=1.9529171578866118, reg_lambda=1.6236758256153858, subsample=0.7827951966150837
# [CV 3/5; 203/500] END colsample_bylevel=0.9430588774385686, colsample_bynode=0.9361110750600461, colsample_bytree=0.6479126284052423, gamma=1.7415218064713318, learning_rate=0.14607780598049375, max_depth=19, n_estimators=137, reg_alpha=1.9529171578866118, reg_lambda=1.6236758256153858, subsample=0.7827951966150837;, score=(train=0.894, test=0.848) total time=   0.3s
# [CV 1/5; 205/500] START colsample_bylevel=0.7304023176276756, colsample_bynode=0.8883500126489263, colsample_bytree=0.8797084842137108, gamma=0.5883333600916552, learning_rate=0.11514343786067713, max_depth=22, n_estimators=124, reg_alpha=1.5271189025327971, reg_lambda=0.3804000760303017, subsample=0.6413616208380629
# [CV 1/5; 205/500] END colsample_bylevel=0.7304023176276756, colsample_bynode=0.8883500126489263, colsample_bytree=0.8797084842137108, gamma=0.5883333600916552, learning_rate=0.11514343786067713, max_depth=22, n_estimators=124, reg_alpha=1.5271189025327971, reg_lambda=0.3804000760303017, subsample=0.6413616208380629;, score=(train=0.979, test=0.810) total time=   0.6s
# [CV 4/5; 206/500] START colsample_bylevel=0.935789039553861, colsample_bynode=0.9420964977748231, colsample_bytree=0.7166192402377198, gamma=0.8668928823798558, learning_rate=0.08098854024814159, max_depth=21, n_estimators=85, reg_alpha=1.6845646318867054, reg_lambda=0.16202144469650848, subsample=0.9361517682771949
# [CV 4/5; 206/500] END colsample_bylevel=0.935789039553861, colsample_bynode=0.9420964977748231, colsample_bytree=0.7166192402377198, gamma=0.8668928823798558, learning_rate=0.08098854024814159, max_depth=21, n_estimators=85, reg_alpha=1.6845646318867054, reg_lambda=0.16202144469650848, subsample=0.9361517682771949;, score=(train=0.956, test=0.803) total time=   0.5s
# [CV 3/5; 208/500] START colsample_bylevel=0.7542395219237683, colsample_bynode=0.897117148876633, colsample_bytree=0.8963595981290273, gamma=0.6124565059328277, learning_rate=0.1363414832192329, max_depth=27, n_estimators=50, reg_alpha=0.9117799472237018, reg_lambda=0.9052427923862871, subsample=0.9255797514582085
# [CV 3/5; 208/500] END colsample_bylevel=0.7542395219237683, colsample_bynode=0.897117148876633, colsample_bytree=0.8963595981290273, gamma=0.6124565059328277, learning_rate=0.1363414832192329, max_depth=27, n_estimators=50, reg_alpha=0.9117799472237018, reg_lambda=0.9052427923862871, subsample=0.9255797514582085;, score=(train=0.987, test=0.862) total time=   0.4s
# [CV 5/5; 209/500] START colsample_bylevel=0.8362496896996522, colsample_bynode=0.625758828481542, colsample_bytree=0.8840893719004823, gamma=0.9850176840991836, learning_rate=0.12457628877408197, max_depth=33, n_estimators=89, reg_alpha=0.6897692235654118, reg_lambda=0.49314505805006603, subsample=0.7724287373674913
# [CV 5/5; 209/500] END colsample_bylevel=0.8362496896996522, colsample_bynode=0.625758828481542, colsample_bytree=0.8840893719004823, gamma=0.9850176840991836, learning_rate=0.12457628877408197, max_depth=33, n_estimators=89, reg_alpha=0.6897692235654118, reg_lambda=0.49314505805006603, subsample=0.7724287373674913;, score=(train=0.982, test=0.780) total time=   0.4s
# [CV 5/5; 211/500] START colsample_bylevel=0.9247640214125157, colsample_bynode=0.7999330710028886, colsample_bytree=0.6588031156215232, gamma=0.8133549792918375, learning_rate=0.07876950911925482, max_depth=34, n_estimators=81, reg_alpha=1.9103250970356949, reg_lambda=1.1595012516263203, subsample=0.9750837610511303
# [CV 5/5; 211/500] END colsample_bylevel=0.9247640214125157, colsample_bynode=0.7999330710028886, colsample_bytree=0.6588031156215232, gamma=0.8133549792918375, learning_rate=0.07876950911925482, max_depth=34, n_estimators=81, reg_alpha=1.9103250970356949, reg_lambda=1.1595012516263203, subsample=0.9750837610511303;, score=(train=0.947, test=0.791) total time=   0.5s
# [CV 3/5; 213/500] START colsample_bylevel=0.679860322747334, colsample_bynode=0.9557541840805066, colsample_bytree=0.6310645208131306, gamma=0.3893395368742514, learning_rate=0.10569469947511993, max_depth=33, n_estimators=103, reg_alpha=1.1170491566087304, reg_lambda=0.1614821370738726, subsample=0.659819138846153
# [CV 3/5; 213/500] END colsample_bylevel=0.679860322747334, colsample_bynode=0.9557541840805066, colsample_bytree=0.6310645208131306, gamma=0.3893395368742514, learning_rate=0.10569469947511993, max_depth=33, n_estimators=103, reg_alpha=1.1170491566087304, reg_lambda=0.1614821370738726, subsample=0.659819138846153;, score=(train=0.992, test=0.839) total time=   0.6s
# [CV 1/5; 215/500] START colsample_bylevel=0.7084686710705975, colsample_bynode=0.7979719691913985, colsample_bytree=0.9427460361606853, gamma=0.6704680507560701, learning_rate=0.07931353422670898, max_depth=23, n_estimators=78, reg_alpha=1.1076177345391596, reg_lambda=0.08452083361964235, subsample=0.8834982965124577
# [CV 1/5; 215/500] END colsample_bylevel=0.7084686710705975, colsample_bynode=0.7979719691913985, colsample_bytree=0.9427460361606853, gamma=0.6704680507560701, learning_rate=0.07931353422670898, max_depth=23, n_estimators=78, reg_alpha=1.1076177345391596, reg_lambda=0.08452083361964235, subsample=0.8834982965124577;, score=(train=0.981, test=0.815) total time=   0.6s
# [CV 5/5; 216/500] START colsample_bylevel=0.9428597373288331, colsample_bynode=0.726638429764267, colsample_bytree=0.9687331381907378, gamma=1.9390421021521749, learning_rate=0.05504967980191488, max_depth=48, n_estimators=128, reg_alpha=0.51665778115154, reg_lambda=0.4798241450571714, subsample=0.8630156740981763
# [CV 5/5; 216/500] END colsample_bylevel=0.9428597373288331, colsample_bynode=0.726638429764267, colsample_bytree=0.9687331381907378, gamma=1.9390421021521749, learning_rate=0.05504967980191488, max_depth=48, n_estimators=128, reg_alpha=0.51665778115154, reg_lambda=0.4798241450571714, subsample=0.8630156740981763;, score=(train=0.950, test=0.808) total time=   0.6s
# [CV 4/5; 218/500] START colsample_bylevel=0.7509521729005841, colsample_bynode=0.6276357645878431, colsample_bytree=0.9144637267084507, gamma=0.6548813770492112, learning_rate=0.053118762890415665, max_depth=19, n_estimators=130, reg_alpha=1.8826354384505992, reg_lambda=1.1055638386565165, subsample=0.6537816643222187
# [CV 4/5; 218/500] END colsample_bylevel=0.7509521729005841, colsample_bynode=0.6276357645878431, colsample_bytree=0.9144637267084507, gamma=0.6548813770492112, learning_rate=0.053118762890415665, max_depth=19, n_estimators=130, reg_alpha=1.8826354384505992, reg_lambda=1.1055638386565165, subsample=0.6537816643222187;, score=(train=0.937, test=0.794) total time=   0.7s
# [CV 2/5; 220/500] START colsample_bylevel=0.7538009808204149, colsample_bynode=0.646305329577331, colsample_bytree=0.8867019213842998, gamma=0.2875520165320953, learning_rate=0.0657561078557509, max_depth=38, n_estimators=138, reg_alpha=0.6287176219693409, reg_lambda=1.3701552353502562, subsample=0.82208578523078
# [CV 2/5; 220/500] END colsample_bylevel=0.7538009808204149, colsample_bynode=0.646305329577331, colsample_bytree=0.8867019213842998, gamma=0.2875520165320953, learning_rate=0.0657561078557509, max_depth=38, n_estimators=138, reg_alpha=0.6287176219693409, reg_lambda=1.3701552353502562, subsample=0.82208578523078;, score=(train=0.998, test=0.824) total time=   0.9s
# [CV 5/5; 221/500] START colsample_bylevel=0.8816390022073322, colsample_bynode=0.7751402054389568, colsample_bytree=0.8375450625197944, gamma=0.9538357565120035, learning_rate=0.11123324293476583, max_depth=43, n_estimators=98, reg_alpha=1.1041104742771164, reg_lambda=1.877914182042724, subsample=0.9948500531092438
# [CV 5/5; 221/500] END colsample_bylevel=0.8816390022073322, colsample_bynode=0.7751402054389568, colsample_bytree=0.8375450625197944, gamma=0.9538357565120035, learning_rate=0.11123324293476583, max_depth=43, n_estimators=98, reg_alpha=1.1041104742771164, reg_lambda=1.877914182042724, subsample=0.9948500531092438;, score=(train=0.959, test=0.801) total time=   0.4s
# [CV 3/5; 223/500] START colsample_bylevel=0.6981112970407523, colsample_bynode=0.8339989816566754, colsample_bytree=0.6142409358258504, gamma=0.9787559137685924, learning_rate=0.14858081231882792, max_depth=40, n_estimators=67, reg_alpha=1.8433899512727243, reg_lambda=0.5799291413016536, subsample=0.9819060084448586
# [CV 3/5; 223/500] END colsample_bylevel=0.6981112970407523, colsample_bynode=0.8339989816566754, colsample_bytree=0.6142409358258504, gamma=0.9787559137685924, learning_rate=0.14858081231882792, max_depth=40, n_estimators=67, reg_alpha=1.8433899512727243, reg_lambda=0.5799291413016536, subsample=0.9819060084448586;, score=(train=0.935, test=0.857) total time=   0.3s
# [CV 1/5; 224/500] START colsample_bylevel=0.6370365248151689, colsample_bynode=0.8234080630604463, colsample_bytree=0.9801809042228118, gamma=1.282563672292442, learning_rate=0.05681233856542903, max_depth=34, n_estimators=69, reg_alpha=0.7955288589705536, reg_lambda=0.8374381073738517, subsample=0.6967107392593812
# [CV 1/5; 224/500] END colsample_bylevel=0.6370365248151689, colsample_bynode=0.8234080630604463, colsample_bytree=0.9801809042228118, gamma=1.282563672292442, learning_rate=0.05681233856542903, max_depth=34, n_estimators=69, reg_alpha=0.7955288589705536, reg_lambda=0.8374381073738517, subsample=0.6967107392593812;, score=(train=0.939, test=0.793) total time=   0.5s

# %%
cv_results.head()

# %%
results_path = f"./tuning_results/tuning_xgb/{timestamp}/Assets"
if not os.path.exists(results_path):
    os.makedirs(results_path)

# %% [markdown]
# # CV Evaluation

# %%
cv_results.columns

# %%
cv_results.sort_values(by='rank_test_score', ascending=True).head(5)

# %%
sorted_cv = cv_results.sort_values(by='rank_test_score', ascending=True)

# %% [markdown]
# # Train vs Test Comparison

# %%
plt.figure(figsize=(16, 6))    

plt.plot(sorted_cv['rank_test_score'], sorted_cv['mean_train_score'], label="Train Score")
plt.plot(sorted_cv['rank_test_score'], sorted_cv['mean_test_score'], label="Validation Score")

plt.grid()
plt.xlabel('Sorted Validation Rank')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy by Final Rank')
plt.legend(loc='best')

filename = "test_train_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(10, 3))
fig.suptitle('Test Accuracy by Rank')

ax = fig.add_subplot(111)

plt.boxplot(sorted_cv.iloc[:10, :][['split0_test_score', 'split1_test_score', 'split2_test_score',
   'split3_test_score', 'split4_test_score']].T)
ax.set_xticklabels(range(1, 11))
ax.set_xlabel("Rank")
ax.set_ylabel("Accuracy")

filename = "test_accuracy_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(10, 3))
fig.suptitle('Train Accuracy by Rank')

ax = fig.add_subplot(111)

plt.boxplot(sorted_cv.iloc[:10, :][['split0_train_score', 'split1_train_score', 'split2_train_score',
   'split3_train_score', 'split4_train_score']].T)
ax.set_xticklabels(range(1, 11))
ax.set_xlabel("Rank")
ax.set_ylabel("Accuracy")

filename = "train_accuracy_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
max_params = cv_results.loc[cv_results['rank_test_score'] == 1]
best_params = max_params.params.values[0]

# %%
print(f"Mean Train Accuracy = {max_params['mean_train_score'].values[0]:.2f}")
print(f"Mean Validation Accuracy = {max_params['mean_test_score'].values[0]:.2f}")

# %%
random_search = pickle.load(open(os.path.join(f'./tuning_results/tuning_xgb/{timestamp}/', file_name), "rb"))
model = random_search.best_estimator_

#model = XGBClassifier(**best_params)
#model.fit(X_train, y_train)

y_train_prediction = model.predict(X_train)
y_test_prediction = model.predict(X_test)

# %%
print(f"Train set, Accuracy = {accuracy_score(y_train, y_train_prediction):.2f}")
print(f"Test set, Accuracy = {accuracy_score(y_test, y_test_prediction):.2f}")

# %%
ind = np.argpartition(model.feature_importances_, -20)[-20:]

features = X.columns[ind]
importance = model.feature_importances_[ind]

fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(ind)), importance, align='center')
plt.yticks(range(len(ind)), features)
plt.title('Feature Importance XGB')
plt.grid()

filename = "feature_importance.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# In the context of XGBoost, these scores are often computed based on the following:
#
# - Weight: The number of times a feature appears in a tree across the ensemble of trees.
# - Gain: The average gain of a feature when it is used in trees.
# - Cover: The average coverage of a feature when it is used in trees.

# %%
# TEST
for col in ['param_colsample_bylevel', 'param_colsample_bynode',
       'param_colsample_bytree', 'param_gamma', 'param_learning_rate',
       'param_max_depth', 'param_n_estimators', 'param_reg_alpha',
       'param_reg_lambda', 'param_subsample']:
    
    plt.figure(figsize=(16, 6))    

    m, b = np.polyfit(list(sorted_cv['mean_test_score'].values), list(sorted_cv[col].values), 1)
    plt.plot(sorted_cv['mean_test_score'], m * sorted_cv['mean_test_score'] + b, c='r', label="Regression Line")
    plt.scatter(sorted_cv['mean_test_score'], sorted_cv[col], label=f"{col} Values")
    
    plt.grid()
    plt.xlabel('Mean Validation Score')
    plt.ylabel('Parameter Value')
    plt.title(col)
    plt.legend(loc='best')

    
    filename = f"{col}_by_rank.png"
    plt.savefig(os.path.join(results_path, filename))
                  
    plt.show()

# %% [markdown]
# # Hyperparameter Evaluation

# %%
def plot_parameters(x_values, title):
    
    fig, ax1 = plt.subplots(figsize=(16, 6))
    ax2 = ax1.twinx()

    ax1.scatter(x_values, cv_results['mean_test_score'], label='mean_test_score', c='b')
    #ax2.scatter(x_values, cv_results['std_test_score'], label='std_test_score', c='r')

    m, b = np.polyfit(list(x_values.values), list(cv_results['mean_test_score'].values), 1)
    ax1.plot(x_values, m * x_values + b, c='b')

    m, b = np.polyfit(list(x_values.values), list(cv_results['std_test_score'].values), 1)
    ax2.plot(x_values, m * x_values + b, c='r', label='std_test_score')
    
    ax1.set_title(title)
    ax1.set_xlabel('Parameter Value')
    ax1.set_ylabel('Mean Test Score')
    ax2.set_ylabel('Standard Deviation of Test Score')
    ax1.grid(True)
    
    
    # Combine the legends from both axes
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax2.legend(lines + lines2, labels + labels2, loc='upper right')

    filename = f"{title}_test_score.png"
    plt.savefig(os.path.join(results_path, filename))
            
    plt.show()

# %%
for param in ['param_colsample_bylevel', 'param_colsample_bynode', 'param_colsample_bytree',
                     'param_gamma', 'param_learning_rate', 'param_max_depth', 'param_n_estimators', 
                     'param_reg_alpha', 'param_reg_lambda', 'param_subsample']:
    x_values = cv_results[param]
    plot_parameters(x_values, param)

# %% [markdown]
# # Plotting Evaluation Metrics (Precision, Recall, F1-Score, AUC-ROC):

# %%
# For multiclass classification, you need to binarize the labels
y_true_bin = label_binarize(y_test, classes=np.unique(y_test))
y_score_bin = label_binarize(y_test_prediction, classes=np.unique(y_test_prediction))

auc_roc = roc_auc_score(y_true_bin, y_score_bin, average='macro')

# Plot Precision-Recall curve for each class
precision = dict()
recall = dict()

plt.figure(figsize=(16, 6))    
for i in range(7):
    precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], y_score_bin[:, i])
    plt.plot(recall[i], precision[i], label='Covertype {}'.format(i + 1))

plt.grid()
plt.xlabel('Recall')
plt.ylabel('True Positive Rate / Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')

filename = "precision_recall.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()


# Plot AUC-ROC curve for each class
fpr = dict()
tpr = dict()

plt.figure(figsize=(16, 6))    
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score_bin[:, i])
    plt.plot(fpr[i], tpr[i], label='Covertype {}'.format(i + 1))

plt.grid()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate / Precision')
plt.title('ROC Curve')
plt.legend(loc='best')
            
filename = "roc_curve.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# # Partial Dependence

# %%
# potentially iterate over features (and relation ie 0 to 1)

# %%
features, feature_names = [(0,)], [f"Features #{i}" for i in range(X.shape[1])]
deciles = {0: np.linspace(0, 1, num=5)}

pd_results = partial_dependence(
    model, X, features=1, kind="average", grid_resolution=5)

display = PartialDependenceDisplay(
    [pd_results], features=features, feature_names=feature_names,
    target_idx=0, deciles=deciles
)
display.plot(pdp_lim={1: (-1.38, 0.66)})

plt.grid()
plt.xlabel('Feature Value')
plt.ylabel('Partial Dependence') 
plt.title('Partial Dependence')

filename = "partial_dependence.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
class_names = np.unique(y)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        model,
        X_test,
        y_test,
        display_labels=class_names + 1,
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    png_name = title.lower().replace(" ", "_")
    filename = f"{png_name}.png"
    plt.savefig(os.path.join(results_path, filename))

plt.show()

# %% [markdown]
# # Shap Values

# %%
explainer = shap.TreeExplainer(model)
explanation = explainer.shap_values(X_test, check_additivity=False)

# %%
shap.summary_plot(explanation, X_test, plot_type="bar", show=False)

filename = f"shap_summary.png"
plt.savefig(os.path.join(results_path, filename))
plt.close()

# %% [markdown]
# SHAP values show how each feature affects each final prediction, the significance of each feature compared to others, and the model's reliance on the interaction between features.

# %%
# IF WE SCALE: SCALE ONLY TRAIN DATA SET
# BOOSTING ALG:

# - Feature Selection: AUTOMATIC (NON CRITICAL)
# - Scaling: AUTOMATIC
# - Handling Missing Values: AUTOMATIC
# - Outliers: NEED TO DEAL WITH

# %% [markdown]
# # KAGGLE Prediction

# %%
test_processed = pd.read_csv('Data/test_engineered.csv')

# %%
test_processed.head()

# %%
test_processed = test_processed.loc[:, [col for col in test_processed if not col.startswith('Cover_Type_')]]
X_kaggle = test_processed.drop(columns=['Aspect_Sector'])
y_kaggle = model.predict(X_kaggle) + 1

# %%
pd.read_csv("Data/Kaggle/full_submission.csv").head()

# %%
test_processed['Cover_Type'] = y_kaggle

# %%
kaggle_submission = test_processed.loc[:, ['Id', 'Cover_Type']]

# %%
kaggle_submission.Cover_Type.value_counts()

# %%
kaggle_submission.to_csv(f'Data/kaggle_submission_{timestamp}.csv', index=False)

# %%
pd.read_csv(f'Data/kaggle_submission_{timestamp}.csv')

# %%
timestamp
