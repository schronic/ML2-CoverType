# %%
import datetime
import os
import pickle
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import lightgbm as lgb
from sklearn.inspection import PartialDependenceDisplay, partial_dependence
from sklearn.metrics import (ConfusionMatrixDisplay, accuracy_score, precision_recall_curve, roc_auc_score, roc_curve)
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import label_binarize

import shap

# %config InlineBackend.figure_format = 'retina'

# %%
from notebook import notebookapp
import urllib
import json
import ipykernel
from shutil import copy2

def notebook_path():
    """Returns the absolute path of the Notebook or None if it cannot be determined
    NOTE: works only when the security is token-based or there is also no password
    """
    connection_file = os.path.basename(ipykernel.get_connection_file())
    kernel_id = connection_file.split('-', 1)[1].split('.')[0]

    for srv in notebookapp.list_running_servers():
        try:
            if srv['token']=='' and not srv['password']:  # No token and no password, ahem...
                req = urllib.request.urlopen(srv['url']+'api/sessions')
            else:
                req = urllib.request.urlopen(srv['url']+'api/sessions?token='+srv['token'])
            sessions = json.load(req)
            for sess in sessions:
                if sess['kernel']['id'] == kernel_id:
                    return os.path.join(srv['notebook_dir'],sess['notebook']['path'])
        except:
            pass  # There may be stale entries in the runtime directory 
    return None


def copy_current_nb(new_name):
    nb = notebook_path()
    if nb:
        new_path = os.path.join(os.path.dirname(nb), new_name+'.ipynb')
        copy2(nb, new_path)
    else:
        print("Current notebook path cannot be determined.")

# %%
df = pd.read_csv('Data/cover_type_engineered.csv')

# %%
df = df.loc[:, [col for col in df if not col.startswith('Cover_Type_')]]
X = df.drop(columns=['Cover_Type', 'Aspect_Sector'])
y = df['Cover_Type'] - 1

# %%
timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M")

warnings.filterwarnings("ignore", category=FutureWarning, module="pandas.api.types")

# Assuming X and y are defined
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.33, random_state=42)

# Define the LightGBM classifier
estimator = lgb.LGBMClassifier(objective='multiclass', num_class=len(np.unique(y)))

# Define hyperparameters for tuning LightGBM
hyperparameters = {
    'num_leaves': stats.randint(30, 150),
    'min_child_samples': stats.randint(20, 500),
    'min_child_weight': stats.uniform(1e-5, 1e-2),
    'subsample': stats.uniform(0.5, 0.5),  
    'colsample_bytree': stats.uniform(0.5, 0.5),
    'reg_alpha': stats.uniform(1e-5, 1),
    'reg_lambda': stats.uniform(1e-5, 1),
    'learning_rate': stats.uniform(0.01, 0.3),
    'n_estimators': stats.randint(50, 500),
}

random_search = RandomizedSearchCV(estimator,
                                   param_distributions=hyperparameters,
                                   scoring='accuracy',  # Choose appropriate metric
                                   return_train_score=True,
                                   n_iter=500,
                                   cv=5,
                                   verbose=10,
                                   n_jobs=-1)

# Fit the RandomizedSearchCV
try:
    random_search.fit(X_train, y_train)  # Assuming X_train and y_train are defined
    print("Best parameters found:", random_search.best_params_)
    print("Best score found:", random_search.best_score_)

    
    # Save results
    results_path = f"./tuning_results/tuning_lgbm/{timestamp}"
    if not os.path.exists(results_path):
        os.makedirs(results_path)
        
    # Saving cross-validation results
    cv_results = pd.DataFrame(random_search.cv_results_)
    cv_results_file = f"{timestamp}_results.csv"
    cv_results.to_csv(os.path.join(results_path, cv_results_file), index=False)
    
    # Save .ipynb
    copy_current_nb(os.path.join(results_path, 'Evaluation_Notebook'))
    
    # Save Model
    file_name = f"lgbm_{timestamp}.pkl"
    pickle.dump(random_search, open(os.path.join(results_path, file_name), "wb"))
    
    # random_search = pickle.load(open(file_name, "rb"))
    

except Exception as e:
    print(f"An error occurred during model optimization: {e}")
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV 1/5; 1/500] START colsample_bytree=0.957931407341758, learning_rate=0.14798891436244344, min_child_samples=457, min_child_weight=0.008557504687892561, n_estimators=410, num_leaves=135, reg_alpha=0.593905100504062, reg_lambda=0.6546088499394438, subsample=0.8947327855022912
# [CV 1/5; 1/500] END colsample_bytree=0.957931407341758, learning_rate=0.14798891436244344, min_child_samples=457, min_child_weight=0.008557504687892561, n_estimators=410, num_leaves=135, reg_alpha=0.593905100504062, reg_lambda=0.6546088499394438, subsample=0.8947327855022912;, score=(train=1.000, test=0.856) total time=   6.2s
# [CV 1/5; 4/500] START colsample_bytree=0.6062056232493445, learning_rate=0.2974894547758782, min_child_samples=277, min_child_weight=0.008712765129695923, n_estimators=91, num_leaves=136, reg_alpha=0.3021074899194223, reg_lambda=0.8127735491539001, subsample=0.9501615916275031
# [CV 1/5; 4/500] END colsample_bytree=0.6062056232493445, learning_rate=0.2974894547758782, min_child_samples=277, min_child_weight=0.008712765129695923, n_estimators=91, num_leaves=136, reg_alpha=0.3021074899194223, reg_lambda=0.8127735491539001, subsample=0.9501615916275031;, score=(train=0.999, test=0.852) total time=   1.3s
# [CV 4/5; 4/500] START colsample_bytree=0.6062056232493445, learning_rate=0.2974894547758782, min_child_samples=277, min_child_weight=0.008712765129695923, n_estimators=91, num_leaves=136, reg_alpha=0.3021074899194223, reg_lambda=0.8127735491539001, subsample=0.9501615916275031
# [CV 4/5; 4/500] END colsample_bytree=0.6062056232493445, learning_rate=0.2974894547758782, min_child_samples=277, min_child_weight=0.008712765129695923, n_estimators=91, num_leaves=136, reg_alpha=0.3021074899194223, reg_lambda=0.8127735491539001, subsample=0.9501615916275031;, score=(train=0.999, test=0.861) total time=   1.4s
# [CV 2/5; 6/500] START colsample_bytree=0.6144025438340186, learning_rate=0.04127037810427947, min_child_samples=270, min_child_weight=0.0017964103717113145, n_estimators=372, num_leaves=112, reg_alpha=0.9644397319063548, reg_lambda=0.3748811852878737, subsample=0.5250380458408055
# [CV 2/5; 6/500] END colsample_bytree=0.6144025438340186, learning_rate=0.04127037810427947, min_child_samples=270, min_child_weight=0.0017964103717113145, n_estimators=372, num_leaves=112, reg_alpha=0.9644397319063548, reg_lambda=0.3748811852878737, subsample=0.5250380458408055;, score=(train=0.981, test=0.842) total time=   6.4s
# [CV 5/5; 7/500] START colsample_bytree=0.877598437750193, learning_rate=0.2587186593942219, min_child_samples=146, min_child_weight=0.0036923537388434927, n_estimators=247, num_leaves=116, reg_alpha=0.6516308670238609, reg_lambda=0.9302614610762346, subsample=0.5622728244114128
# [CV 5/5; 7/500] END colsample_bytree=0.877598437750193, learning_rate=0.2587186593942219, min_child_samples=146, min_child_weight=0.0036923537388434927, n_estimators=247, num_leaves=116, reg_alpha=0.6516308670238609, reg_lambda=0.9302614610762346, subsample=0.5622728244114128;, score=(train=1.000, test=0.863) total time=   3.3s
# [CV 1/5; 9/500] START colsample_bytree=0.7131692188039493, learning_rate=0.15207960102194776, min_child_samples=126, min_child_weight=0.006620486311235841, n_estimators=432, num_leaves=136, reg_alpha=0.41857195147367315, reg_lambda=0.7132056108356599, subsample=0.6121655129035777
# [CV 1/5; 9/500] END colsample_bytree=0.7131692188039493, learning_rate=0.15207960102194776, min_child_samples=126, min_child_weight=0.006620486311235841, n_estimators=432, num_leaves=136, reg_alpha=0.41857195147367315, reg_lambda=0.7132056108356599, subsample=0.6121655129035777;, score=(train=1.000, test=0.867) total time=   5.9s
# [CV 4/5; 10/500] START colsample_bytree=0.6591753728445784, learning_rate=0.03827548141519166, min_child_samples=393, min_child_weight=0.009597782476628363, n_estimators=240, num_leaves=33, reg_alpha=0.39952351311247386, reg_lambda=0.28548316048685335, subsample=0.7144427471666425
# [CV 4/5; 10/500] END colsample_bytree=0.6591753728445784, learning_rate=0.03827548141519166, min_child_samples=393, min_child_weight=0.009597782476628363, n_estimators=240, num_leaves=33, reg_alpha=0.39952351311247386, reg_lambda=0.28548316048685335, subsample=0.7144427471666425;, score=(train=0.911, test=0.836) total time=   3.0s
# [CV 2/5; 12/500] START colsample_bytree=0.6991909930922442, learning_rate=0.0802337684434164, min_child_samples=409, min_child_weight=0.0067518035425637975, n_estimators=277, num_leaves=146, reg_alpha=0.09436022884789534, reg_lambda=0.5038857272864634, subsample=0.5390868477611992
# [CV 2/5; 12/500] END colsample_bytree=0.6991909930922442, learning_rate=0.0802337684434164, min_child_samples=409, min_child_weight=0.0067518035425637975, n_estimators=277, num_leaves=146, reg_alpha=0.09436022884789534, reg_lambda=0.5038857272864634, subsample=0.5390868477611992;, score=(train=0.987, test=0.850) total time=   4.3s
# [CV 5/5; 12/500] START colsample_bytree=0.6991909930922442, learning_rate=0.0802337684434164, min_child_samples=409, min_child_weight=0.0067518035425637975, n_estimators=277, num_leaves=146, reg_alpha=0.09436022884789534, reg_lambda=0.5038857272864634, subsample=0.5390868477611992
# [CV 5/5; 12/500] END colsample_bytree=0.6991909930922442, learning_rate=0.0802337684434164, min_child_samples=409, min_child_weight=0.0067518035425637975, n_estimators=277, num_leaves=146, reg_alpha=0.09436022884789534, reg_lambda=0.5038857272864634, subsample=0.5390868477611992;, score=(train=0.988, test=0.857) total time=   3.9s
# [CV 3/5; 14/500] START colsample_bytree=0.9160301952192211, learning_rate=0.16507373093601682, min_child_samples=473, min_child_weight=0.005066035653002689, n_estimators=448, num_leaves=103, reg_alpha=0.7953283529408258, reg_lambda=0.2796583784551569, subsample=0.8090979101654628
# [CV 3/5; 14/500] END colsample_bytree=0.9160301952192211, learning_rate=0.16507373093601682, min_child_samples=473, min_child_weight=0.005066035653002689, n_estimators=448, num_leaves=103, reg_alpha=0.7953283529408258, reg_lambda=0.2796583784551569, subsample=0.8090979101654628;, score=(train=1.000, test=0.854) total time=   6.2s
# [CV 2/5; 17/500] START colsample_bytree=0.5678209211371046, learning_rate=0.026389417105567338, min_child_samples=245, min_child_weight=0.004989703834796677, n_estimators=141, num_leaves=53, reg_alpha=0.06989588084505009, reg_lambda=0.8171396006529525, subsample=0.5560658102701981
# [CV 2/5; 17/500] END colsample_bytree=0.5678209211371046, learning_rate=0.026389417105567338, min_child_samples=245, min_child_weight=0.004989703834796677, n_estimators=141, num_leaves=53, reg_alpha=0.06989588084505009, reg_lambda=0.8171396006529525, subsample=0.5560658102701981;, score=(train=0.851, test=0.796) total time=   2.4s
# [CV 4/5; 18/500] START colsample_bytree=0.6398291931901467, learning_rate=0.25350886494247166, min_child_samples=46, min_child_weight=0.005561916845346728, n_estimators=63, num_leaves=52, reg_alpha=0.021508779995855477, reg_lambda=0.7081935383318329, subsample=0.9709853548984191
# [CV 4/5; 18/500] END colsample_bytree=0.6398291931901467, learning_rate=0.25350886494247166, min_child_samples=46, min_child_weight=0.005561916845346728, n_estimators=63, num_leaves=52, reg_alpha=0.021508779995855477, reg_lambda=0.7081935383318329, subsample=0.9709853548984191;, score=(train=1.000, test=0.866) total time=   2.2s
# [CV 2/5; 20/500] START colsample_bytree=0.5041993808209212, learning_rate=0.10064709113855665, min_child_samples=434, min_child_weight=0.002716740133636054, n_estimators=98, num_leaves=137, reg_alpha=0.11698275178091215, reg_lambda=0.29232967831386797, subsample=0.9528577943910083
# [CV 2/5; 20/500] END colsample_bytree=0.5041993808209212, learning_rate=0.10064709113855665, min_child_samples=434, min_child_weight=0.002716740133636054, n_estimators=98, num_leaves=137, reg_alpha=0.11698275178091215, reg_lambda=0.29232967831386797, subsample=0.9528577943910083;, score=(train=0.905, test=0.815) total time=   1.6s
# [CV 5/5; 20/500] START colsample_bytree=0.5041993808209212, learning_rate=0.10064709113855665, min_child_samples=434, min_child_weight=0.002716740133636054, n_estimators=98, num_leaves=137, reg_alpha=0.11698275178091215, reg_lambda=0.29232967831386797, subsample=0.9528577943910083
# [CV 5/5; 20/500] END colsample_bytree=0.5041993808209212, learning_rate=0.10064709113855665, min_child_samples=434, min_child_weight=0.002716740133636054, n_estimators=98, num_leaves=137, reg_alpha=0.11698275178091215, reg_lambda=0.29232967831386797, subsample=0.9528577943910083;, score=(train=0.902, test=0.829) total time=   1.5s
# [CV 3/5; 21/500] START colsample_bytree=0.954937404008411, learning_rate=0.21751355971252292, min_child_samples=270, min_child_weight=0.004086271673714464, n_estimators=163, num_leaves=34, reg_alpha=0.33062081079891475, reg_lambda=0.9834311375601652, subsample=0.8293894916895413
# [CV 3/5; 21/500] END colsample_bytree=0.954937404008411, learning_rate=0.21751355971252292, min_child_samples=270, min_child_weight=0.004086271673714464, n_estimators=163, num_leaves=34, reg_alpha=0.33062081079891475, reg_lambda=0.9834311375601652, subsample=0.8293894916895413;, score=(train=1.000, test=0.862) total time=   4.0s
# [CV 1/5; 23/500] START colsample_bytree=0.965723344225673, learning_rate=0.14642642219971172, min_child_samples=477, min_child_weight=0.0001693191102267677, n_estimators=301, num_leaves=130, reg_alpha=0.2951567792441619, reg_lambda=0.28419064360475516, subsample=0.8628318893970073
# [CV 1/5; 23/500] END colsample_bytree=0.965723344225673, learning_rate=0.14642642219971172, min_child_samples=477, min_child_weight=0.0001693191102267677, n_estimators=301, num_leaves=130, reg_alpha=0.2951567792441619, reg_lambda=0.28419064360475516, subsample=0.8628318893970073;, score=(train=1.000, test=0.866) total time=   7.0s
# [CV 4/5; 24/500] START colsample_bytree=0.7072860266189321, learning_rate=0.11417058862930773, min_child_samples=444, min_child_weight=0.007187108296775437, n_estimators=476, num_leaves=85, reg_alpha=0.48292970552628317, reg_lambda=0.839045980362488, subsample=0.6774747620811009
# [CV 4/5; 24/500] END colsample_bytree=0.7072860266189321, learning_rate=0.11417058862930773, min_child_samples=444, min_child_weight=0.007187108296775437, n_estimators=476, num_leaves=85, reg_alpha=0.48292970552628317, reg_lambda=0.839045980362488, subsample=0.6774747620811009;, score=(train=1.000, test=0.862) total time=   9.0s
# [CV 2/5; 26/500] START colsample_bytree=0.6278505888977577, learning_rate=0.19953833388916856, min_child_samples=486, min_child_weight=0.003030860396202155, n_estimators=182, num_leaves=64, reg_alpha=0.8359040707212192, reg_lambda=0.8115313191056833, subsample=0.8666123667122825
# [CV 2/5; 26/500] END colsample_bytree=0.6278505888977577, learning_rate=0.19953833388916856, min_child_samples=486, min_child_weight=0.003030860396202155, n_estimators=182, num_leaves=64, reg_alpha=0.8359040707212192, reg_lambda=0.8115313191056833, subsample=0.8666123667122825;, score=(train=0.991, test=0.839) total time=   2.5s
# [CV 3/5; 27/500] START colsample_bytree=0.76173105970526, learning_rate=0.10948203337408337, min_child_samples=355, min_child_weight=0.008534507442513736, n_estimators=295, num_leaves=56, reg_alpha=0.36575273037448525, reg_lambda=0.44752196963684826, subsample=0.8491635745725834
# [CV 3/5; 27/500] END colsample_bytree=0.76173105970526, learning_rate=0.10948203337408337, min_child_samples=355, min_child_weight=0.008534507442513736, n_estimators=295, num_leaves=56, reg_alpha=0.36575273037448525, reg_lambda=0.44752196963684826, subsample=0.8491635745725834;, score=(train=0.999, test=0.857) total time=   5.1s
# [CV 1/5; 29/500] START colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203
# [CV 1/5; 29/500] END colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203;, score=(train=1.000, test=0.868) total time=   4.1s
# [CV 4/5; 29/500] START colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203
# [CV 4/5; 29/500] END colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203;, score=(train=1.000, test=0.861) total time=   4.0s
# [CV 4/5; 30/500] START colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286
# [CV 4/5; 30/500] END colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286;, score=(train=0.953, test=0.846) total time=   1.0s
# [CV 3/5; 31/500] START colsample_bytree=0.8606331304774888, learning_rate=0.25988900089034195, min_child_samples=268, min_child_weight=0.007894368775446374, n_estimators=495, num_leaves=96, reg_alpha=0.7281113112040195, reg_lambda=0.8292104763469844, subsample=0.9465614255203967
# [CV 3/5; 31/500] END colsample_bytree=0.8606331304774888, learning_rate=0.25988900089034195, min_child_samples=268, min_child_weight=0.007894368775446374, n_estimators=495, num_leaves=96, reg_alpha=0.7281113112040195, reg_lambda=0.8292104763469844, subsample=0.9465614255203967;, score=(train=1.000, test=0.863) total time=   5.2s
# [CV 2/5; 33/500] START colsample_bytree=0.6008976127113117, learning_rate=0.22178744960992644, min_child_samples=161, min_child_weight=0.0006544802587909171, n_estimators=343, num_leaves=116, reg_alpha=0.9192435052779919, reg_lambda=0.24497321180788062, subsample=0.9094972383901834
# [CV 2/5; 33/500] END colsample_bytree=0.6008976127113117, learning_rate=0.22178744960992644, min_child_samples=161, min_child_weight=0.0006544802587909171, n_estimators=343, num_leaves=116, reg_alpha=0.9192435052779919, reg_lambda=0.24497321180788062, subsample=0.9094972383901834;, score=(train=1.000, test=0.852) total time=   3.5s
# [CV 5/5; 34/500] START colsample_bytree=0.6376101690099447, learning_rate=0.05836027000402384, min_child_samples=340, min_child_weight=0.005700582614316239, n_estimators=158, num_leaves=112, reg_alpha=0.8005062718050137, reg_lambda=0.7577380147055932, subsample=0.521671442435157
# [CV 5/5; 34/500] END colsample_bytree=0.6376101690099447, learning_rate=0.05836027000402384, min_child_samples=340, min_child_weight=0.005700582614316239, n_estimators=158, num_leaves=112, reg_alpha=0.8005062718050137, reg_lambda=0.7577380147055932, subsample=0.521671442435157;, score=(train=0.916, test=0.834) total time=   2.3s
# [CV 3/5; 36/500] START colsample_bytree=0.9232406589088409, learning_rate=0.168782459534108, min_child_samples=292, min_child_weight=0.007988870204911434, n_estimators=454, num_leaves=115, reg_alpha=0.25400453283113517, reg_lambda=0.16265802085157915, subsample=0.9923906752740294
# [CV 3/5; 36/500] END colsample_bytree=0.9232406589088409, learning_rate=0.168782459534108, min_child_samples=292, min_child_weight=0.007988870204911434, n_estimators=454, num_leaves=115, reg_alpha=0.25400453283113517, reg_lambda=0.16265802085157915, subsample=0.9923906752740294;, score=(train=1.000, test=0.871) total time=   7.2s
# [CV 3/5; 2/500] START colsample_bytree=0.7676967674304089, learning_rate=0.1197306578497946, min_child_samples=438, min_child_weight=0.00043063308326785846, n_estimators=317, num_leaves=73, reg_alpha=0.6499012319862668, reg_lambda=0.37227264404505983, subsample=0.9335210168715294
# [CV 3/5; 2/500] END colsample_bytree=0.7676967674304089, learning_rate=0.1197306578497946, min_child_samples=438, min_child_weight=0.00043063308326785846, n_estimators=317, num_leaves=73, reg_alpha=0.6499012319862668, reg_lambda=0.37227264404505983, subsample=0.9335210168715294;, score=(train=0.998, test=0.857) total time=   3.9s
# [CV 4/5; 2/500] START colsample_bytree=0.7676967674304089, learning_rate=0.1197306578497946, min_child_samples=438, min_child_weight=0.00043063308326785846, n_estimators=317, num_leaves=73, reg_alpha=0.6499012319862668, reg_lambda=0.37227264404505983, subsample=0.9335210168715294
# [CV 4/5; 2/500] END colsample_bytree=0.7676967674304089, learning_rate=0.1197306578497946, min_child_samples=438, min_child_weight=0.00043063308326785846, n_estimators=317, num_leaves=73, reg_alpha=0.6499012319862668, reg_lambda=0.37227264404505983, subsample=0.9335210168715294;, score=(train=0.998, test=0.867) total time=   4.0s
# [CV 4/5; 5/500] START colsample_bytree=0.648507454794542, learning_rate=0.1875935908052941, min_child_samples=248, min_child_weight=0.0008311710354274638, n_estimators=464, num_leaves=106, reg_alpha=0.25774887214167624, reg_lambda=0.2333231373392613, subsample=0.7779115017774032
# [CV 4/5; 5/500] END colsample_bytree=0.648507454794542, learning_rate=0.1875935908052941, min_child_samples=248, min_child_weight=0.0008311710354274638, n_estimators=464, num_leaves=106, reg_alpha=0.25774887214167624, reg_lambda=0.2333231373392613, subsample=0.7779115017774032;, score=(train=1.000, test=0.866) total time=   5.6s
# [CV 2/5; 7/500] START colsample_bytree=0.877598437750193, learning_rate=0.2587186593942219, min_child_samples=146, min_child_weight=0.0036923537388434927, n_estimators=247, num_leaves=116, reg_alpha=0.6516308670238609, reg_lambda=0.9302614610762346, subsample=0.5622728244114128
# [CV 2/5; 7/500] END colsample_bytree=0.877598437750193, learning_rate=0.2587186593942219, min_child_samples=146, min_child_weight=0.0036923537388434927, n_estimators=247, num_leaves=116, reg_alpha=0.6516308670238609, reg_lambda=0.9302614610762346, subsample=0.5622728244114128;, score=(train=1.000, test=0.857) total time=   3.1s
# [CV 3/5; 8/500] START colsample_bytree=0.8422709523866381, learning_rate=0.23137464605719718, min_child_samples=423, min_child_weight=0.004343813046081161, n_estimators=286, num_leaves=78, reg_alpha=0.7779834896577675, reg_lambda=0.9668347333039408, subsample=0.6108664431536566
# [CV 3/5; 8/500] END colsample_bytree=0.8422709523866381, learning_rate=0.23137464605719718, min_child_samples=423, min_child_weight=0.004343813046081161, n_estimators=286, num_leaves=78, reg_alpha=0.7779834896577675, reg_lambda=0.9668347333039408, subsample=0.6108664431536566;, score=(train=1.000, test=0.855) total time=   3.8s
# [CV 1/5; 10/500] START colsample_bytree=0.6591753728445784, learning_rate=0.03827548141519166, min_child_samples=393, min_child_weight=0.009597782476628363, n_estimators=240, num_leaves=33, reg_alpha=0.39952351311247386, reg_lambda=0.28548316048685335, subsample=0.7144427471666425
# [CV 1/5; 10/500] END colsample_bytree=0.6591753728445784, learning_rate=0.03827548141519166, min_child_samples=393, min_child_weight=0.009597782476628363, n_estimators=240, num_leaves=33, reg_alpha=0.39952351311247386, reg_lambda=0.28548316048685335, subsample=0.7144427471666425;, score=(train=0.908, test=0.828) total time=   3.1s
# [CV 5/5; 10/500] START colsample_bytree=0.6591753728445784, learning_rate=0.03827548141519166, min_child_samples=393, min_child_weight=0.009597782476628363, n_estimators=240, num_leaves=33, reg_alpha=0.39952351311247386, reg_lambda=0.28548316048685335, subsample=0.7144427471666425
# [CV 5/5; 10/500] END colsample_bytree=0.6591753728445784, learning_rate=0.03827548141519166, min_child_samples=393, min_child_weight=0.009597782476628363, n_estimators=240, num_leaves=33, reg_alpha=0.39952351311247386, reg_lambda=0.28548316048685335, subsample=0.7144427471666425;, score=(train=0.908, test=0.838) total time=   3.0s
# [CV 3/5; 12/500] START colsample_bytree=0.6991909930922442, learning_rate=0.0802337684434164, min_child_samples=409, min_child_weight=0.0067518035425637975, n_estimators=277, num_leaves=146, reg_alpha=0.09436022884789534, reg_lambda=0.5038857272864634, subsample=0.5390868477611992
# [CV 3/5; 12/500] END colsample_bytree=0.6991909930922442, learning_rate=0.0802337684434164, min_child_samples=409, min_child_weight=0.0067518035425637975, n_estimators=277, num_leaves=146, reg_alpha=0.09436022884789534, reg_lambda=0.5038857272864634, subsample=0.5390868477611992;, score=(train=0.989, test=0.853) total time=   4.2s
# [CV 2/5; 13/500] START colsample_bytree=0.6055611792094118, learning_rate=0.10387757484691883, min_child_samples=110, min_child_weight=0.004125405743489376, n_estimators=206, num_leaves=63, reg_alpha=0.48304153334614525, reg_lambda=0.6031082128999856, subsample=0.8333120896276958
# [CV 2/5; 13/500] END colsample_bytree=0.6055611792094118, learning_rate=0.10387757484691883, min_child_samples=110, min_child_weight=0.004125405743489376, n_estimators=206, num_leaves=63, reg_alpha=0.48304153334614525, reg_lambda=0.6031082128999856, subsample=0.8333120896276958;, score=(train=1.000, test=0.857) total time=   4.7s
# [CV 2/5; 15/500] START colsample_bytree=0.6357191460839982, learning_rate=0.2181591947084738, min_child_samples=495, min_child_weight=0.006232732993940106, n_estimators=74, num_leaves=138, reg_alpha=0.7671858366277895, reg_lambda=0.8100881749370188, subsample=0.8538472279424327
# [CV 2/5; 15/500] END colsample_bytree=0.6357191460839982, learning_rate=0.2181591947084738, min_child_samples=495, min_child_weight=0.006232732993940106, n_estimators=74, num_leaves=138, reg_alpha=0.7671858366277895, reg_lambda=0.8100881749370188, subsample=0.8538472279424327;, score=(train=0.938, test=0.824) total time=   1.1s
# [CV 5/5; 15/500] START colsample_bytree=0.6357191460839982, learning_rate=0.2181591947084738, min_child_samples=495, min_child_weight=0.006232732993940106, n_estimators=74, num_leaves=138, reg_alpha=0.7671858366277895, reg_lambda=0.8100881749370188, subsample=0.8538472279424327
# [CV 5/5; 15/500] END colsample_bytree=0.6357191460839982, learning_rate=0.2181591947084738, min_child_samples=495, min_child_weight=0.006232732993940106, n_estimators=74, num_leaves=138, reg_alpha=0.7671858366277895, reg_lambda=0.8100881749370188, subsample=0.8538472279424327;, score=(train=0.939, test=0.837) total time=   1.0s
# [CV 4/5; 16/500] START colsample_bytree=0.7629201327323766, learning_rate=0.1192748356951025, min_child_samples=139, min_child_weight=0.005393279250397922, n_estimators=173, num_leaves=118, reg_alpha=0.974580007324722, reg_lambda=0.20213266230812282, subsample=0.9855907586810491
# [CV 4/5; 16/500] END colsample_bytree=0.7629201327323766, learning_rate=0.1192748356951025, min_child_samples=139, min_child_weight=0.005393279250397922, n_estimators=173, num_leaves=118, reg_alpha=0.974580007324722, reg_lambda=0.20213266230812282, subsample=0.9855907586810491;, score=(train=1.000, test=0.864) total time=   4.5s
# [CV 4/5; 17/500] START colsample_bytree=0.5678209211371046, learning_rate=0.026389417105567338, min_child_samples=245, min_child_weight=0.004989703834796677, n_estimators=141, num_leaves=53, reg_alpha=0.06989588084505009, reg_lambda=0.8171396006529525, subsample=0.5560658102701981
# [CV 4/5; 17/500] END colsample_bytree=0.5678209211371046, learning_rate=0.026389417105567338, min_child_samples=245, min_child_weight=0.004989703834796677, n_estimators=141, num_leaves=53, reg_alpha=0.06989588084505009, reg_lambda=0.8171396006529525, subsample=0.5560658102701981;, score=(train=0.854, test=0.808) total time=   2.4s
# [CV 2/5; 19/500] START colsample_bytree=0.6969879998793244, learning_rate=0.02287786901844493, min_child_samples=273, min_child_weight=0.0055354547779262915, n_estimators=324, num_leaves=101, reg_alpha=0.9224002946179483, reg_lambda=0.4656605035747334, subsample=0.7858974378438133
# [CV 2/5; 19/500] END colsample_bytree=0.6969879998793244, learning_rate=0.02287786901844493, min_child_samples=273, min_child_weight=0.0055354547779262915, n_estimators=324, num_leaves=101, reg_alpha=0.9224002946179483, reg_lambda=0.4656605035747334, subsample=0.7858974378438133;, score=(train=0.912, test=0.819) total time=   5.8s
# [CV 5/5; 21/500] START colsample_bytree=0.954937404008411, learning_rate=0.21751355971252292, min_child_samples=270, min_child_weight=0.004086271673714464, n_estimators=163, num_leaves=34, reg_alpha=0.33062081079891475, reg_lambda=0.9834311375601652, subsample=0.8293894916895413
# [CV 5/5; 21/500] END colsample_bytree=0.954937404008411, learning_rate=0.21751355971252292, min_child_samples=270, min_child_weight=0.004086271673714464, n_estimators=163, num_leaves=34, reg_alpha=0.33062081079891475, reg_lambda=0.9834311375601652, subsample=0.8293894916895413;, score=(train=1.000, test=0.862) total time=   4.3s
# [CV 3/5; 23/500] START colsample_bytree=0.965723344225673, learning_rate=0.14642642219971172, min_child_samples=477, min_child_weight=0.0001693191102267677, n_estimators=301, num_leaves=130, reg_alpha=0.2951567792441619, reg_lambda=0.28419064360475516, subsample=0.8628318893970073
# [CV 3/5; 23/500] END colsample_bytree=0.965723344225673, learning_rate=0.14642642219971172, min_child_samples=477, min_child_weight=0.0001693191102267677, n_estimators=301, num_leaves=130, reg_alpha=0.2951567792441619, reg_lambda=0.28419064360475516, subsample=0.8628318893970073;, score=(train=0.999, test=0.855) total time=   6.6s
# [CV 1/5; 25/500] START colsample_bytree=0.5929765918559615, learning_rate=0.13671556355010342, min_child_samples=438, min_child_weight=0.004328501901382878, n_estimators=457, num_leaves=141, reg_alpha=0.8862703088131431, reg_lambda=0.05929955189264629, subsample=0.7937462450895044
# [CV 1/5; 25/500] END colsample_bytree=0.5929765918559615, learning_rate=0.13671556355010342, min_child_samples=438, min_child_weight=0.004328501901382878, n_estimators=457, num_leaves=141, reg_alpha=0.8862703088131431, reg_lambda=0.05929955189264629, subsample=0.7937462450895044;, score=(train=1.000, test=0.861) total time=   7.8s
# [CV 3/5; 26/500] START colsample_bytree=0.6278505888977577, learning_rate=0.19953833388916856, min_child_samples=486, min_child_weight=0.003030860396202155, n_estimators=182, num_leaves=64, reg_alpha=0.8359040707212192, reg_lambda=0.8115313191056833, subsample=0.8666123667122825
# [CV 3/5; 26/500] END colsample_bytree=0.6278505888977577, learning_rate=0.19953833388916856, min_child_samples=486, min_child_weight=0.003030860396202155, n_estimators=182, num_leaves=64, reg_alpha=0.8359040707212192, reg_lambda=0.8115313191056833, subsample=0.8666123667122825;, score=(train=0.990, test=0.849) total time=   2.5s
# [CV 4/5; 27/500] START colsample_bytree=0.76173105970526, learning_rate=0.10948203337408337, min_child_samples=355, min_child_weight=0.008534507442513736, n_estimators=295, num_leaves=56, reg_alpha=0.36575273037448525, reg_lambda=0.44752196963684826, subsample=0.8491635745725834
# [CV 4/5; 27/500] END colsample_bytree=0.76173105970526, learning_rate=0.10948203337408337, min_child_samples=355, min_child_weight=0.008534507442513736, n_estimators=295, num_leaves=56, reg_alpha=0.36575273037448525, reg_lambda=0.44752196963684826, subsample=0.8491635745725834;, score=(train=0.999, test=0.869) total time=   5.1s
# [CV 2/5; 29/500] START colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203
# [CV 2/5; 29/500] END colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203;, score=(train=1.000, test=0.859) total time=   4.3s
# [CV 5/5; 29/500] START colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203
# [CV 5/5; 29/500] END colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203;, score=(train=1.000, test=0.865) total time=   3.9s
# [CV 5/5; 30/500] START colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286
# [CV 5/5; 30/500] END colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286;, score=(train=0.953, test=0.846) total time=   1.0s
# [CV 4/5; 31/500] START colsample_bytree=0.8606331304774888, learning_rate=0.25988900089034195, min_child_samples=268, min_child_weight=0.007894368775446374, n_estimators=495, num_leaves=96, reg_alpha=0.7281113112040195, reg_lambda=0.8292104763469844, subsample=0.9465614255203967
# [CV 4/5; 31/500] END colsample_bytree=0.8606331304774888, learning_rate=0.25988900089034195, min_child_samples=268, min_child_weight=0.007894368775446374, n_estimators=495, num_leaves=96, reg_alpha=0.7281113112040195, reg_lambda=0.8292104763469844, subsample=0.9465614255203967;, score=(train=1.000, test=0.865) total time=   4.9s
# [CV 3/5; 33/500] START colsample_bytree=0.6008976127113117, learning_rate=0.22178744960992644, min_child_samples=161, min_child_weight=0.0006544802587909171, n_estimators=343, num_leaves=116, reg_alpha=0.9192435052779919, reg_lambda=0.24497321180788062, subsample=0.9094972383901834
# [CV 3/5; 33/500] END colsample_bytree=0.6008976127113117, learning_rate=0.22178744960992644, min_child_samples=161, min_child_weight=0.0006544802587909171, n_estimators=343, num_leaves=116, reg_alpha=0.9192435052779919, reg_lambda=0.24497321180788062, subsample=0.9094972383901834;, score=(train=1.000, test=0.863) total time=   3.5s
# [CV 2/5; 35/500] START colsample_bytree=0.526532174812703, learning_rate=0.1073653102602023, min_child_samples=180, min_child_weight=0.00024793798298714757, n_estimators=287, num_leaves=104, reg_alpha=0.6918909419416709, reg_lambda=0.06073867038135022, subsample=0.8986267526597721
# [CV 2/5; 35/500] END colsample_bytree=0.526532174812703, learning_rate=0.1073653102602023, min_child_samples=180, min_child_weight=0.00024793798298714757, n_estimators=287, num_leaves=104, reg_alpha=0.6918909419416709, reg_lambda=0.06073867038135022, subsample=0.8986267526597721;, score=(train=1.000, test=0.856) total time=   5.2s
# [CV 5/5; 36/500] START colsample_bytree=0.9232406589088409, learning_rate=0.168782459534108, min_child_samples=292, min_child_weight=0.007988870204911434, n_estimators=454, num_leaves=115, reg_alpha=0.25400453283113517, reg_lambda=0.16265802085157915, subsample=0.9923906752740294
# [CV 5/5; 36/500] END colsample_bytree=0.9232406589088409, learning_rate=0.168782459534108, min_child_samples=292, min_child_weight=0.007988870204911434, n_estimators=454, num_leaves=115, reg_alpha=0.25400453283113517, reg_lambda=0.16265802085157915, subsample=0.9923906752740294;, score=(train=1.000, test=0.869) total time=   7.3s
# [CV 1/5; 2/500] START colsample_bytree=0.7676967674304089, learning_rate=0.1197306578497946, min_child_samples=438, min_child_weight=0.00043063308326785846, n_estimators=317, num_leaves=73, reg_alpha=0.6499012319862668, reg_lambda=0.37227264404505983, subsample=0.9335210168715294
# [CV 1/5; 2/500] END colsample_bytree=0.7676967674304089, learning_rate=0.1197306578497946, min_child_samples=438, min_child_weight=0.00043063308326785846, n_estimators=317, num_leaves=73, reg_alpha=0.6499012319862668, reg_lambda=0.37227264404505983, subsample=0.9335210168715294;, score=(train=0.998, test=0.857) total time=   4.1s
# [CV 1/5; 3/500] START colsample_bytree=0.6551286221305597, learning_rate=0.024850666743911676, min_child_samples=20, min_child_weight=0.00334658941417462, n_estimators=77, num_leaves=47, reg_alpha=0.4590196133500141, reg_lambda=0.6858679287504249, subsample=0.996998505485779
# [CV 1/5; 3/500] END colsample_bytree=0.6551286221305597, learning_rate=0.024850666743911676, min_child_samples=20, min_child_weight=0.00334658941417462, n_estimators=77, num_leaves=47, reg_alpha=0.4590196133500141, reg_lambda=0.6858679287504249, subsample=0.996998505485779;, score=(train=0.934, test=0.844) total time=   2.0s
# [CV 2/5; 4/500] START colsample_bytree=0.6062056232493445, learning_rate=0.2974894547758782, min_child_samples=277, min_child_weight=0.008712765129695923, n_estimators=91, num_leaves=136, reg_alpha=0.3021074899194223, reg_lambda=0.8127735491539001, subsample=0.9501615916275031
# [CV 2/5; 4/500] END colsample_bytree=0.6062056232493445, learning_rate=0.2974894547758782, min_child_samples=277, min_child_weight=0.008712765129695923, n_estimators=91, num_leaves=136, reg_alpha=0.3021074899194223, reg_lambda=0.8127735491539001, subsample=0.9501615916275031;, score=(train=0.999, test=0.849) total time=   1.6s
# [CV 3/5; 5/500] START colsample_bytree=0.648507454794542, learning_rate=0.1875935908052941, min_child_samples=248, min_child_weight=0.0008311710354274638, n_estimators=464, num_leaves=106, reg_alpha=0.25774887214167624, reg_lambda=0.2333231373392613, subsample=0.7779115017774032
# [CV 3/5; 5/500] END colsample_bytree=0.648507454794542, learning_rate=0.1875935908052941, min_child_samples=248, min_child_weight=0.0008311710354274638, n_estimators=464, num_leaves=106, reg_alpha=0.25774887214167624, reg_lambda=0.2333231373392613, subsample=0.7779115017774032;, score=(train=1.000, test=0.866) total time=   5.6s
# [CV 5/5; 6/500] START colsample_bytree=0.6144025438340186, learning_rate=0.04127037810427947, min_child_samples=270, min_child_weight=0.0017964103717113145, n_estimators=372, num_leaves=112, reg_alpha=0.9644397319063548, reg_lambda=0.3748811852878737, subsample=0.5250380458408055
# [CV 5/5; 6/500] END colsample_bytree=0.6144025438340186, learning_rate=0.04127037810427947, min_child_samples=270, min_child_weight=0.0017964103717113145, n_estimators=372, num_leaves=112, reg_alpha=0.9644397319063548, reg_lambda=0.3748811852878737, subsample=0.5250380458408055;, score=(train=0.982, test=0.850) total time=   5.7s
# [CV 4/5; 9/500] START colsample_bytree=0.7131692188039493, learning_rate=0.15207960102194776, min_child_samples=126, min_child_weight=0.006620486311235841, n_estimators=432, num_leaves=136, reg_alpha=0.41857195147367315, reg_lambda=0.7132056108356599, subsample=0.6121655129035777
# [CV 4/5; 9/500] END colsample_bytree=0.7131692188039493, learning_rate=0.15207960102194776, min_child_samples=126, min_child_weight=0.006620486311235841, n_estimators=432, num_leaves=136, reg_alpha=0.41857195147367315, reg_lambda=0.7132056108356599, subsample=0.6121655129035777;, score=(train=1.000, test=0.862) total time=   5.9s
# [CV 5/5; 11/500] START colsample_bytree=0.9341955687549997, learning_rate=0.02254657172213466, min_child_samples=403, min_child_weight=0.007511678843436882, n_estimators=457, num_leaves=117, reg_alpha=0.9759656719129202, reg_lambda=0.9857576514251851, subsample=0.7654189544957244
# [CV 5/5; 11/500] END colsample_bytree=0.9341955687549997, learning_rate=0.02254657172213466, min_child_samples=403, min_child_weight=0.007511678843436882, n_estimators=457, num_leaves=117, reg_alpha=0.9759656719129202, reg_lambda=0.9857576514251851, subsample=0.7654189544957244;, score=(train=0.919, test=0.841) total time=   6.4s
# [CV 1/5; 14/500] START colsample_bytree=0.9160301952192211, learning_rate=0.16507373093601682, min_child_samples=473, min_child_weight=0.005066035653002689, n_estimators=448, num_leaves=103, reg_alpha=0.7953283529408258, reg_lambda=0.2796583784551569, subsample=0.8090979101654628
# [CV 1/5; 14/500] END colsample_bytree=0.9160301952192211, learning_rate=0.16507373093601682, min_child_samples=473, min_child_weight=0.005066035653002689, n_estimators=448, num_leaves=103, reg_alpha=0.7953283529408258, reg_lambda=0.2796583784551569, subsample=0.8090979101654628;, score=(train=1.000, test=0.864) total time=   6.3s
# [CV 2/5; 16/500] START colsample_bytree=0.7629201327323766, learning_rate=0.1192748356951025, min_child_samples=139, min_child_weight=0.005393279250397922, n_estimators=173, num_leaves=118, reg_alpha=0.974580007324722, reg_lambda=0.20213266230812282, subsample=0.9855907586810491
# [CV 2/5; 16/500] END colsample_bytree=0.7629201327323766, learning_rate=0.1192748356951025, min_child_samples=139, min_child_weight=0.005393279250397922, n_estimators=173, num_leaves=118, reg_alpha=0.974580007324722, reg_lambda=0.20213266230812282, subsample=0.9855907586810491;, score=(train=1.000, test=0.855) total time=   4.5s
# [CV 3/5; 17/500] START colsample_bytree=0.5678209211371046, learning_rate=0.026389417105567338, min_child_samples=245, min_child_weight=0.004989703834796677, n_estimators=141, num_leaves=53, reg_alpha=0.06989588084505009, reg_lambda=0.8171396006529525, subsample=0.5560658102701981
# [CV 3/5; 17/500] END colsample_bytree=0.5678209211371046, learning_rate=0.026389417105567338, min_child_samples=245, min_child_weight=0.004989703834796677, n_estimators=141, num_leaves=53, reg_alpha=0.06989588084505009, reg_lambda=0.8171396006529525, subsample=0.5560658102701981;, score=(train=0.847, test=0.795) total time=   2.3s
# [CV 1/5; 19/500] START colsample_bytree=0.6969879998793244, learning_rate=0.02287786901844493, min_child_samples=273, min_child_weight=0.0055354547779262915, n_estimators=324, num_leaves=101, reg_alpha=0.9224002946179483, reg_lambda=0.4656605035747334, subsample=0.7858974378438133
# [CV 1/5; 19/500] END colsample_bytree=0.6969879998793244, learning_rate=0.02287786901844493, min_child_samples=273, min_child_weight=0.0055354547779262915, n_estimators=324, num_leaves=101, reg_alpha=0.9224002946179483, reg_lambda=0.4656605035747334, subsample=0.7858974378438133;, score=(train=0.911, test=0.825) total time=   6.2s
# [CV 4/5; 21/500] START colsample_bytree=0.954937404008411, learning_rate=0.21751355971252292, min_child_samples=270, min_child_weight=0.004086271673714464, n_estimators=163, num_leaves=34, reg_alpha=0.33062081079891475, reg_lambda=0.9834311375601652, subsample=0.8293894916895413
# [CV 4/5; 21/500] END colsample_bytree=0.954937404008411, learning_rate=0.21751355971252292, min_child_samples=270, min_child_weight=0.004086271673714464, n_estimators=163, num_leaves=34, reg_alpha=0.33062081079891475, reg_lambda=0.9834311375601652, subsample=0.8293894916895413;, score=(train=1.000, test=0.866) total time=   3.8s
# [CV 2/5; 23/500] START colsample_bytree=0.965723344225673, learning_rate=0.14642642219971172, min_child_samples=477, min_child_weight=0.0001693191102267677, n_estimators=301, num_leaves=130, reg_alpha=0.2951567792441619, reg_lambda=0.28419064360475516, subsample=0.8628318893970073
# [CV 2/5; 23/500] END colsample_bytree=0.965723344225673, learning_rate=0.14642642219971172, min_child_samples=477, min_child_weight=0.0001693191102267677, n_estimators=301, num_leaves=130, reg_alpha=0.2951567792441619, reg_lambda=0.28419064360475516, subsample=0.8628318893970073;, score=(train=0.999, test=0.847) total time=   7.1s
# [CV 5/5; 24/500] START colsample_bytree=0.7072860266189321, learning_rate=0.11417058862930773, min_child_samples=444, min_child_weight=0.007187108296775437, n_estimators=476, num_leaves=85, reg_alpha=0.48292970552628317, reg_lambda=0.839045980362488, subsample=0.6774747620811009
# [CV 5/5; 24/500] END colsample_bytree=0.7072860266189321, learning_rate=0.11417058862930773, min_child_samples=444, min_child_weight=0.007187108296775437, n_estimators=476, num_leaves=85, reg_alpha=0.48292970552628317, reg_lambda=0.839045980362488, subsample=0.6774747620811009;, score=(train=1.000, test=0.862) total time=   8.6s
# [CV 4/5; 26/500] START colsample_bytree=0.6278505888977577, learning_rate=0.19953833388916856, min_child_samples=486, min_child_weight=0.003030860396202155, n_estimators=182, num_leaves=64, reg_alpha=0.8359040707212192, reg_lambda=0.8115313191056833, subsample=0.8666123667122825
# [CV 4/5; 26/500] END colsample_bytree=0.6278505888977577, learning_rate=0.19953833388916856, min_child_samples=486, min_child_weight=0.003030860396202155, n_estimators=182, num_leaves=64, reg_alpha=0.8359040707212192, reg_lambda=0.8115313191056833, subsample=0.8666123667122825;, score=(train=0.992, test=0.853) total time=   2.6s
# [CV 5/5; 27/500] START colsample_bytree=0.76173105970526, learning_rate=0.10948203337408337, min_child_samples=355, min_child_weight=0.008534507442513736, n_estimators=295, num_leaves=56, reg_alpha=0.36575273037448525, reg_lambda=0.44752196963684826, subsample=0.8491635745725834
# [CV 5/5; 27/500] END colsample_bytree=0.76173105970526, learning_rate=0.10948203337408337, min_child_samples=355, min_child_weight=0.008534507442513736, n_estimators=295, num_leaves=56, reg_alpha=0.36575273037448525, reg_lambda=0.44752196963684826, subsample=0.8491635745725834;, score=(train=1.000, test=0.860) total time=   5.3s
# [CV 3/5; 29/500] START colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203
# [CV 3/5; 29/500] END colsample_bytree=0.6078008299325115, learning_rate=0.28699027089269746, min_child_samples=70, min_child_weight=0.007848372848819788, n_estimators=389, num_leaves=100, reg_alpha=0.19845715599271513, reg_lambda=0.4604204222494394, subsample=0.8464843589677203;, score=(train=1.000, test=0.872) total time=   4.1s
# [CV 1/5; 30/500] START colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286
# [CV 1/5; 30/500] END colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286;, score=(train=0.956, test=0.838) total time=   1.1s
# [CV 2/5; 30/500] START colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286
# [CV 2/5; 30/500] END colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286;, score=(train=0.952, test=0.830) total time=   1.1s
# [CV 3/5; 30/500] START colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286
# [CV 3/5; 30/500] END colsample_bytree=0.7386862525351254, learning_rate=0.2031816765382956, min_child_samples=435, min_child_weight=0.004349409311091845, n_estimators=75, num_leaves=63, reg_alpha=0.586156814629455, reg_lambda=0.22160995745508322, subsample=0.6500610151154286;, score=(train=0.954, test=0.843) total time=   1.0s
# [CV 1/5; 31/500] START colsample_bytree=0.8606331304774888, learning_rate=0.25988900089034195, min_child_samples=268, min_child_weight=0.007894368775446374, n_estimators=495, num_leaves=96, reg_alpha=0.7281113112040195, reg_lambda=0.8292104763469844, subsample=0.9465614255203967
# [CV 1/5; 31/500] END colsample_bytree=0.8606331304774888, learning_rate=0.25988900089034195, min_child_samples=268, min_child_weight=0.007894368775446374, n_estimators=495, num_leaves=96, reg_alpha=0.7281113112040195, reg_lambda=0.8292104763469844, subsample=0.9465614255203967;, score=(train=1.000, test=0.864) total time=   5.2s
# [CV 4/5; 32/500] START colsample_bytree=0.7624368070913342, learning_rate=0.01558025169778993, min_child_samples=141, min_child_weight=0.004546374332903495, n_estimators=171, num_leaves=103, reg_alpha=0.7280584984529597, reg_lambda=0.03476608300160538, subsample=0.5098521975714906
# [CV 4/5; 32/500] END colsample_bytree=0.7624368070913342, learning_rate=0.01558025169778993, min_child_samples=141, min_child_weight=0.004546374332903495, n_estimators=171, num_leaves=103, reg_alpha=0.7280584984529597, reg_lambda=0.03476608300160538, subsample=0.5098521975714906;, score=(train=0.868, test=0.817) total time=   3.3s
# [CV 3/5; 34/500] START colsample_bytree=0.6376101690099447, learning_rate=0.05836027000402384, min_child_samples=340, min_child_weight=0.005700582614316239, n_estimators=158, num_leaves=112, reg_alpha=0.8005062718050137, reg_lambda=0.7577380147055932, subsample=0.521671442435157
# [CV 3/5; 34/500] END colsample_bytree=0.6376101690099447, learning_rate=0.05836027000402384, min_child_samples=340, min_child_weight=0.005700582614316239, n_estimators=158, num_leaves=112, reg_alpha=0.8005062718050137, reg_lambda=0.7577380147055932, subsample=0.521671442435157;, score=(train=0.917, test=0.831) total time=   2.3s
# [CV 5/5; 35/500] START colsample_bytree=0.526532174812703, learning_rate=0.1073653102602023, min_child_samples=180, min_child_weight=0.00024793798298714757, n_estimators=287, num_leaves=104, reg_alpha=0.6918909419416709, reg_lambda=0.06073867038135022, subsample=0.8986267526597721
# [CV 5/5; 35/500] END colsample_bytree=0.526532174812703, learning_rate=0.1073653102602023, min_child_samples=180, min_child_weight=0.00024793798298714757, n_estimators=287, num_leaves=104, reg_alpha=0.6918909419416709, reg_lambda=0.06073867038135022, subsample=0.8986267526597721;, score=(train=1.000, test=0.859) total time=   5.3s
# [CV 3/5; 37/500] START colsample_bytree=0.8736118883618402, learning_rate=0.13045273734478594, min_child_samples=210, min_child_weight=0.0020101358569271244, n_estimators=330, num_leaves=101, reg_alpha=0.37933305743023277, reg_lambda=0.5850339535344945, subsample=0.7879240063222367
# [CV 3/5; 37/500] END colsample_bytree=0.8736118883618402, learning_rate=0.13045273734478594, min_child_samples=210, min_child_weight=0.0020101358569271244, n_estimators=330, num_leaves=101, reg_alpha=0.37933305743023277, reg_lambda=0.5850339535344945, subsample=0.7879240063222367;, score=(train=1.000, test=0.868) total time=   7.0s
# [CV 2/5; 39/500] START colsample_bytree=0.6366170272315417, learning_rate=0.2505017520297317, min_child_samples=94, min_child_weight=0.006907116197764718, n_estimators=154, num_leaves=125, reg_alpha=0.24239016067465863, reg_lambda=0.5191634228725925, subsample=0.7276082724618653
# [CV 2/5; 39/500] END colsample_bytree=0.6366170272315417, learning_rate=0.2505017520297317, min_child_samples=94, min_child_weight=0.006907116197764718, n_estimators=154, num_leaves=125, reg_alpha=0.24239016067465863, reg_lambda=0.5191634228725925, subsample=0.7276082724618653;, score=(train=1.000, test=0.857) total time=   3.4s
# ...
# [CV 4/5; 416/500] START colsample_bytree=0.8574923242491597, learning_rate=0.2846661594905912, min_child_samples=148, min_child_weight=0.004251044358753849, n_estimators=279, num_leaves=77, reg_alpha=0.08607645524048928, reg_lambda=0.17329703571477723, subsample=0.9207966105105452
# [CV 4/5; 416/500] END colsample_bytree=0.8574923242491597, learning_rate=0.2846661594905912, min_child_samples=148, min_child_weight=0.004251044358753849, n_estimators=279, num_leaves=77, reg_alpha=0.08607645524048928, reg_lambda=0.17329703571477723, subsample=0.9207966105105452;, score=(train=1.000, test=0.866) total time=   4.5s
# [CV 2/5; 418/500] START colsample_bytree=0.6449905690342621, learning_rate=0.13807251401223045, min_child_samples=432, min_child_weight=0.009861625481783062, n_estimators=267, num_leaves=80, reg_alpha=0.9928037819733815, reg_lambda=0.1974075238142588, subsample=0.5762064939885562
# [CV 2/5; 418/500] END colsample_bytree=0.6449905690342621, learning_rate=0.13807251401223045, min_child_samples=432, min_child_weight=0.009861625481783062, n_estimators=267, num_leaves=80, reg_alpha=0.9928037819733815, reg_lambda=0.1974075238142588, subsample=0.5762064939885562;, score=(train=0.994, test=0.846) total time=   4.1s
# [CV 1/5; 419/500] START colsample_bytree=0.6160417557370272, learning_rate=0.05564290116861788, min_child_samples=458, min_child_weight=0.005705931872774128, n_estimators=354, num_leaves=99, reg_alpha=0.41093891358426676, reg_lambda=0.7832587129171658, subsample=0.9956763914885198
# [CV 1/5; 419/500] END colsample_bytree=0.6160417557370272, learning_rate=0.05564290116861788, min_child_samples=458, min_child_weight=0.005705931872774128, n_estimators=354, num_leaves=99, reg_alpha=0.41093891358426676, reg_lambda=0.7832587129171658, subsample=0.9956763914885198;, score=(train=0.967, test=0.850) total time=   5.7s
# [CV 1/5; 421/500] START colsample_bytree=0.6151659884372931, learning_rate=0.18015115112245092, min_child_samples=173, min_child_weight=0.005450269124683046, n_estimators=181, num_leaves=46, reg_alpha=0.5354526180552451, reg_lambda=0.44600256612806904, subsample=0.6015992758994483
# [CV 1/5; 421/500] END colsample_bytree=0.6151659884372931, learning_rate=0.18015115112245092, min_child_samples=173, min_child_weight=0.005450269124683046, n_estimators=181, num_leaves=46, reg_alpha=0.5354526180552451, reg_lambda=0.44600256612806904, subsample=0.6015992758994483;, score=(train=1.000, test=0.856) total time=   3.6s
# [CV 4/5; 422/500] START colsample_bytree=0.8898575742371806, learning_rate=0.05021172440208946, min_child_samples=163, min_child_weight=0.009250894858366117, n_estimators=254, num_leaves=140, reg_alpha=0.4671013895300931, reg_lambda=0.6303935570756248, subsample=0.5559294003355272
# [CV 4/5; 422/500] END colsample_bytree=0.8898575742371806, learning_rate=0.05021172440208946, min_child_samples=163, min_child_weight=0.009250894858366117, n_estimators=254, num_leaves=140, reg_alpha=0.4671013895300931, reg_lambda=0.6303935570756248, subsample=0.5559294003355272;, score=(train=0.996, test=0.864) total time=   6.9s
# [CV 2/5; 425/500] START colsample_bytree=0.5438601158850553, learning_rate=0.012636808915309085, min_child_samples=204, min_child_weight=0.008945299454156978, n_estimators=370, num_leaves=50, reg_alpha=0.4236845802007389, reg_lambda=0.713413775571315, subsample=0.7053080040898712
# [CV 2/5; 425/500] END colsample_bytree=0.5438601158850553, learning_rate=0.012636808915309085, min_child_samples=204, min_child_weight=0.008945299454156978, n_estimators=370, num_leaves=50, reg_alpha=0.4236845802007389, reg_lambda=0.713413775571315, subsample=0.7053080040898712;, score=(train=0.892, test=0.817) total time=   6.7s
# [CV 5/5; 425/500] START colsample_bytree=0.5438601158850553, learning_rate=0.012636808915309085, min_child_samples=204, min_child_weight=0.008945299454156978, n_estimators=370, num_leaves=50, reg_alpha=0.4236845802007389, reg_lambda=0.713413775571315, subsample=0.7053080040898712
# [CV 5/5; 425/500] END colsample_bytree=0.5438601158850553, learning_rate=0.012636808915309085, min_child_samples=204, min_child_weight=0.008945299454156978, n_estimators=370, num_leaves=50, reg_alpha=0.4236845802007389, reg_lambda=0.713413775571315, subsample=0.7053080040898712;, score=(train=0.890, test=0.828) total time=   6.3s
# [CV 3/5; 428/500] START colsample_bytree=0.5104952154640217, learning_rate=0.25603999165840513, min_child_samples=31, min_child_weight=0.005318628059100625, n_estimators=354, num_leaves=39, reg_alpha=0.7829244257997096, reg_lambda=0.9587870435311637, subsample=0.750857174822599
# [CV 3/5; 428/500] END colsample_bytree=0.5104952154640217, learning_rate=0.25603999165840513, min_child_samples=31, min_child_weight=0.005318628059100625, n_estimators=354, num_leaves=39, reg_alpha=0.7829244257997096, reg_lambda=0.9587870435311637, subsample=0.750857174822599;, score=(train=1.000, test=0.863) total time=   3.8s
# [CV 1/5; 430/500] START colsample_bytree=0.9188607725796074, learning_rate=0.07469152984890776, min_child_samples=311, min_child_weight=0.006868009070384776, n_estimators=247, num_leaves=98, reg_alpha=0.13028982477442602, reg_lambda=0.18516375328765627, subsample=0.7021017433157875
# [CV 1/5; 430/500] END colsample_bytree=0.9188607725796074, learning_rate=0.07469152984890776, min_child_samples=311, min_child_weight=0.006868009070384776, n_estimators=247, num_leaves=98, reg_alpha=0.13028982477442602, reg_lambda=0.18516375328765627, subsample=0.7021017433157875;, score=(train=0.995, test=0.862) total time=   5.0s
# [CV 4/5; 431/500] START colsample_bytree=0.6959557707521091, learning_rate=0.0892860829130655, min_child_samples=204, min_child_weight=0.006264951038370861, n_estimators=442, num_leaves=70, reg_alpha=0.5394995921536846, reg_lambda=0.494787526070071, subsample=0.9046503148322771
# [CV 4/5; 431/500] END colsample_bytree=0.6959557707521091, learning_rate=0.0892860829130655, min_child_samples=204, min_child_weight=0.006264951038370861, n_estimators=442, num_leaves=70, reg_alpha=0.5394995921536846, reg_lambda=0.494787526070071, subsample=0.9046503148322771;, score=(train=1.000, test=0.868) total time=   9.6s
# [CV 3/5; 434/500] START colsample_bytree=0.8128363335797871, learning_rate=0.07752902653777605, min_child_samples=478, min_child_weight=0.0010767120272171195, n_estimators=445, num_leaves=142, reg_alpha=0.6162518024854473, reg_lambda=0.011355937675502182, subsample=0.5617715152749212
# [CV 3/5; 434/500] END colsample_bytree=0.8128363335797871, learning_rate=0.07752902653777605, min_child_samples=478, min_child_weight=0.0010767120272171195, n_estimators=445, num_leaves=142, reg_alpha=0.6162518024854473, reg_lambda=0.011355937675502182, subsample=0.5617715152749212;, score=(train=0.995, test=0.856) total time=   8.1s
# [CV 4/5; 436/500] START colsample_bytree=0.8497039226172267, learning_rate=0.09335083689759406, min_child_samples=140, min_child_weight=0.006439453439976767, n_estimators=331, num_leaves=52, reg_alpha=0.3404670261610592, reg_lambda=0.270163419618711, subsample=0.8797059346129674
# [CV 4/5; 436/500] END colsample_bytree=0.8497039226172267, learning_rate=0.09335083689759406, min_child_samples=140, min_child_weight=0.006439453439976767, n_estimators=331, num_leaves=52, reg_alpha=0.3404670261610592, reg_lambda=0.270163419618711, subsample=0.8797059346129674;, score=(train=1.000, test=0.865) total time=   8.5s
# [CV 4/5; 438/500] START colsample_bytree=0.6464753842174675, learning_rate=0.24406431306647092, min_child_samples=203, min_child_weight=0.007694530819080923, n_estimators=326, num_leaves=48, reg_alpha=0.08103170902055727, reg_lambda=0.4693393605769905, subsample=0.7059568470077098
# [CV 4/5; 438/500] END colsample_bytree=0.6464753842174675, learning_rate=0.24406431306647092, min_child_samples=203, min_child_weight=0.007694530819080923, n_estimators=326, num_leaves=48, reg_alpha=0.08103170902055727, reg_lambda=0.4693393605769905, subsample=0.7059568470077098;, score=(train=1.000, test=0.872) total time=   6.5s
# [CV 3/5; 440/500] START colsample_bytree=0.7740302470475009, learning_rate=0.1328879157800038, min_child_samples=25, min_child_weight=0.008219242229652847, n_estimators=103, num_leaves=131, reg_alpha=0.6676557469745911, reg_lambda=0.06706033509013735, subsample=0.7129126891085484
# [CV 3/5; 440/500] END colsample_bytree=0.7740302470475009, learning_rate=0.1328879157800038, min_child_samples=25, min_child_weight=0.008219242229652847, n_estimators=103, num_leaves=131, reg_alpha=0.6676557469745911, reg_lambda=0.06706033509013735, subsample=0.7129126891085484;, score=(train=1.000, test=0.859) total time=   3.5s
# [CV 2/5; 442/500] START colsample_bytree=0.6105137674182203, learning_rate=0.11085534801417955, min_child_samples=210, min_child_weight=0.00960861824500413, n_estimators=387, num_leaves=88, reg_alpha=0.6400805395457626, reg_lambda=0.21172564038963354, subsample=0.571216471827577
# [CV 2/5; 442/500] END colsample_bytree=0.6105137674182203, learning_rate=0.11085534801417955, min_child_samples=210, min_child_weight=0.00960861824500413, n_estimators=387, num_leaves=88, reg_alpha=0.6400805395457626, reg_lambda=0.21172564038963354, subsample=0.571216471827577;, score=(train=1.000, test=0.853) total time=   7.1s
# [CV 3/5; 444/500] START colsample_bytree=0.8740751880091228, learning_rate=0.1831661104471723, min_child_samples=248, min_child_weight=0.005894480394443422, n_estimators=234, num_leaves=136, reg_alpha=0.4751706540899128, reg_lambda=0.8191271897861714, subsample=0.8445549230850358
# [CV 3/5; 444/500] END colsample_bytree=0.8740751880091228, learning_rate=0.1831661104471723, min_child_samples=248, min_child_weight=0.005894480394443422, n_estimators=234, num_leaves=136, reg_alpha=0.4751706540899128, reg_lambda=0.8191271897861714, subsample=0.8445549230850358;, score=(train=1.000, test=0.863) total time=   4.9s
# [CV 5/5; 445/500] START colsample_bytree=0.7458179322947676, learning_rate=0.2815045491229445, min_child_samples=258, min_child_weight=0.0010907710324550692, n_estimators=195, num_leaves=115, reg_alpha=0.14508081072720452, reg_lambda=0.21414995645289997, subsample=0.7352047695988715
# [CV 5/5; 445/500] END colsample_bytree=0.7458179322947676, learning_rate=0.2815045491229445, min_child_samples=258, min_child_weight=0.0010907710324550692, n_estimators=195, num_leaves=115, reg_alpha=0.14508081072720452, reg_lambda=0.21414995645289997, subsample=0.7352047695988715;, score=(train=1.000, test=0.866) total time=   4.0s
# [CV 3/5; 447/500] START colsample_bytree=0.8982238255139641, learning_rate=0.13155117874642924, min_child_samples=165, min_child_weight=0.007772955273865851, n_estimators=467, num_leaves=97, reg_alpha=0.38875963280079956, reg_lambda=0.6992439481193956, subsample=0.5713395136755337
# [CV 3/5; 447/500] END colsample_bytree=0.8982238255139641, learning_rate=0.13155117874642924, min_child_samples=165, min_child_weight=0.007772955273865851, n_estimators=467, num_leaves=97, reg_alpha=0.38875963280079956, reg_lambda=0.6992439481193956, subsample=0.5713395136755337;, score=(train=1.000, test=0.867) total time=   9.5s
# [CV 5/5; 449/500] START colsample_bytree=0.5031015954164073, learning_rate=0.21361655797930681, min_child_samples=238, min_child_weight=0.0031367366123487683, n_estimators=444, num_leaves=92, reg_alpha=0.06417895369476105, reg_lambda=0.35215955782605207, subsample=0.5889070314836126
# [CV 5/5; 449/500] END colsample_bytree=0.5031015954164073, learning_rate=0.21361655797930681, min_child_samples=238, min_child_weight=0.0031367366123487683, n_estimators=444, num_leaves=92, reg_alpha=0.06417895369476105, reg_lambda=0.35215955782605207, subsample=0.5889070314836126;, score=(train=1.000, test=0.868) total time=   8.1s
# [CV 3/5; 453/500] START colsample_bytree=0.6456216017802736, learning_rate=0.23292855170540036, min_child_samples=444, min_child_weight=0.009876145864004595, n_estimators=94, num_leaves=31, reg_alpha=0.4470923561466765, reg_lambda=0.11654557693116123, subsample=0.7940242599743248
# [CV 3/5; 453/500] END colsample_bytree=0.6456216017802736, learning_rate=0.23292855170540036, min_child_samples=444, min_child_weight=0.009876145864004595, n_estimators=94, num_leaves=31, reg_alpha=0.4470923561466765, reg_lambda=0.11654557693116123, subsample=0.7940242599743248;, score=(train=0.977, test=0.848) total time=   1.4s
# [CV 1/5; 454/500] START colsample_bytree=0.9117152361743749, learning_rate=0.07094415495569581, min_child_samples=142, min_child_weight=0.006012556203600715, n_estimators=146, num_leaves=52, reg_alpha=0.3962922179261776, reg_lambda=0.1873572075673003, subsample=0.6979152484482432
# [CV 1/5; 454/500] END colsample_bytree=0.9117152361743749, learning_rate=0.07094415495569581, min_child_samples=142, min_child_weight=0.006012556203600715, n_estimators=146, num_leaves=52, reg_alpha=0.3962922179261776, reg_lambda=0.1873572075673003, subsample=0.6979152484482432;, score=(train=0.996, test=0.863) total time=   3.8s
# [CV 5/5; 456/500] START colsample_bytree=0.6469992214735325, learning_rate=0.0939793887017775, min_child_samples=430, min_child_weight=0.0024740855276401165, n_estimators=323, num_leaves=35, reg_alpha=0.749254674497866, reg_lambda=0.6044301794778514, subsample=0.8393571322330472
# [CV 5/5; 456/500] END colsample_bytree=0.6469992214735325, learning_rate=0.0939793887017775, min_child_samples=430, min_child_weight=0.0024740855276401165, n_estimators=323, num_leaves=35, reg_alpha=0.749254674497866, reg_lambda=0.6044301794778514, subsample=0.8393571322330472;, score=(train=0.991, test=0.855) total time=   5.1s
# [CV 5/5; 459/500] START colsample_bytree=0.7527949513623795, learning_rate=0.23771190864582412, min_child_samples=85, min_child_weight=0.0016364947410170572, n_estimators=205, num_leaves=32, reg_alpha=0.35858673587071804, reg_lambda=0.5357851820446489, subsample=0.8948310023663458
# [CV 5/5; 459/500] END colsample_bytree=0.7527949513623795, learning_rate=0.23771190864582412, min_child_samples=85, min_child_weight=0.0016364947410170572, n_estimators=205, num_leaves=32, reg_alpha=0.35858673587071804, reg_lambda=0.5357851820446489, subsample=0.8948310023663458;, score=(train=1.000, test=0.865) total time=   3.7s
# [CV 3/5; 461/500] START colsample_bytree=0.9976677025713878, learning_rate=0.12835452751022142, min_child_samples=48, min_child_weight=0.0034456170746941005, n_estimators=191, num_leaves=129, reg_alpha=0.3034742426401263, reg_lambda=0.1958442809687196, subsample=0.9935241682451124
# [CV 3/5; 461/500] END colsample_bytree=0.9976677025713878, learning_rate=0.12835452751022142, min_child_samples=48, min_child_weight=0.0034456170746941005, n_estimators=191, num_leaves=129, reg_alpha=0.3034742426401263, reg_lambda=0.1958442809687196, subsample=0.9935241682451124;, score=(train=1.000, test=0.865) total time=   5.7s
# [CV 5/5; 463/500] START colsample_bytree=0.6332950871831955, learning_rate=0.0695601272162837, min_child_samples=73, min_child_weight=0.0008874046477708586, n_estimators=316, num_leaves=94, reg_alpha=0.8280091547874295, reg_lambda=0.29586460980947243, subsample=0.8140743792853407
# [CV 5/5; 463/500] END colsample_bytree=0.6332950871831955, learning_rate=0.0695601272162837, min_child_samples=73, min_child_weight=0.0008874046477708586, n_estimators=316, num_leaves=94, reg_alpha=0.8280091547874295, reg_lambda=0.29586460980947243, subsample=0.8140743792853407;, score=(train=1.000, test=0.864) total time=   7.9s
# [CV 2/5; 467/500] START colsample_bytree=0.8195697890565126, learning_rate=0.1564529457726573, min_child_samples=243, min_child_weight=0.008077973383164818, n_estimators=93, num_leaves=88, reg_alpha=0.5273889412659712, reg_lambda=0.42819848785184517, subsample=0.6793586559075449
# [CV 2/5; 467/500] END colsample_bytree=0.8195697890565126, learning_rate=0.1564529457726573, min_child_samples=243, min_child_weight=0.008077973383164818, n_estimators=93, num_leaves=88, reg_alpha=0.5273889412659712, reg_lambda=0.42819848785184517, subsample=0.6793586559075449;, score=(train=0.989, test=0.842) total time=   1.8s

# %%
cv_results.head()

# %%
results_path = f"./tuning_results/tuning_lgbm/{timestamp}/Assets"
if not os.path.exists(results_path):
    os.makedirs(results_path)

# %% [markdown]
# # CV Evaluation

# %%
cv_results.columns

# %%
cv_results.sort_values(by='rank_test_score', ascending=True).head(5)

# %%
sorted_cv = cv_results.sort_values(by='rank_test_score', ascending=True)

# %% [markdown]
# # Train vs Test Comparison

# %%
plt.figure(figsize=(16, 6))    

plt.plot(sorted_cv['rank_test_score'], sorted_cv['mean_train_score'], label="Train Score")
plt.plot(sorted_cv['rank_test_score'], sorted_cv['mean_test_score'], label="Test Score")

plt.grid()
plt.xlabel('Sorted Test Rank')
plt.ylabel('Accuracy')
plt.title('Train and Test Accuracy by Final Rank (top 15)')
plt.legend(loc='best')

filename = "test_train_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(10, 3))
fig.suptitle('Test Accuracy by Rank')

ax = fig.add_subplot(111)

plt.boxplot(sorted_cv.iloc[:10, :][['split0_test_score', 'split1_test_score', 'split2_test_score',
   'split3_test_score', 'split4_test_score']].T)
ax.set_xticklabels(range(1, 11))
ax.set_xlabel("Rank")
ax.set_ylabel("Accuracy")

filename = "test_accuracy_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
# boxplot algorithm comparison
fig = plt.figure(figsize=(10, 3))
fig.suptitle('Train Accuracy by Rank')

ax = fig.add_subplot(111)

plt.boxplot(sorted_cv.iloc[:10, :][['split0_train_score', 'split1_train_score', 'split2_train_score',
   'split3_train_score', 'split4_train_score']].T)
ax.set_xticklabels(range(1, 11))
ax.set_xlabel("Rank")
ax.set_ylabel("Accuracy")

filename = "train_accuracy_by_rank.png"
plt.savefig(os.path.join(results_path, filename))

plt.show()

# %%
max_params = cv_results.loc[cv_results['rank_test_score'] == 1]
best_params = max_params.params.values[0]

# %%
print(f"Mean Train set, Accuracy = {max_params['mean_train_score'].values[0]:.2f}")
print(f"Mean Test  set, Accuracy = {max_params['mean_test_score'].values[0]:.2f}")

# %%
random_search = pickle.load(open(os.path.join(f"./tuning_results/tuning_lgbm/{timestamp}", file_name), "rb"))
model = random_search.best_estimator_

#model = LGBMClassifier(**best_params)
#model.fit(X_train, y_train)

y_train_prediction = model.predict(X_train)
y_test_prediction = model.predict(X_test)

# %%
print(f"Train set, Accuracy = {accuracy_score(y_train, y_train_prediction):.2f}")
print(f"Test set, Accuracy = {accuracy_score(y_test, y_test_prediction):.2f}")

# %%
ind = np.argpartition(model.feature_importances_, -20)[-20:]

features = X.columns[ind]
importance = model.feature_importances_[ind]

fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(ind)), importance, align='center')
plt.yticks(range(len(ind)), features)
plt.title('Feature Importance LGBM')
plt.grid()

filename = "feature_importance.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %%
# TEST
for col in ['param_n_estimators', 'param_learning_rate']:
    
    plt.figure(figsize=(16, 6))    

    m, b = np.polyfit(list(sorted_cv['rank_test_score'].values), list(sorted_cv[col].values), 1)
    plt.plot(sorted_cv['rank_test_score'], m * sorted_cv['rank_test_score'] + b, c='r', label="Regression Line")
    plt.plot(sorted_cv['rank_test_score'], sorted_cv[col], label=f"{col} Values")
    
    plt.grid()
    plt.xlabel('Hyperparameter Values')
    plt.ylabel('Parameter Value')
    plt.title(col)
    plt.legend(loc='best')

    
    filename = f"{col}_by_rank.png"
    plt.savefig(os.path.join(results_path, filename))
                  
    plt.show()

# %% [markdown]
# # Hyperparameter Evaluation

# %%
def plot_parameters(x_values, title):
    
    fig, ax1 = plt.subplots(figsize=(16, 6))
    ax2 = ax1.twinx()

    ax1.scatter(x_values, cv_results['mean_test_score'], label='mean_test_score', c='b')
    ax2.scatter(x_values, cv_results['std_test_score'], label='std_test_score', c='r')

    m, b = np.polyfit(list(x_values.values), list(cv_results['mean_test_score'].values), 1)
    ax1.plot(x_values, m * x_values + b, c='b')

    m, b = np.polyfit(list(x_values.values), list(cv_results['std_test_score'].values), 1)
    ax2.plot(x_values, m * x_values + b, c='r')
    
    ax1.set_title(title)
    ax1.set_xlabel('Parameter Value')
    ax1.set_ylabel('Mean Test Score')
    ax2.set_ylabel('Standard Deviation of Test Score')
    ax1.grid(True)
    
    
    # Combine the legends from both axes
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax2.legend(lines + lines2, labels + labels2, loc='upper right')

    filename = f"{title}_test_score.png"
    plt.savefig(os.path.join(results_path, filename))
            
    plt.show()

# %%
for param in ['param_n_estimators', 'param_learning_rate']:
    x_values = cv_results[param]
    plot_parameters(x_values, param)

# %% [markdown]
# # Plotting Evaluation Metrics (Precision, Recall, F1-Score, AUC-ROC):

# %%
# For multiclass classification, you need to binarize the labels
y_true_bin = label_binarize(y_test, classes=np.unique(y_test))
y_score_bin = label_binarize(y_test_prediction, classes=np.unique(y_test_prediction))

auc_roc = roc_auc_score(y_true_bin, y_score_bin, average='macro')

# Plot Precision-Recall curve for each class
precision = dict()
recall = dict()

plt.figure(figsize=(16, 6))    
for i in range(7):
    precision[i], recall[i], _ = precision_recall_curve(y_true_bin[:, i], y_score_bin[:, i])
    plt.plot(recall[i], precision[i], label='Covertype {}'.format(i + 1))

plt.grid()
plt.xlabel('Recall')
plt.ylabel('True Positive Rate / Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')

filename = "precision_recall.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()


# Plot AUC-ROC curve for each class
fpr = dict()
tpr = dict()

plt.figure(figsize=(16, 6))    
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score_bin[:, i])
    plt.plot(fpr[i], tpr[i], label='Covertype {}'.format(i + 1))

plt.grid()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate / Precision')
plt.title('ROC Curve')
plt.legend(loc='best')
            
filename = "roc_curve.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# # Partial Dependence

# %%
# potentially iterate over features (and relation ie 0 to 1)

# %%
features, feature_names = [(0,)], [f"Features #{i}" for i in range(X.shape[1])]
deciles = {0: np.linspace(0, 1, num=5)}

pd_results = partial_dependence(
    model, X, features=1, kind="average", grid_resolution=5)

display = PartialDependenceDisplay(
    [pd_results], features=features, feature_names=feature_names,
    target_idx=0, deciles=deciles
)
display.plot(pdp_lim={1: (-1.38, 0.66)})

plt.grid()
plt.xlabel('Feature Value')
plt.ylabel('Partial Dependence') 
plt.title('Partial Dependence')

filename = "partial_dependence.png"
plt.savefig(os.path.join(results_path, filename))
            
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
class_names = np.unique(y)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [
    ("Confusion matrix without normalization", None),
    ("Normalized confusion matrix", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        model,
        X_test,
        y_test,
        display_labels=class_names + 1,
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    png_name = title.lower().replace(" ", "_")
    filename = f"{png_name}.png"
    plt.savefig(os.path.join(results_path, filename))

plt.show()

# %% [markdown]
# # Shap Values

# %%
explainer = shap.TreeExplainer(model)
explanation = explainer.shap_values(X_test, check_additivity=False)

# %%
shap.summary_plot(explanation, X_test, plot_type="bar", show=False)

filename = f"shap_summary.png"
plt.savefig(os.path.join(results_path, filename))
plt.close()

# %% [markdown]
# SHAP values show how each feature affects each final prediction, the significance of each feature compared to others, and the model's reliance on the interaction between features.
